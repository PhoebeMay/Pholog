# %%
import matplotlib.pyplot as plt
import  matplotlib

font = {'size'   : 15}

loc = "/home/phoebe/Dropbox/Stuff1819/proooject/diss/graphs"

plt.rc('text', usetex=True)


import statistics 

plt.rc('font', **font)

# %%
tro = [2.85, 2.85, 2.85, 3.01, 2.98, 2.85, 2.86, 2.85, 2.83, 2.83]
trno = [10.77, 10.46, 10.23, 10.20, 10.06, 10.52, 10.15, 9.87, 10.11, 11.27]


print(statistics.mean(tro))
print(statistics.stdev(tro))

print(statistics.mean(trno))
print(statistics.stdev(trno))

print(statistics.mean(trno) / statistics.mean(tro))
# Out:
# 2.876
# 0.06380525927469538
# 10.364
# 0.40972077212549407
# 3.6036161335187766

# %%
# yes tail recursion 

yes = [(1553393257802536616,150057),
(1553393257823885147,151750),
(1553393257848293063,153668),
(1553393257871022628,155325),
(1553393257895462409,157222),
(1553393257918707790,158915),
(1553393257942830061,160935),
(1553393257965154553,162839),
(1553393257989795239,164532),
(1553393258012507005,166405),
(1553393258037135327,168099),
(1553393258060515217,170119),
(1553393258085015866,172057),
(1553393258110044373,173707),
(1553393258134797030,175609),
(1553393258160502192,177289),
(1553393258185116326,179160),
(1553393258210754575,180853),
(1553393258236923208,182726),
(1553393258261472224,184420),
(1553393258286712517,186317),
(1553393258312480678,187967),
(1553393258336842114,189869),
(1553393258362484526,191549),
(1553393258388618352,193420),
(1553393258413094174,195113),
(1553393258438330949,197022),
(1553393258463632971,198679),
(1553393258488194401,200576),
(1553393258513711655,202226),
(1553393258537740521,204128),
(1553393258563572001,205808),
(1553393258588157837,176435),
(1553393258611321032,178128),
(1553393258635691435,180046),
(1553393258658412956,181703),
(1553393258682126781,183600),
(1553393258705307755,185293),
(1553393258729262885,187313),
(1553393258751761382,189217),
(1553393258775248466,190910),
(1553393258798079409,192783),
(1553393258821989436,194477),
(1553393258844572179,196497),
(1553393258868239217,198401),
(1553393258890883733,200094),
(1553393258915176969,201967),
(1553393258937623038,203661),
(1553393258961417353,205558),
(1553393258984125337,207208),
(1553393259008095539,209110),
(1553393259031616146,210795),
(1553393259056936127,212692),
(1553393259082219392,214342),
(1553393259106642813,216244),
(1553393259132076320,217924),
(1553393259157308437,219795),
(1553393259181074076,221488),
(1553393259206508790,223397),
(1553393259231628811,225054),
(1553393259257148349,226951),
(1553393259282476658,228601),
(1553393259306945901,230503),
(1553393259332092557,232183),
(1553393259357647664,234054),
(1553393259383577046,235747),
(1553393259409133427,237665),
(1553393259434224591,239322),
(1553393259458085344,241219),
(1553393259483745991,242912),
(1553393259509151129,244932),
(1553393259531910296,177490),
(1553393259555876332,179147),
(1553393259578739536,181044),
(1553393259602851188,182738),
(1553393259625318180,184758),
(1553393259649331752,186662),
(1553393259671566994,188355),
(1553393259695530046,190228),
(1553393259718404189,191922),
(1553393259742353608,193979),
(1553393259764517819,195841),
(1553393259788229917,197534),
(1553393259811113132,199443),
(1553393259834738562,201100),
(1553393259857648554,202997),
(1553393259881467489,204647),
(1553393259904341257,206549),
(1553393259928142018,208229),
(1553393259950396369,210100),
(1553393259974594927,211793),
(1553393259997133565,213711),
(1553393260022005320,215368),
(1553393260044148973,217265),
(1553393260068395293,218956),
(1553393260092857950,220874),
(1553393260118039570,222531),
(1553393260143256790,224428),
(1553393260166887632,226121),
(1553393260191884030,228141),
(1553393260216517507,230045),
(1553393260242353412,231738),
(1553393260267965522,233611),
(1553393260292418018,235305),
(1553393260317386046,237325),
(1553393260342995941,239229),
(1553393260367500581,240922),
(1553393260394219637,242795),
(1553393260421185022,244489),
(1553393260446779111,246386),
(1553393260472661011,248036),
(1553393260498387454,249938),
(1553393260523474458,251618),
(1553393260548511466,176018),
(1553393260572827358,177711),
(1553393260595748043,179620),
(1553393260620211563,181277),
(1553393260643432502,183174),
(1553393260667859624,184824),
(1553393260690742173,186726)]

(start,z) = yes[0]
yes_x = [(i - start)/1000000000 for (i,j) in yes]
yes_y = [j for (i,j) in yes]

# %%
no = [(1553393324870227632,150057),
(1553393324894702112,151750),
(1553393324923391573,153668),
(1553393324949605630,155325),
(1553393324974261649,157222),
(1553393324996935160,158915),
(1553393325022725774,160935),
(1553393325046390840,162839),
(1553393325070667270,164532),
(1553393325093625568,166405),
(1553393325117197807,168099),
(1553393325140446055,170119),
(1553393325164050450,172057),
(1553393325188043803,173707),
(1553393325213541598,175609),
(1553393325238119954,177289),
(1553393325262937825,179160),
(1553393325288863694,180853),
(1553393325312588413,182726),
(1553393325338195245,184420),
(1553393325365609476,186317),
(1553393325391314819,187967),
(1553393325416134523,189869),
(1553393325441562286,191549),
(1553393325465340736,193420),
(1553393325490796293,195113),
(1553393325516399033,197022),
(1553393325540634624,198679),
(1553393325566035608,200576),
(1553393325590209810,202226),
(1553393325615398486,204128),
(1553393325640449740,205808),
(1553393325664235651,176435),
(1553393325688189226,178128),
(1553393325710254127,180046),
(1553393325734237288,181703),
(1553393325757333529,183600),
(1553393325781106033,185293),
(1553393325803412257,187313),
(1553393325827701139,189217),
(1553393325851401544,190910),
(1553393325875188060,192783),
(1553393325897323429,194477),
(1553393325921370115,196497),
(1553393325944449909,198401),
(1553393325968242675,200094),
(1553393325991025551,201967),
(1553393326015093464,203661),
(1553393326037707589,205558),
(1553393326061621490,207208),
(1553393326084294820,209110),
(1553393326109239492,210795),
(1553393326134581718,212692),
(1553393326158590635,214342),
(1553393326184003252,216244),
(1553393326209102454,217924),
(1553393326233527041,219795),
(1553393326259028466,221488),
(1553393326283105628,223397),
(1553393326308699941,225054),
(1553393326334303527,226951),
(1553393326358927941,228601),
(1553393326387580206,230503),
(1553393326414170544,232183),
(1553393326438648869,234054),
(1553393326463765538,235747),
(1553393326489022536,237665),
(1553393326513651198,239322),
(1553393326539030361,241219),
(1553393326564292963,242912),
(1553393326588349598,244932),
(1553393326612822839,177490),
(1553393326635737366,179147),
(1553393326660105164,181044),
(1553393326683059027,182738),
(1553393326706726412,184758),
(1553393326730441639,186662),
(1553393326754217629,188355),
(1553393326777547411,190228),
(1553393326800953095,191922),
(1553393326825309333,193979),
(1553393326849351169,195841),
(1553393326873683152,197534),
(1553393326896368580,199443),
(1553393326920418784,201100),
(1553393326943386560,202997),
(1553393326967544080,204647),
(1553393326990494899,206549),
(1553393327014375723,208229),
(1553393327037784870,210100),
(1553393327061535761,211793),
(1553393327085349459,213711),
(1553393327108135911,215368),
(1553393327132371611,217265),
(1553393327156438505,218956),
(1553393327181746714,220874),
(1553393327205690778,222531),
(1553393327230754708,224428),
(1553393327255597712,226121),
(1553393327280303939,228141),
(1553393327305780249,230045),
(1553393327330288413,231738),
(1553393327355731903,233611),
(1553393327381434628,235305),
(1553393327405751141,237325),
(1553393327431468725,239229),
(1553393327457213915,240922),
(1553393327481299134,242795),
(1553393327506951004,244489),
(1553393327532635312,246386),
(1553393327557183583,248036),
(1553393327582788856,249938),
(1553393327607494785,251618),
(1553393327632023219,176018),
(1553393327656470856,177711),
(1553393327679589781,179620),
(1553393327703640839,181277),
(1553393327726286934,183174),
(1553393327750521977,184824),
(1553393327773183178,186726)]

(start,z)=no[0]
no_x = [(i-start)/1000000000 for (i,j) in no]
no_y = [j for (i,j) in no]

# %%
yes2 = [(1553525236651803531,148954),
(1553525236689171320,150498),
(1553525236732929137,152005),
(1553525236767772368,153553),
(1553525236788971001,155067),
(1553525236814213908,156621),
(1553525236837483048,158133),
(1553525236858282026,159677),
(1553525236879149050,161189),
(1553525236908283414,162742),
(1553525236929658142,164242),
(1553525236950436591,165794),
(1553525236973123481,167300),
(1553525236996189445,168850),
(1553525237023688087,170386),
(1553525237047113406,171935),
(1553525237071163066,173487),
(1553525237095875694,175009),
(1553525237123459391,176545),
(1553525237147926737,178052),
(1553525237172418204,179600),
(1553525237194675922,181114),
(1553525237219254949,182668),
(1553525237241951531,184180),
(1553525237263898984,185724),
(1553525237285818504,187236),
(1553525237313962794,188789),
(1553525237338434320,190289),
(1553525237361823557,191841),
(1553525237385358088,193347),
(1553525237411399048,194897),
(1553525237436913716,196433),
(1553525237461018530,197977),
(1553525237484873215,199491),
(1553525237511332012,201039),
(1553525237535652579,202546),
(1553525237559764090,204098),
(1553525237583188461,205620),
(1553525237608287888,176622),
(1553525237632084168,178129),
(1553525237656156898,179677),
(1553525237678202570,181191),
(1553525237702508626,182881),
(1553525237727745102,184429),
(1553525237749548011,185943),
(1553525237778509086,187497),
(1553525237807854799,189009),
(1553525237830607829,190553),
(1553525237852703506,192065),
(1553525237875131621,193618),
(1553525237898161919,195118),
(1553525237928653234,196670),
(1553525237951638888,198176),
(1553525237983967313,199726),
(1553525238015034929,201262),
(1553525238038599159,202806),
(1553525238062201952,204320),
(1553525238086252783,205868),
(1553525238114281677,207375),
(1553525238138106322,208927),
(1553525238162502622,210481),
(1553525238187205577,211995),
(1553525238215951615,213549),
(1553525238240980563,215061),
(1553525238266102559,216605),
(1553525238291044466,218117),
(1553525238319748063,219670),
(1553525238344688806,221170),
(1553525238368279844,222722),
(1553525238391538259,224228),
(1553525238416904922,225778),
(1553525238440830748,227314),
(1553525238463038947,228858),
(1553525238486725945,230372),
(1553525238513105167,231920),
(1553525238538594338,233427),
(1553525238563760064,234979),
(1553525238602931794,236501),
(1553525238633460914,238037),
(1553525238659086337,239544),
(1553525238684044428,241092),
(1553525238711133327,242606),
(1553525238740871118,244160),
(1553525238766062001,176540),
(1553525238790931847,178084),
(1553525238822296412,179596),
(1553525238850154862,181149),
(1553525238874897417,182649),
(1553525238899113084,184201),
(1553525238924728768,185707),
(1553525238949877923,187257),
(1553525238973104023,188793),
(1553525238996379323,190337),
(1553525239020829656,191851),
(1553525239042958909,193399),
(1553525239063774706,194906),
(1553525239084433526,196458),
(1553525239107564278,197980),
(1553525239134456307,199516),
(1553525239158021393,201023),
(1553525239180935693,202571),
(1553525239204378108,204085),
(1553525239232336483,205639),
(1553525239255517937,207151),
(1553525239279044398,208695),
(1553525239302316446,210207),
(1553525239329397642,211760),
(1553525239352214784,213260),
(1553525239374469513,214812),
(1553525239397403068,216318),
(1553525239422399858,217868),
(1553525239447881533,219416),
(1553525239471555668,220914),
(1553525239495325953,222467),
(1553525239520800175,223998),
(1553525239545813768,225542),
(1553525239569936802,227049),
(1553525239593820321,228597),
(1553525239619345562,230111),
(1553525239646603502,231665)]

(start,z) = yes2[0]
yes2_x = [(i - start)/1000000000 for (i,j) in yes2]
yes2_y = [j for (i,j) in yes2]

# %%
plt.plot(yes_x,yes_y,color='black',linewidth=0.5)
plt.plot(yes2_x,yes2_y,color='red')
plt.xlabel("Time / s")
plt.ylabel("Words of live data in the major heap")
plt.ticklabel_format(style='sci',scilimits=(0,0))

plt.savefig((loc + "/tail_recursion_opt.png"),dpi=800,bbox_inches='tight')

# %%
no_x_raw = [0, 81182783, 167679359, 250698165, 357914179, 444725594, 549612827, 632445749, 733707112, 877225386, 968417042, 1067989957, 1185482051, 1311516050, 1468672982, 1575802606, 1687081887, 1817533631, 1950657195, 2138864251, 2294935219, 2421558767, 2547271553, 2675697914, 2828035158, 2980416552, 3137111512, 3299256984, 3558657205, 3725974063, 3877469417, 4031676357, 4186902779, 4344360739, 4510591204, 4687826675, 4869619775, 5057860454, 5250849919, 5558003040, 5770576450, 5993821032, 6220860361, 6405190785, 6593793755, 6784665669, 6976291062, 7171407845, 7372521667, 7585884042, 7805068265, 8026808075, 8250616976, 8479443054, 8712175237, 8950475336, 9193849861, 9438061882, 9849811400, 10152727416, 10411278909, 10651982029, 10889376145, 11139712987, 11383316121, 11630176895, 11877692796, 12127557884, 12384111861, 12693471870, 12991148951, 13326193006, 13628405172, 13937236300, 14265154269, 14600248323, 14935170083, 15261277942, 15596603195, 15959424253, 16508410101, 16856589739, 17206269440, 17563698015, 17898046394, 18251778807, 18655153466, 18961048866, 19276303746, 19594917295, 19911710643, 20239131038, 20575101261, 20913345954, 21260309073, 21609562765, 21954265659, 22311741985, 22698125236, 23070688086, 23447055735, 23848606846, 24262657193, 24683565403, 25071791111, 25445090151, 25853547667, 26259706792, 26644875358, 27043368769, 27399596113, 27735547095, 28083596964, 28442052105, 28816281870, 29180345128, 29542703188, 29903187030, 30264441961, 30635662778]
no_x = [i/1000000000 for i in no_x_raw]
no_y = [2828392, 5558504, 8316621, 11019867, 13750271, 16453975, 19184100, 21915109, 24673469, 27403153, 30134188, 32837919, 35568928, 38299955, 41029211, 43760217, 46463926, 49194961, 51925970, 54656997, 57385449, 60116455, 62847490, 65578507, 68282228, 71013255, 73744284, 76475290, 79206325, 81933560, 84664587, 87395611, 90126617, 92857652, 95561376, 98292385, 101023412, 103754441, 106485447, 109216482, 111947499, 114678526, 117404305, 120135311, 122866346, 125597363, 128328390, 131004782, 133735809, 136494139, 139225174, 141956191, 144687218, 147418242, 150149248, 152825663, 155556669, 158287704, 161018713, 163749740, 166473197, 169204203, 171935238, 174666247, 177397274, 180128298, 182859304, 185590339, 188321356, 191052383, 193756085, 196487114, 199218120, 201949155, 204680172, 207411199, 210142223, 212873229, 215604264, 218335281, 221011698, 223742707, 226473734, 229204763, 231935769, 234666804, 237387060, 240118087, 242849116, 245580122, 248311157, 251042174, 253773201, 256504225, 259235231, 261966266, 264697283, 267373700, 270104709, 272835736, 275566765, 278325108, 281056125, 283787152, 286518176, 289194566, 291925595, 294656601, 297387636, 300118645, 300160324, 300160481, 300160638, 300160797, 300160954, 300161111, 300161270, 300161427, 300161584, 300161743]

# %%
fig,ax = plt.subplots(1,1)

ax.plot(no_x,no_y,color="black",linewidth=0.5)
ax.set_xlabel("Time / s")
ax.set_ylabel("Words of live data in the major heap")
# plt.ticklabel_format(style='plain')
# print(act_x)
# print(act_y)


fig.savefig((loc + "/no_tail_recursion.png"),dpi=800,bbox_inches='tight')

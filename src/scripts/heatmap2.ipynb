# %%
import subprocess
import re
import seaborn
import numpy
import statistics
import matplotlib.pyplot as plt




font = {'size'   : 20}

plt.rc('font', **font)


seaborn.set(rc={'text.usetex' : True})


plt.rc('text', usetex=True)

seaborn.set(font_scale=1.2)

loc = "/home/phoebe/Dropbox/Stuff1819/proooject/diss/graphs"

# %%
command = "/home/phoebe/Dropbox/Stuff1819/proooject/Project/code/src/scripts/run_me_gc.sh"
testcase = "ack"

# %%
# top = 3000
# yr = range(15,1430,15)
# xr = range(4,380,4)

# def getResult():
#     result = []
#     for major in yr:
#         resa = []
#         for minor in xr:

#             run = subprocess.check_output([command, str(major)+"M", str(minor)+"M", testcase],
#                                           stderr=subprocess.STDOUT).decode('ascii')

#             f = float(run)
#             print(str(major)+","+str(minor))
#             print(f)
#             print()
#             resa += [f]
#         result += [resa]

#     print(result)
#     return result




# getResult()


# result = [[3.94, 2.73, 2.57, 3.28, 2.71, 2.78], 
#           [4.14, 2.71, 2.67, 2.66, 2.8, 2.87], 
#           [4.39, 2.74, 2.72, 2.83, 2.95, 2.88], 
#           [4.55, 3.2, 2.96, 3.36, 2.95, 2.92], 
#           [4.99, 3.02, 2.91, 2.89, 2.86, 2.92], 
#           [4.67, 2.97, 3.06, 3.14, 3.13, 3.2]]


# result = [[4.3, 2.67, 2.55, 2.64, 2.57, 2.84],
#  [3.86, 2.59, 2.73, 2.63, 2.64, 2.79],
#  [4.34, 2.58, 2.64, 2.78, 2.86, 2.83],
#  [3.98, 2.7, 3.05, 2.79, 2.86, 2.71],
#  [4.34, 2.81, 2.75, 2.66, 2.69, 2.71],
#  [4.15, 2.71, 2.78, 3.18, 3.25, 2.79],
#  [4.18, 3.01, 2.84, 2.88, 2.73, 2.71],
#  [4.23, 2.78, 2.83, 2.77, 2.95, 2.81],
#  [4.46, 2.81, 2.94, 2.95, 2.82, 3.0],
#  [4.44, 2.89, 2.74, 2.91, 2.76, 2.84],
#  [4.22, 2.9, 2.92, 2.78, 2.78, 2.94],
#  [4.39, 2.85, 2.88, 2.93, 2.9, 3.09],
#  [4.59, 3.1, 2.97, 2.76, 2.82, 3.02],
#  [4.68, 2.94, 3.35, 2.83, 3.33, 3.15],
#  [4.71, 3.18, 3.11, 2.92, 2.98, 3.08]]


# result = [[4.0, 3.13, 2.96, 2.67, 2.35, 2.55, 2.71, 2.53, 2.56, 2.57, 2.58, 2.51, 2.59, 2.57, 2.68, 2.56, 2.6, 2.63, 2.55, 2.64, 2.58, 2.55, 2.56, 2.48, 2.55, 2.41, 2.55, 2.54, 2.5, 2.59, 2.61, 2.63, 2.62, 2.49, 2.49, 2.56, 2.51, 2.53, 2.6, 2.53, 2.51, 2.53, 2.64, 2.6, 2.47, 2.55, 2.5, 2.52, 2.63, 2.48, 2.6, 2.65, 2.6, 2.55, 2.59, 2.54, 2.58, 2.62, 2.56, 2.52], [3.79, 3.03, 2.95, 2.58, 2.32, 2.51, 2.59, 2.53, 2.53, 2.57, 2.47, 2.51, 2.58, 2.54, 2.49, 2.48, 2.54, 2.51, 2.47, 2.47, 2.45, 2.55, 2.59, 2.56, 2.59, 2.46, 2.54, 2.55, 2.55, 2.52, 2.54, 2.57, 2.57, 2.52, 2.62, 2.48, 2.54, 2.61, 2.53, 2.57, 2.57, 2.63, 2.48, 2.54, 2.55, 2.56, 2.56, 2.54, 2.61, 2.62, 2.58, 2.61, 2.53, 2.55, 2.58, 2.61, 2.62, 2.57, 2.62, 2.48], [4.03, 3.19, 2.93, 2.72, 2.38, 2.56, 2.59, 2.52, 2.59, 2.62, 2.55, 2.56, 2.49, 2.59, 2.61, 2.62, 2.6, 2.52, 2.57, 2.59, 2.53, 2.65, 2.54, 2.66, 2.61, 2.61, 2.63, 2.62, 2.56, 2.6, 2.48, 2.52, 2.54, 2.54, 2.59, 2.7, 2.62, 2.54, 2.59, 2.57, 2.68, 2.54, 2.54, 2.67, 2.59, 2.61, 2.65, 2.57, 2.62, 2.51, 2.56, 2.53, 2.58, 2.59, 2.57, 2.53, 2.69, 2.51, 2.63, 2.62], [4.05, 3.19, 2.91, 2.59, 2.29, 2.61, 2.53, 2.56, 2.54, 2.54, 2.59, 2.55, 2.49, 2.57, 2.55, 2.71, 2.58, 2.52, 2.64, 2.6, 2.55, 2.54, 2.56, 2.54, 2.62, 2.51, 2.56, 2.48, 2.64, 2.48, 2.53, 2.58, 2.54, 2.51, 2.58, 2.65, 2.57, 2.63, 2.51, 2.6, 2.57, 2.58, 2.45, 2.57, 2.46, 2.54, 2.52, 2.62, 2.59, 2.53, 2.63, 2.59, 2.54, 2.54, 2.57, 2.58, 2.6, 2.59, 2.62, 2.6], [3.94, 3.14, 2.93, 2.67, 2.34, 2.59, 2.5, 2.54, 2.55, 2.48, 2.61, 2.59, 2.62, 2.61, 2.55, 2.61, 2.54, 2.58, 2.53, 2.63, 2.6, 2.59, 2.56, 2.56, 2.58, 2.6, 2.55, 2.55, 2.62, 2.5, 2.55, 2.61, 2.65, 2.59, 2.56, 2.59, 2.56, 2.58, 2.62, 2.59, 2.68, 2.54, 2.6, 2.59, 2.54, 2.52, 2.57, 2.58, 2.62, 2.61, 2.64, 2.56, 2.64, 2.59, 2.57, 2.62, 2.56, 2.61, 2.61, 2.59], [3.87, 3.16, 2.96, 2.71, 2.25, 2.49, 2.63, 2.66, 2.55, 2.6, 2.61, 2.56, 2.63, 2.53, 2.53, 2.59, 2.59, 2.62, 2.56, 2.52, 2.59, 2.64, 2.5, 2.61, 2.63, 2.58, 2.63, 2.48, 2.61, 2.6, 2.72, 2.67, 2.62, 2.57, 2.6, 2.55, 2.57, 2.59, 2.59, 2.55, 2.57, 2.62, 2.6, 2.7, 2.64, 2.65, 2.63, 2.63, 2.58, 2.57, 2.58, 2.65, 2.56, 2.64, 2.67, 2.69, 2.61, 2.61, 2.6, 2.55], [4.04, 3.2, 2.92, 2.65, 2.35, 2.5, 2.61, 2.52, 2.59, 2.62, 2.55, 2.53, 2.58, 2.6, 2.57, 2.59, 2.54, 2.61, 2.6, 2.61, 2.62, 2.6, 2.62, 2.54, 2.53, 2.6, 2.56, 2.57, 2.61, 2.52, 2.67, 2.7, 2.59, 2.65, 2.63, 2.7, 2.63, 2.58, 2.69, 2.59, 2.65, 2.55, 2.63, 2.57, 2.66, 2.6, 2.61, 2.69, 2.63, 2.56, 2.55, 2.62, 2.6, 2.45, 2.66, 2.65, 2.68, 2.59, 2.56, 2.64], [3.96, 3.19, 3.0, 2.65, 2.25, 2.61, 2.61, 2.66, 2.61, 2.59, 2.64, 2.67, 2.65, 2.54, 2.57, 2.5, 2.67, 2.64, 2.54, 2.66, 2.7, 2.55, 2.63, 2.58, 2.69, 2.61, 2.78, 2.65, 2.67, 2.59, 2.54, 2.6, 2.58, 2.65, 2.56, 2.57, 2.59, 2.64, 2.66, 2.62, 2.6, 2.65, 2.72, 2.73, 2.52, 2.68, 2.63, 2.58, 2.56, 2.59, 2.66, 2.59, 2.6, 2.59, 2.62, 2.6, 2.58, 2.62, 2.7, 2.59], [4.11, 3.57, 3.12, 2.93, 2.61, 2.78, 2.79, 2.77, 2.8, 2.67, 2.77, 2.73, 2.7, 2.69, 2.74, 2.63, 2.63, 2.76, 2.66, 2.65, 2.7, 2.64, 2.72, 2.61, 2.78, 2.65, 2.63, 2.77, 2.67, 2.83, 2.58, 2.62, 2.76, 2.65, 2.62, 2.71, 2.83, 2.59, 2.68, 2.71, 2.71, 2.7, 2.73, 2.72, 2.67, 2.71, 2.73, 2.69, 2.74, 2.72, 2.73, 2.72, 2.62, 2.69, 2.6, 2.73, 2.66, 2.7, 2.75, 2.73], [3.97, 3.29, 3.04, 2.77, 2.37, 2.7, 2.67, 2.7, 2.71, 2.69, 2.69, 2.68, 2.85, 2.92, 2.87, 2.91, 2.81, 2.66, 2.67, 2.75, 2.74, 2.81, 2.75, 2.73, 2.69, 2.75, 2.69, 2.72, 2.71, 2.58, 2.66, 2.73, 2.79, 2.63, 2.67, 2.76, 2.77, 2.73, 2.79, 2.68, 2.74, 2.62, 2.66, 2.62, 2.68, 2.75, 2.75, 2.67, 2.68, 2.72, 2.73, 2.68, 2.76, 2.66, 2.69, 2.73, 2.73, 2.7, 2.61, 2.65], [4.05, 3.2, 3.09, 2.78, 2.48, 2.67, 2.75, 2.66, 2.69, 2.72, 2.76, 2.72, 2.67, 2.63, 2.72, 2.68, 2.64, 2.69, 2.65, 2.77, 2.66, 2.72, 2.75, 2.8, 2.7, 2.7, 2.68, 2.71, 2.67, 2.64, 2.71, 2.78, 2.69, 2.69, 2.7, 2.65, 2.75, 2.75, 2.69, 2.69, 2.68, 2.75, 2.78, 2.69, 2.66, 2.77, 2.76, 2.69, 2.71, 2.78, 2.71, 2.72, 2.7, 2.71, 2.73, 2.73, 2.74, 2.69, 2.72, 2.74], [4.15, 3.29, 3.12, 2.8, 2.41, 2.72, 2.62, 2.67, 2.73, 2.74, 2.74, 2.69, 2.74, 2.73, 2.74, 2.77, 2.72, 2.72, 2.7, 2.82, 2.82, 2.74, 2.74, 2.71, 2.62, 2.72, 2.69, 2.7, 2.74, 2.78, 2.73, 2.69, 2.79, 2.8, 2.75, 2.7, 2.65, 2.76, 2.72, 2.76, 2.84, 2.73, 2.79, 2.74, 2.77, 2.7, 2.76, 2.72, 2.72, 2.73, 2.75, 2.71, 2.7, 2.71, 2.68, 2.7, 2.61, 2.73, 2.65, 2.69], [4.25, 3.23, 3.0, 2.74, 2.39, 2.62, 2.68, 2.79, 2.63, 2.68, 2.7, 2.67, 2.71, 2.68, 2.7, 2.71, 2.69, 2.69, 2.64, 2.72, 2.7, 2.74, 2.72, 2.75, 2.69, 2.74, 2.8, 2.76, 2.75, 2.61, 2.67, 2.73, 2.68, 2.64, 2.65, 2.65, 2.61, 2.67, 2.72, 2.76, 2.67, 2.66, 2.66, 2.78, 2.76, 2.7, 2.7, 2.7, 2.65, 2.66, 2.64, 2.65, 2.67, 2.69, 2.65, 2.66, 2.69, 2.7, 2.72, 2.73], [4.3, 3.26, 3.0, 2.77, 2.46, 2.67, 2.71, 2.77, 2.62, 2.62, 2.69, 2.68, 2.78, 2.76, 2.74, 2.76, 2.75, 2.72, 2.73, 2.72, 2.71, 2.69, 2.62, 2.73, 2.74, 2.6, 2.75, 2.72, 2.72, 2.74, 2.73, 2.77, 2.72, 2.63, 2.82, 2.73, 2.81, 2.72, 2.74, 2.67, 2.74, 2.67, 2.7, 2.77, 2.71, 2.73, 2.77, 2.74, 2.71, 2.74, 2.66, 2.62, 2.81, 2.71, 2.7, 2.73, 2.76, 2.77, 2.75, 2.76], [4.32, 3.08, 3.06, 2.68, 2.48, 2.68, 2.74, 2.68, 2.71, 2.78, 2.74, 2.68, 2.73, 2.8, 2.8, 2.82, 2.76, 2.68, 2.72, 2.7, 2.8, 2.8, 2.69, 2.71, 2.7, 2.76, 2.71, 2.69, 2.71, 2.78, 2.72, 2.78, 2.81, 2.79, 2.8, 2.59, 2.74, 2.68, 2.79, 2.72, 2.71, 2.74, 2.77, 2.73, 2.7, 2.7, 2.75, 2.73, 2.79, 2.75, 2.77, 2.8, 2.76, 2.71, 2.73, 2.73, 2.71, 2.78, 2.69, 2.71]]

# result = [[4.3, 3.66, 3.34, 3.03, 3.02, 2.86, 2.77, 2.84, 2.9, 2.6, 2.81, 2.73, 2.53, 2.57, 2.51, 2.6, 2.53, 2.59, 2.51, 2.56, 2.53, 2.48, 2.78, 2.6, 2.59, 2.55, 2.66, 2.5, 2.63, 2.52, 2.57, 2.53, 2.59, 2.49, 2.59, 2.56, 2.56, 2.54, 2.89, 2.6], [3.79, 3.46, 3.19, 3.17, 2.99, 3.0, 2.79, 2.81, 2.56, 2.63, 2.41, 2.43, 2.58, 2.54, 2.68, 2.68, 2.84, 2.78, 2.53, 2.59, 2.64, 2.68, 2.63, 2.59, 2.64, 2.84, 2.66, 2.74, 2.63, 2.58, 2.59, 2.56, 2.56, 2.53, 2.59, 2.53, 2.62, 2.54, 2.55, 2.53], [3.98, 3.36, 3.08, 3.05, 2.83, 2.94, 2.95, 2.79, 2.81, 2.61, 2.39, 2.39, 2.5, 2.63, 2.52, 2.55, 2.59, 2.63, 2.64, 2.65, 2.61, 2.62, 2.57, 2.64, 2.74, 2.6, 2.83, 2.87, 2.74, 2.72, 2.85, 2.82, 2.76, 2.69, 2.64, 2.57, 2.56, 2.62, 2.52, 2.59], [3.96, 3.42, 3.28, 3.08, 2.79, 2.92, 2.94, 2.86, 2.77, 2.64, 2.35, 2.44, 2.45, 2.65, 2.63, 2.67, 2.6, 2.61, 2.6, 2.52, 2.57, 2.65, 2.65, 2.64, 2.7, 2.64, 2.67, 2.83, 2.61, 2.62, 2.58, 2.55, 2.67, 2.64, 2.55, 2.6, 2.76, 2.68, 2.68, 2.61], [3.96, 3.44, 3.21, 3.09, 2.85, 3.1, 2.99, 2.83, 2.78, 2.73, 2.39, 2.43, 2.54, 2.65, 2.58, 2.68, 2.67, 2.62, 2.54, 2.57, 2.66, 2.64, 2.62, 2.57, 2.62, 2.64, 2.66, 2.52, 2.65, 2.56, 2.58, 2.65, 2.67, 2.61, 2.59, 2.59, 2.51, 2.62, 2.59, 2.69], [3.89, 3.39, 3.21, 3.08, 2.85, 2.91, 2.97, 2.84, 2.78, 2.67, 2.34, 2.38, 2.59, 2.57, 2.64, 2.64, 2.64, 2.62, 2.66, 2.62, 2.56, 2.69, 2.61, 2.55, 2.67, 2.58, 2.56, 2.6, 2.66, 2.58, 2.61, 2.68, 2.58, 2.64, 2.61, 2.57, 2.59, 2.61, 2.62, 2.68], [3.94, 5.51, 3.23, 3.1, 2.93, 3.01, 2.87, 2.86, 2.75, 2.66, 2.32, 2.44, 2.55, 2.61, 2.65, 2.68, 2.67, 2.59, 2.66, 2.62, 2.67, 2.65, 2.72, 2.67, 2.65, 2.66, 2.58, 2.63, 2.67, 2.63, 2.7, 2.58, 2.61, 2.62, 2.6, 2.63, 2.53, 2.61, 2.66, 2.62], [4.01, 5.61, 3.24, 3.04, 2.95, 2.96, 2.93, 2.8, 2.85, 2.81, 2.39, 2.47, 2.55, 2.67, 2.7, 2.65, 2.69, 2.71, 2.72, 2.72, 2.69, 2.62, 2.7, 2.65, 2.64, 2.71, 2.74, 2.7, 2.66, 2.67, 2.66, 2.59, 2.63, 2.66, 2.71, 2.69, 2.63, 2.64, 2.64, 2.6], [4.06, 5.57, 3.22, 3.04, 2.94, 2.96, 2.96, 2.9, 2.84, 2.7, 2.34, 2.6, 2.71, 2.63, 2.76, 2.72, 2.65, 2.51, 2.53, 2.52, 2.73, 2.8, 2.81, 2.8, 2.69, 2.68, 2.61, 2.87, 2.8, 2.75, 2.74, 2.68, 2.64, 2.73, 2.68, 2.67, 2.64, 2.68, 2.69, 2.84], [4.31, 5.92, 3.71, 3.11, 3.05, 3.34, 3.31, 3.19, 3.03, 2.78, 2.47, 2.75, 2.84, 2.72, 2.75, 2.96, 2.73, 2.73, 2.7, 2.75, 2.96, 3.71, 3.41, 3.09, 3.21, 2.96, 2.81, 2.92, 3.04, 2.97, 2.73, 2.65, 3.16, 3.4, 3.21, 3.19, 3.21, 3.19, 2.81, 3.09], [4.59, 6.43, 3.55, 3.44, 3.28, 3.87, 3.37, 3.87, 3.35, 3.1, 2.66, 2.75, 2.76, 2.92, 3.16, 3.31, 2.8, 3.06, 3.23, 3.39, 3.12, 3.05, 2.96, 2.96, 3.03, 2.96, 3.02, 3.07, 3.08, 3.0, 3.07, 3.12, 3.03, 2.93, 3.39, 2.94, 3.14, 3.09, 3.6, 2.79], [4.29, 5.61, 3.28, 3.32, 3.08, 3.21, 3.23, 3.1, 2.96, 2.94, 2.5, 2.56, 2.67, 2.94, 2.91, 3.06, 2.97, 2.91, 3.06, 3.18, 2.95, 2.84, 2.85, 2.86, 2.78, 2.74, 3.23, 2.84, 2.9, 2.99, 2.74, 2.94, 2.93, 3.23, 3.1, 3.09, 3.5, 3.03, 3.15, 3.07], [5.11, 6.44, 3.66, 3.54, 3.42, 3.8, 3.31, 3.53, 3.61, 3.14, 2.61, 2.84, 2.88, 3.51, 3.03, 3.1, 3.19, 3.21, 3.22, 2.75, 3.01, 2.87, 3.05, 3.1, 3.09, 2.9, 2.96, 2.97, 2.92, 3.1, 3.08, 3.09, 3.14, 2.92, 2.88, 2.9, 2.83, 2.95, 2.98, 3.06], [4.45, 5.96, 3.39, 3.34, 3.34, 3.13, 3.09, 2.98, 2.96, 2.86, 2.9, 2.56, 2.72, 2.8, 3.11, 2.83, 2.83, 2.96, 2.9, 3.03, 3.01, 3.0, 2.94, 3.03, 3.24, 3.2, 3.34, 3.08, 3.18, 3.02, 2.91, 2.96, 3.02, 3.04, 2.89, 3.05, 3.05, 3.01, 3.03, 3.03], [4.92, 6.58, 3.86, 3.36, 3.07, 3.36, 3.21, 3.11, 3.14, 3.1, 2.99, 2.86, 2.98, 3.05, 2.85, 2.83, 2.89, 2.83, 2.82, 2.79, 2.81, 2.84, 2.77, 2.8, 2.82, 2.74, 2.74, 2.72, 2.9, 2.93, 2.84, 2.81, 2.87, 3.11, 3.05, 2.83, 6.66, 2.8, 2.83, 2.77]]

# result = [[3.34, 3.01, 2.61, 2.53, 2.39],
#  [2.95, 2.82, 2.66, 2.55, 2.68],
#  [3.08, 2.93, 2.59, 2.46, 2.62],
#  [3.04, 2.94, 2.65, 2.61, 2.56],
#  [3.08, 2.97, 2.63, 2.58, 2.66],
#  [3.07, 3.07, 2.71, 2.7, 2.68]]



# res = getResult()
# print(res)

# %%
yr = range(15,1430,15)
xr = range(4,380,4)

result = [[3.99, 3.61, 3.41, 3.36, 3.3, 3.29, 3.14, 3.19, 3.23, 3.23, 3.2, 3.17, 3.37, 3.11, 2.97, 2.9, 2.79, 2.74, 2.72, 2.73, 2.68, 2.74, 2.69, 2.64, 2.66, 2.67, 2.45, 2.52, 2.6, 2.69, 2.72, 2.69, 2.48, 2.55, 2.57, 2.65, 2.49, 2.57, 2.57, 2.65, 2.78, 2.4, 2.37, 2.42, 2.44, 2.5, 2.52, 2.5, 2.39, 2.48, 2.48, 2.43, 2.5, 2.79, 2.65, 2.41, 2.71, 2.64, 2.33, 2.25, 2.29, 2.3, 2.35, 2.32, 2.56, 2.38, 2.43, 2.4, 2.43, 2.41, 2.42, 2.39, 2.39, 2.39, 2.3, 2.47, 2.35, 2.41, 2.41, 2.46, 2.38, 2.37, 2.36, 2.35, 2.36, 2.36, 2.45, 2.37, 2.43, 2.37, 2.46, 2.48, 2.46, 2.4], [3.52, 3.54, 3.42, 3.25, 3.28, 3.12, 3.07, 3.18, 3.05, 3.01, 2.9, 2.93, 2.96, 2.97, 2.93, 2.92, 2.96, 2.69, 2.8, 2.67, 2.63, 2.75, 2.61, 2.6, 2.67, 2.82, 2.64, 2.6, 2.71, 2.64, 2.6, 2.73, 2.39, 2.63, 2.49, 2.5, 2.57, 2.55, 2.72, 2.65, 2.73, 2.41, 2.33, 2.42, 2.45, 2.54, 2.43, 2.47, 2.36, 2.41, 2.54, 2.48, 2.43, 2.54, 2.56, 2.51, 2.63, 2.63, 2.32, 2.32, 2.41, 2.32, 2.4, 2.33, 2.35, 2.39, 2.36, 2.47, 2.42, 2.31, 2.51, 2.51, 2.35, 2.45, 2.48, 2.45, 2.41, 2.29, 2.3, 2.38, 2.38, 2.45, 2.41, 2.65, 2.49, 2.27, 2.36, 2.39, 2.42, 2.41, 2.45, 2.37, 2.38, 2.5], [3.56, 3.58, 3.34, 3.31, 3.34, 3.11, 3.11, 3.13, 2.97, 2.99, 2.97, 2.93, 2.89, 2.9, 2.88, 2.91, 2.69, 2.82, 2.68, 2.66, 2.66, 2.77, 2.69, 2.72, 2.79, 2.78, 2.6, 2.68, 2.81, 2.64, 2.65, 2.68, 2.54, 2.58, 2.51, 2.54, 2.53, 2.53, 2.48, 2.47, 2.57, 2.48, 2.47, 2.53, 2.48, 2.54, 2.57, 2.56, 2.17, 2.17, 2.21, 2.29, 2.3, 2.35, 2.55, 2.54, 2.64, 2.64, 2.44, 2.45, 2.43, 2.57, 2.35, 2.51, 2.4, 2.39, 2.66, 2.42, 2.43, 2.47, 2.34, 2.43, 2.4, 2.54, 2.44, 2.38, 2.28, 2.35, 2.29, 2.46, 2.36, 2.39, 2.4, 2.4, 2.35, 2.45, 2.42, 2.52, 2.44, 2.4, 2.4, 2.34, 2.36, 2.42], [3.46, 3.37, 3.41, 3.2, 3.29, 3.08, 3.09, 3.13, 2.95, 2.99, 2.9, 2.93, 2.95, 2.95, 2.98, 2.97, 2.82, 2.86, 2.78, 2.64, 2.77, 2.72, 2.61, 2.7, 2.71, 2.64, 2.65, 2.71, 2.69, 2.6, 2.63, 2.69, 2.41, 2.56, 2.44, 2.51, 2.43, 2.53, 2.55, 2.57, 2.59, 2.39, 2.45, 2.44, 2.52, 2.45, 2.48, 2.51, 2.15, 2.18, 2.19, 2.16, 2.26, 2.19, 2.29, 2.38, 2.27, 2.29, 2.29, 2.3, 2.25, 2.37, 2.43, 2.43, 2.41, 2.39, 2.42, 2.43, 2.44, 2.43, 2.32, 2.39, 2.41, 2.39, 2.39, 2.3, 2.37, 2.4, 2.34, 2.29, 2.38, 2.39, 2.43, 2.4, 2.5, 2.47, 2.32, 2.36, 2.36, 2.43, 2.36, 2.36, 2.38, 2.42], [3.43, 3.42, 3.26, 3.22, 3.22, 3.02, 3.24, 3.12, 3.0, 3.05, 3.0, 3.03, 2.96, 2.96, 2.94, 2.86, 2.81, 2.83, 2.72, 2.68, 2.62, 2.71, 2.59, 2.64, 2.69, 2.71, 2.61, 2.66, 2.75, 2.62, 2.68, 2.58, 2.5, 2.43, 2.49, 2.63, 2.52, 2.53, 2.47, 2.6, 2.6, 2.48, 2.37, 2.47, 2.52, 2.5, 2.56, 2.6, 2.19, 2.22, 2.21, 2.22, 2.24, 2.3, 2.27, 2.28, 2.27, 2.29, 2.28, 2.35, 2.32, 2.34, 2.34, 2.32, 2.38, 2.38, 2.43, 2.41, 2.29, 2.31, 2.43, 2.37, 2.41, 2.37, 2.38, 2.41, 2.4, 2.32, 2.4, 2.36, 2.4, 2.29, 2.36, 2.36, 2.38, 2.37, 2.39, 2.36, 2.34, 2.38, 2.27, 2.34, 2.31, 2.4], [3.46, 3.4, 3.28, 3.23, 3.18, 3.0, 3.12, 3.07, 2.91, 2.94, 2.86, 2.91, 2.91, 2.88, 2.85, 2.67, 2.84, 2.8, 2.72, 2.6, 2.59, 2.74, 2.58, 2.63, 2.69, 2.75, 2.53, 2.63, 2.69, 2.59, 2.61, 2.55, 2.42, 2.47, 2.53, 2.54, 2.38, 2.45, 2.47, 2.51, 2.34, 2.33, 2.38, 2.41, 2.41, 2.43, 2.47, 2.56, 2.12, 2.13, 2.14, 2.21, 2.22, 2.27, 2.28, 2.22, 2.27, 2.37, 2.29, 2.31, 2.36, 2.34, 2.31, 2.33, 2.3, 2.36, 2.38, 2.3, 2.26, 2.33, 2.44, 2.38, 2.28, 2.3, 2.36, 2.29, 2.32, 2.4, 2.41, 2.37, 2.48, 2.37, 2.37, 2.3, 2.34, 2.46, 2.36, 2.35, 2.28, 2.28, 2.29, 2.36, 2.37, 2.38], [3.84, 3.38, 3.23, 3.13, 3.04, 3.03, 3.13, 2.96, 2.93, 2.94, 3.01, 2.93, 2.95, 2.8, 2.84, 2.71, 2.77, 2.75, 2.7, 2.61, 2.64, 2.74, 2.51, 2.63, 2.73, 2.78, 2.57, 2.61, 2.69, 2.6, 2.6, 2.66, 2.51, 2.53, 2.54, 2.55, 2.28, 2.5, 2.37, 2.35, 2.6, 2.36, 2.47, 2.42, 2.45, 2.61, 2.53, 2.6, 2.19, 2.23, 2.23, 2.21, 2.27, 2.21, 2.23, 2.23, 2.23, 2.34, 2.28, 2.28, 2.24, 2.3, 2.34, 2.37, 2.39, 2.35, 2.32, 2.37, 2.38, 2.35, 2.34, 2.41, 2.36, 2.42, 2.38, 2.41, 2.36, 2.35, 2.33, 2.34, 2.34, 2.31, 2.34, 2.38, 2.37, 2.32, 2.29, 2.43, 2.38, 2.34, 2.32, 2.34, 2.35, 2.33], [3.9, 3.46, 3.31, 3.24, 3.07, 3.05, 3.04, 2.95, 2.96, 2.86, 2.84, 2.91, 2.87, 2.71, 2.86, 2.84, 2.78, 2.78, 2.76, 2.66, 2.67, 2.74, 2.51, 2.62, 2.66, 2.73, 2.62, 2.57, 2.67, 2.63, 2.65, 2.71, 2.48, 2.49, 2.46, 2.56, 2.53, 2.5, 2.56, 2.52, 2.54, 2.38, 2.39, 2.4, 2.41, 2.44, 2.47, 2.48, 2.1, 2.1, 2.11, 2.18, 2.12, 2.14, 2.19, 2.22, 2.2, 2.28, 2.24, 2.27, 2.34, 2.32, 2.28, 2.41, 2.41, 2.28, 2.34, 2.28, 2.44, 2.31, 2.35, 2.32, 2.41, 2.36, 2.36, 2.38, 2.31, 2.38, 2.37, 2.38, 2.32, 2.44, 2.35, 2.44, 2.37, 2.41, 2.35, 2.39, 2.35, 2.38, 2.38, 2.32, 2.37, 2.37], [3.83, 3.4, 3.29, 3.16, 3.05, 3.03, 3.13, 2.98, 3.01, 2.92, 2.94, 2.98, 2.88, 2.71, 2.77, 2.76, 2.76, 2.77, 2.65, 2.6, 2.67, 2.74, 2.55, 2.53, 2.6, 2.69, 2.59, 2.63, 2.68, 2.64, 2.73, 2.73, 2.46, 2.47, 2.56, 2.61, 2.44, 2.48, 2.49, 2.54, 2.61, 2.35, 2.36, 2.35, 2.43, 2.46, 2.46, 2.51, 2.14, 2.23, 2.15, 2.16, 2.31, 2.23, 2.27, 2.34, 2.25, 2.28, 2.26, 2.26, 2.32, 2.26, 2.38, 2.36, 2.32, 2.31, 2.36, 2.35, 2.24, 2.32, 2.33, 2.37, 2.27, 2.37, 2.35, 2.37, 2.39, 2.39, 2.48, 2.38, 2.34, 2.28, 2.27, 2.33, 2.42, 2.34, 2.29, 2.43, 2.3, 2.33, 2.43, 2.46, 2.34, 2.41], [3.8, 3.39, 3.31, 3.25, 3.07, 3.07, 3.1, 2.95, 2.91, 2.84, 2.88, 2.87, 2.91, 2.72, 2.74, 2.68, 2.76, 2.7, 2.69, 2.51, 2.65, 2.7, 2.52, 2.62, 2.66, 2.78, 2.56, 2.7, 2.64, 2.64, 2.7, 2.7, 2.46, 2.52, 2.59, 2.6, 2.42, 2.44, 2.48, 2.46, 2.62, 2.32, 2.38, 2.38, 2.42, 2.44, 2.5, 2.42, 2.13, 2.12, 2.15, 2.19, 2.35, 2.38, 2.59, 2.25, 2.31, 2.32, 2.29, 2.29, 2.37, 2.35, 2.29, 2.34, 2.45, 2.42, 2.43, 2.41, 2.35, 2.34, 2.47, 2.4, 2.46, 2.41, 2.42, 2.47, 2.35, 2.34, 2.39, 2.44, 2.39, 2.33, 2.39, 2.4, 2.4, 2.33, 2.51, 2.45, 2.4, 2.37, 2.38, 2.49, 2.44, 2.48], [3.91, 3.43, 3.38, 3.28, 3.09, 2.98, 3.16, 2.99, 2.96, 2.9, 2.88, 3.02, 2.96, 2.76, 2.77, 2.85, 2.81, 2.76, 2.76, 2.64, 2.71, 2.77, 2.63, 2.67, 2.72, 2.82, 2.64, 2.62, 2.67, 2.66, 2.75, 2.77, 2.5, 2.55, 2.62, 2.66, 2.5, 2.52, 2.5, 2.62, 2.55, 2.37, 2.45, 2.48, 2.45, 2.51, 2.54, 2.56, 2.11, 2.15, 2.17, 2.13, 2.21, 2.24, 2.23, 2.22, 2.28, 2.26, 2.37, 2.35, 2.33, 2.39, 2.4, 2.42, 2.42, 2.39, 2.36, 2.28, 2.37, 2.45, 2.47, 2.39, 2.36, 2.4, 2.35, 2.37, 2.38, 2.37, 2.32, 2.37, 2.37, 2.44, 2.45, 2.47, 2.37, 2.43, 2.39, 2.41, 2.39, 2.36, 2.39, 2.38, 2.43, 2.39], [3.92, 3.4, 3.27, 3.16, 3.1, 3.04, 3.13, 3.02, 3.02, 2.95, 2.97, 2.97, 2.99, 2.81, 2.82, 2.73, 2.76, 2.65, 2.66, 2.5, 2.68, 2.78, 2.59, 2.66, 2.66, 2.85, 2.59, 2.64, 2.69, 2.77, 2.77, 2.71, 2.56, 2.55, 2.6, 2.71, 2.51, 2.52, 2.49, 2.54, 2.55, 2.4, 2.4, 2.45, 2.44, 2.5, 2.53, 2.56, 2.08, 2.21, 2.2, 2.29, 2.14, 2.25, 2.28, 2.21, 2.21, 2.21, 2.3, 2.26, 2.27, 2.38, 2.35, 2.36, 2.37, 2.43, 2.33, 2.36, 2.33, 2.29, 2.27, 2.43, 2.45, 2.37, 2.29, 2.36, 2.42, 2.38, 2.41, 2.32, 2.36, 2.36, 2.39, 2.36, 2.37, 2.4, 2.41, 2.39, 2.34, 2.34, 2.37, 2.37, 2.35, 2.36], [3.86, 3.41, 3.35, 3.22, 3.17, 3.01, 3.09, 2.98, 2.94, 2.86, 2.89, 2.92, 2.91, 2.75, 2.77, 2.76, 2.74, 2.66, 2.66, 2.65, 2.68, 2.76, 2.53, 2.65, 2.73, 2.71, 2.57, 2.57, 2.62, 2.63, 2.76, 2.7, 2.48, 2.53, 2.55, 2.5, 2.5, 2.39, 2.57, 2.58, 2.59, 2.36, 2.35, 2.45, 2.45, 2.45, 2.47, 2.5, 2.05, 2.18, 2.11, 2.2, 2.12, 2.23, 2.14, 2.26, 2.25, 2.31, 2.28, 2.4, 2.25, 2.31, 2.36, 2.34, 2.35, 2.43, 2.4, 2.44, 2.34, 2.41, 2.32, 2.31, 2.36, 2.39, 2.31, 2.44, 2.35, 2.35, 2.28, 2.45, 2.34, 2.33, 2.38, 2.38, 2.38, 2.32, 2.34, 2.41, 2.38, 2.4, 2.33, 2.41, 2.45, 2.4], [3.86, 4.2, 3.27, 3.23, 3.1, 3.09, 3.03, 2.97, 2.88, 2.87, 2.84, 2.95, 2.93, 2.8, 2.77, 2.79, 2.8, 2.78, 2.72, 2.56, 2.71, 2.72, 2.55, 2.66, 2.71, 2.76, 2.5, 2.56, 2.71, 2.63, 2.68, 2.75, 2.47, 2.57, 2.61, 2.62, 2.41, 2.47, 2.49, 2.57, 2.56, 2.35, 2.37, 2.37, 2.43, 2.43, 2.47, 2.48, 2.11, 2.16, 2.18, 2.1, 2.19, 2.22, 2.27, 2.23, 2.27, 2.3, 2.26, 2.31, 2.26, 2.32, 2.3, 2.33, 2.31, 2.3, 2.33, 2.31, 2.36, 2.35, 2.37, 2.39, 2.42, 2.37, 2.3, 2.35, 2.3, 2.4, 2.38, 2.34, 2.43, 2.38, 2.35, 2.4, 2.3, 2.36, 2.4, 2.38, 2.33, 2.4, 2.37, 2.33, 2.42, 2.37], [3.8, 4.1, 3.25, 3.15, 3.09, 3.07, 3.15, 3.08, 2.97, 2.92, 2.91, 2.97, 2.9, 2.73, 2.76, 2.75, 2.78, 2.68, 2.74, 2.53, 2.69, 2.68, 2.55, 2.58, 2.75, 2.83, 2.62, 2.65, 2.73, 2.65, 2.74, 2.67, 2.45, 2.58, 2.58, 2.51, 2.51, 2.46, 2.52, 2.51, 2.69, 2.37, 2.28, 2.4, 2.42, 2.51, 2.48, 2.48, 2.08, 2.09, 2.13, 2.19, 2.2, 2.27, 2.2, 2.23, 2.26, 2.27, 2.23, 2.27, 2.36, 2.29, 2.37, 2.39, 2.47, 2.4, 2.3, 2.36, 2.27, 2.34, 2.42, 2.41, 2.46, 2.38, 2.36, 2.44, 2.41, 2.4, 2.39, 2.33, 2.35, 2.35, 2.39, 2.39, 2.34, 2.36, 2.45, 2.32, 2.38, 2.4, 2.32, 2.39, 2.45, 2.42], [3.97, 4.22, 3.29, 3.18, 3.08, 3.02, 3.15, 3.0, 2.86, 2.9, 2.89, 2.93, 2.97, 2.78, 2.73, 2.73, 2.71, 2.74, 2.66, 2.58, 2.65, 2.78, 2.58, 2.67, 2.68, 2.74, 2.59, 2.59, 2.69, 2.7, 2.65, 2.68, 2.51, 2.57, 2.67, 2.56, 2.5, 2.45, 2.51, 2.55, 2.66, 2.41, 2.33, 2.44, 2.41, 2.44, 2.47, 2.47, 2.07, 2.11, 2.06, 2.09, 2.18, 2.24, 2.18, 2.23, 2.24, 2.31, 2.27, 2.36, 2.38, 2.24, 2.34, 2.4, 2.41, 2.36, 2.34, 2.4, 2.39, 2.38, 2.39, 2.37, 2.43, 2.42, 2.35, 2.38, 2.4, 2.4, 2.37, 2.4, 2.41, 2.43, 2.34, 2.33, 2.35, 2.36, 2.42, 2.34, 2.35, 2.41, 2.44, 2.41, 2.4, 2.36], [3.83, 4.16, 3.26, 3.22, 3.09, 3.06, 3.05, 3.01, 2.93, 2.87, 2.87, 2.96, 2.89, 2.8, 2.74, 2.8, 2.83, 2.81, 2.73, 2.59, 2.71, 2.73, 2.57, 2.59, 2.73, 2.73, 2.53, 2.65, 2.66, 2.64, 2.67, 2.8, 2.54, 2.5, 2.57, 2.67, 2.46, 2.46, 2.52, 2.55, 2.57, 2.33, 2.39, 2.36, 2.38, 2.43, 2.48, 2.51, 2.11, 2.17, 2.07, 2.11, 2.12, 2.2, 2.21, 2.21, 2.18, 2.38, 2.25, 2.32, 2.36, 2.43, 2.38, 2.44, 2.36, 2.41, 2.37, 2.38, 2.38, 2.39, 2.33, 2.37, 2.34, 2.38, 2.37, 2.33, 2.37, 2.31, 2.39, 2.42, 2.39, 2.4, 2.37, 2.45, 2.43, 2.33, 2.4, 2.32, 2.4, 2.26, 2.31, 2.35, 2.36, 2.42], [3.86, 4.13, 3.27, 3.29, 3.16, 3.07, 3.16, 3.05, 2.92, 2.85, 2.9, 2.9, 2.86, 2.79, 2.69, 2.76, 2.8, 2.7, 2.66, 2.59, 2.65, 2.69, 2.57, 2.63, 2.77, 2.73, 2.62, 2.68, 2.7, 2.75, 2.67, 2.73, 2.54, 2.5, 2.6, 2.66, 2.38, 2.52, 2.5, 2.52, 2.62, 2.36, 2.4, 2.42, 2.43, 2.42, 2.5, 2.57, 2.12, 2.17, 2.18, 2.17, 2.14, 2.15, 2.18, 2.2, 2.26, 2.29, 2.25, 2.23, 2.36, 2.33, 2.3, 2.35, 2.34, 2.41, 2.35, 2.41, 2.44, 2.37, 2.44, 2.44, 2.43, 2.45, 2.41, 2.4, 2.35, 2.4, 2.39, 2.37, 2.4, 2.29, 2.41, 2.37, 2.39, 2.39, 2.35, 2.43, 2.4, 2.41, 2.43, 2.43, 2.41, 2.39], [3.88, 4.16, 3.26, 3.21, 3.11, 3.04, 3.08, 2.99, 2.88, 2.84, 2.86, 2.96, 2.92, 2.8, 2.81, 2.79, 2.75, 2.72, 2.66, 2.61, 2.65, 2.7, 2.6, 2.65, 2.7, 2.75, 2.62, 2.65, 2.64, 2.67, 2.72, 2.71, 2.42, 2.52, 2.64, 2.7, 2.44, 2.51, 2.53, 2.6, 2.57, 2.36, 2.37, 2.47, 2.47, 2.54, 2.47, 2.49, 2.08, 2.12, 2.09, 2.25, 2.17, 2.25, 2.22, 2.22, 2.29, 2.35, 2.33, 2.32, 2.38, 2.28, 2.4, 2.3, 2.33, 2.32, 2.42, 2.4, 2.33, 2.39, 2.38, 2.42, 2.41, 2.38, 2.36, 2.36, 2.3, 2.36, 2.39, 2.44, 2.45, 2.4, 2.43, 2.49, 2.37, 2.38, 2.36, 2.32, 2.38, 2.43, 2.4, 2.31, 2.45, 2.37], [3.88, 4.15, 3.28, 3.18, 3.14, 3.07, 3.18, 3.08, 2.92, 2.84, 2.9, 2.97, 2.91, 2.76, 2.7, 2.76, 2.77, 2.7, 2.68, 2.54, 2.63, 2.72, 2.5, 2.69, 2.73, 2.78, 2.69, 2.7, 2.71, 2.71, 2.67, 2.83, 2.51, 2.57, 2.51, 2.54, 2.44, 2.49, 2.43, 2.52, 2.59, 2.32, 2.38, 2.39, 2.44, 2.43, 2.53, 2.6, 2.16, 2.09, 2.21, 2.22, 2.2, 2.22, 2.21, 2.29, 2.29, 2.3, 2.38, 2.24, 2.25, 2.36, 2.37, 2.42, 2.39, 2.39, 2.36, 2.36, 2.4, 2.35, 2.45, 2.4, 2.42, 2.33, 2.4, 2.41, 2.34, 2.49, 2.37, 2.3, 2.31, 2.46, 2.37, 2.36, 2.41, 2.32, 2.41, 2.39, 2.33, 2.4, 2.36, 2.39, 2.45, 2.37], [3.95, 4.25, 4.44, 3.19, 3.08, 3.08, 3.1, 3.0, 2.91, 2.96, 2.84, 2.99, 2.87, 2.72, 2.78, 2.79, 2.8, 2.78, 2.71, 2.63, 2.66, 2.73, 2.63, 2.68, 2.69, 2.75, 2.59, 2.65, 2.68, 2.64, 2.75, 2.8, 2.51, 2.49, 2.59, 2.6, 2.47, 2.5, 2.52, 2.56, 2.64, 2.43, 2.39, 2.41, 2.43, 2.42, 2.45, 2.48, 2.12, 2.16, 2.19, 2.14, 2.25, 2.25, 2.23, 2.29, 2.26, 2.28, 2.32, 2.34, 2.32, 2.42, 2.46, 2.4, 2.38, 2.39, 2.37, 2.43, 2.34, 2.4, 2.41, 2.37, 2.48, 2.37, 2.37, 2.35, 2.43, 2.37, 2.29, 2.36, 2.4, 2.36, 2.32, 2.34, 2.41, 2.37, 2.43, 2.47, 2.43, 2.36, 2.34, 2.41, 2.38, 2.36], [3.85, 4.19, 4.51, 3.25, 3.13, 3.12, 3.16, 3.01, 2.91, 2.92, 2.88, 2.99, 2.96, 2.77, 2.77, 2.72, 2.76, 2.69, 2.61, 2.6, 2.67, 2.66, 2.61, 2.65, 2.75, 2.8, 2.61, 2.69, 2.75, 2.65, 2.68, 2.69, 2.49, 2.57, 2.6, 2.59, 2.42, 2.5, 2.54, 2.57, 2.58, 2.38, 2.37, 2.34, 2.53, 2.47, 2.53, 2.61, 2.06, 2.25, 2.16, 2.16, 2.21, 2.21, 2.26, 2.29, 2.22, 2.27, 2.33, 2.35, 2.36, 2.35, 2.34, 2.32, 2.47, 2.39, 2.41, 2.43, 2.41, 2.39, 2.41, 2.45, 2.37, 2.34, 2.41, 2.37, 2.35, 2.39, 2.41, 2.37, 2.36, 2.33, 2.4, 2.35, 2.36, 2.38, 2.39, 2.42, 2.43, 2.31, 2.42, 2.39, 2.4, 2.41], [3.88, 4.22, 4.45, 3.15, 3.09, 2.99, 3.1, 3.08, 2.99, 2.86, 2.98, 2.96, 2.92, 2.71, 2.74, 2.74, 2.78, 2.73, 2.71, 2.64, 2.67, 2.69, 2.61, 2.69, 2.74, 2.78, 2.61, 2.65, 2.71, 2.67, 2.72, 2.77, 2.52, 2.59, 2.56, 2.54, 2.38, 2.37, 2.59, 2.63, 2.65, 2.35, 2.4, 2.42, 2.44, 2.47, 2.46, 2.45, 2.14, 2.12, 2.12, 2.21, 2.26, 2.22, 2.24, 2.22, 2.24, 2.32, 2.33, 2.35, 2.34, 2.42, 2.37, 2.34, 2.4, 2.4, 2.39, 2.39, 2.45, 2.38, 2.38, 2.33, 2.39, 2.33, 2.4, 2.37, 2.37, 2.42, 2.43, 2.31, 2.34, 2.46, 2.37, 2.4, 2.48, 2.43, 2.44, 2.4, 2.43, 2.34, 2.47, 2.42, 2.37, 2.38], [3.86, 4.15, 4.5, 3.24, 3.1, 3.08, 3.04, 3.04, 2.92, 2.89, 2.9, 3.05, 2.96, 2.73, 2.76, 2.75, 2.76, 2.66, 2.63, 2.57, 2.68, 2.73, 2.61, 2.59, 2.73, 2.76, 2.6, 2.66, 2.72, 2.65, 2.74, 2.84, 2.5, 2.57, 2.62, 2.69, 2.53, 2.56, 2.64, 2.54, 2.6, 2.36, 2.47, 2.35, 2.5, 2.46, 2.45, 2.51, 2.17, 2.12, 2.21, 2.13, 2.21, 2.23, 2.31, 2.28, 2.29, 2.34, 2.33, 2.34, 2.33, 2.32, 2.38, 2.39, 2.56, 2.38, 2.43, 2.38, 2.42, 2.37, 2.39, 2.41, 2.3, 2.36, 2.46, 2.43, 2.36, 2.46, 2.41, 2.32, 2.42, 2.4, 2.34, 2.43, 2.42, 2.34, 2.38, 2.37, 2.45, 2.33, 2.38, 2.34, 2.51, 2.32], [3.87, 4.18, 4.41, 3.24, 3.14, 3.09, 3.19, 3.08, 2.96, 2.88, 2.84, 2.92, 2.9, 2.77, 2.7, 2.77, 2.72, 2.74, 2.65, 2.64, 2.68, 2.66, 2.59, 2.63, 2.72, 2.87, 2.56, 2.68, 2.78, 2.68, 2.74, 2.73, 2.5, 2.55, 2.65, 2.64, 2.49, 2.52, 2.56, 2.53, 2.64, 2.32, 2.41, 2.38, 2.55, 2.46, 2.43, 2.51, 2.15, 2.14, 2.18, 2.18, 2.28, 2.17, 2.23, 2.3, 2.28, 2.34, 2.37, 2.3, 2.37, 2.32, 2.39, 2.36, 2.4, 2.39, 2.38, 2.36, 2.34, 2.37, 2.31, 2.47, 2.36, 2.42, 2.46, 2.39, 2.46, 2.4, 2.41, 2.4, 2.37, 2.46, 2.42, 2.4, 2.41, 2.35, 2.42, 2.39, 2.37, 2.4, 2.38, 2.35, 2.37, 2.46], [3.94, 4.22, 4.52, 3.31, 3.11, 3.03, 3.11, 2.97, 2.95, 2.9, 2.88, 2.97, 2.92, 2.74, 2.71, 2.76, 2.75, 2.72, 2.69, 2.59, 2.68, 2.78, 2.68, 2.65, 2.74, 2.82, 2.56, 2.61, 2.72, 2.61, 2.74, 2.76, 2.56, 2.53, 2.56, 2.63, 2.43, 2.55, 2.56, 2.58, 2.62, 2.41, 2.43, 2.44, 2.44, 2.53, 2.49, 2.52, 2.15, 2.21, 2.2, 2.19, 2.23, 2.19, 2.15, 2.19, 2.3, 2.28, 2.31, 2.34, 2.38, 2.33, 2.43, 2.41, 2.38, 2.41, 2.4, 2.43, 2.44, 2.44, 2.32, 2.41, 2.4, 2.38, 2.42, 2.38, 2.35, 2.41, 2.46, 2.38, 2.33, 2.48, 2.45, 2.45, 2.45, 2.4, 2.46, 2.45, 2.47, 2.29, 2.43, 2.53, 2.39, 2.29], [3.85, 4.17, 4.5, 3.18, 3.08, 3.04, 3.16, 3.07, 2.97, 2.94, 3.04, 2.98, 2.98, 2.81, 2.81, 2.74, 2.72, 2.71, 2.75, 2.6, 2.61, 2.74, 2.56, 2.7, 2.69, 2.79, 2.58, 2.65, 2.64, 2.7, 2.72, 2.81, 2.56, 2.66, 2.71, 2.64, 2.44, 2.55, 2.56, 2.63, 2.6, 2.35, 2.4, 2.36, 2.39, 2.46, 2.51, 2.54, 2.09, 2.13, 2.25, 2.13, 2.24, 2.17, 2.31, 2.25, 2.29, 2.29, 2.3, 2.31, 2.33, 2.44, 2.4, 2.42, 2.41, 2.34, 2.43, 2.39, 2.38, 2.42, 2.37, 2.37, 2.44, 2.42, 2.42, 2.5, 2.47, 2.42, 2.47, 2.47, 2.39, 2.32, 2.44, 2.39, 2.33, 2.4, 2.42, 2.37, 2.39, 2.43, 2.37, 2.37, 2.4, 2.41], [3.91, 4.3, 4.52, 4.77, 3.12, 3.05, 3.18, 2.99, 2.91, 2.89, 2.91, 3.01, 2.89, 2.75, 2.81, 2.79, 2.77, 2.72, 2.71, 2.58, 2.62, 2.76, 2.65, 2.73, 2.67, 2.77, 2.69, 2.62, 2.64, 2.62, 2.66, 2.75, 2.52, 2.54, 2.54, 2.69, 2.5, 2.54, 2.51, 2.56, 2.62, 2.33, 2.42, 2.47, 2.47, 2.48, 2.47, 2.56, 2.12, 2.14, 2.18, 2.19, 2.21, 2.25, 2.25, 2.29, 2.27, 2.24, 2.3, 2.32, 2.34, 2.3, 2.39, 2.35, 2.33, 2.42, 2.4, 2.53, 2.5, 2.46, 2.44, 2.43, 2.45, 2.34, 2.41, 2.45, 2.41, 2.46, 2.35, 2.4, 2.37, 2.35, 2.37, 2.42, 2.31, 2.41, 2.36, 2.48, 2.44, 2.45, 2.43, 2.41, 2.47, 2.43], [3.88, 4.08, 4.5, 4.69, 3.15, 3.08, 3.13, 3.05, 2.96, 2.91, 3.0, 2.94, 2.99, 2.85, 2.82, 2.86, 2.77, 2.67, 2.79, 2.59, 2.63, 2.74, 2.67, 2.69, 2.65, 2.81, 2.62, 2.65, 2.72, 2.67, 2.68, 2.83, 2.52, 2.69, 2.64, 2.66, 2.49, 2.51, 2.54, 2.56, 2.57, 2.4, 2.39, 2.42, 2.49, 2.48, 2.52, 2.61, 2.09, 2.14, 2.21, 2.28, 2.24, 2.31, 2.25, 2.25, 2.35, 2.29, 2.36, 2.26, 2.36, 2.32, 2.38, 2.31, 2.34, 2.36, 2.38, 2.37, 2.34, 2.46, 2.33, 2.38, 2.48, 2.41, 2.43, 2.41, 2.35, 2.38, 2.41, 2.39, 2.44, 2.35, 2.4, 2.38, 2.38, 2.37, 2.34, 2.38, 2.36, 2.37, 2.41, 2.43, 2.55, 2.42], [3.97, 4.25, 4.55, 4.76, 3.11, 3.08, 3.06, 3.03, 3.0, 2.88, 2.85, 2.92, 2.97, 2.78, 2.81, 2.76, 2.77, 2.74, 2.69, 2.66, 2.72, 2.79, 2.66, 2.64, 2.66, 2.74, 2.63, 2.66, 2.7, 2.69, 2.68, 2.72, 2.49, 2.61, 2.58, 2.62, 2.49, 2.53, 2.56, 2.53, 2.7, 2.39, 2.39, 2.47, 2.45, 2.56, 2.56, 2.53, 2.1, 2.19, 2.21, 2.26, 2.23, 2.17, 2.19, 2.28, 2.32, 2.31, 2.31, 2.34, 2.36, 2.38, 2.38, 2.45, 2.46, 2.46, 2.4, 2.51, 2.38, 2.4, 2.5, 2.38, 2.32, 2.38, 2.45, 2.45, 2.44, 2.35, 2.43, 2.37, 2.38, 2.41, 2.43, 2.37, 2.42, 2.43, 2.44, 2.45, 2.45, 2.48, 2.41, 2.37, 2.42, 2.44], [3.96, 4.24, 4.45, 4.66, 3.18, 3.08, 3.07, 2.99, 2.91, 2.93, 2.94, 3.12, 2.97, 2.8, 2.77, 2.79, 2.85, 2.78, 2.71, 2.58, 2.7, 2.67, 2.59, 2.72, 2.78, 2.81, 2.61, 2.67, 2.79, 2.69, 2.76, 2.81, 2.55, 2.6, 2.65, 2.6, 2.42, 2.55, 2.56, 2.61, 2.66, 2.35, 2.45, 2.42, 2.43, 2.54, 2.53, 2.58, 2.21, 2.16, 2.22, 2.19, 2.16, 2.24, 2.36, 2.36, 2.33, 2.3, 2.34, 2.3, 2.42, 2.44, 2.4, 2.42, 2.46, 2.5, 2.39, 2.4, 2.37, 2.41, 2.39, 2.36, 2.45, 2.38, 2.43, 2.46, 2.36, 2.42, 2.41, 2.41, 2.44, 2.39, 2.34, 2.35, 2.3, 2.35, 2.4, 2.43, 2.32, 2.39, 2.41, 2.4, 2.38, 2.42], [3.89, 4.28, 4.5, 4.8, 3.14, 3.07, 3.26, 3.02, 2.94, 2.93, 2.9, 3.02, 2.91, 2.81, 2.77, 2.84, 2.81, 2.76, 2.68, 2.61, 2.7, 2.8, 2.6, 2.7, 2.74, 2.83, 2.66, 2.71, 2.8, 2.74, 2.76, 2.79, 2.58, 2.61, 2.65, 2.62, 2.49, 2.46, 2.49, 2.62, 2.66, 2.4, 2.44, 2.49, 2.54, 2.54, 2.54, 2.53, 2.17, 2.2, 2.21, 2.16, 2.14, 2.21, 2.21, 2.23, 2.34, 2.23, 2.32, 2.33, 2.32, 2.36, 2.38, 2.4, 2.36, 2.37, 2.5, 2.47, 2.36, 2.35, 2.4, 2.45, 2.4, 2.43, 2.47, 2.42, 2.37, 2.43, 2.43, 2.43, 2.4, 2.43, 2.34, 2.37, 2.34, 2.43, 2.37, 2.41, 2.43, 2.41, 2.37, 2.47, 2.52, 2.43], [3.97, 4.26, 4.49, 4.7, 3.1, 3.08, 3.14, 3.06, 3.05, 2.91, 2.93, 2.96, 2.87, 2.79, 2.86, 2.78, 2.86, 2.83, 2.72, 2.64, 2.74, 2.73, 2.65, 2.68, 2.73, 2.76, 2.64, 2.65, 2.74, 2.66, 2.75, 2.77, 2.54, 2.57, 2.64, 2.63, 2.41, 2.47, 2.56, 2.63, 2.61, 2.46, 2.4, 2.41, 2.45, 2.53, 2.58, 2.55, 2.15, 2.24, 2.19, 2.17, 2.2, 2.27, 2.29, 2.31, 2.3, 2.19, 2.36, 2.29, 2.4, 2.38, 2.43, 2.34, 2.43, 2.49, 2.42, 2.45, 2.37, 2.38, 2.4, 2.4, 2.45, 2.45, 2.37, 2.39, 2.39, 2.32, 2.36, 2.4, 2.39, 2.24, 2.45, 2.49, 2.45, 2.43, 2.49, 2.51, 2.41, 2.42, 2.38, 2.36, 2.35, 2.37], [3.89, 4.23, 4.48, 4.78, 3.11, 3.18, 3.12, 3.05, 2.99, 2.95, 2.98, 2.99, 2.99, 2.82, 2.73, 2.75, 2.78, 2.69, 2.66, 2.59, 2.69, 2.74, 2.54, 2.73, 2.74, 2.73, 2.6, 2.65, 2.71, 2.72, 2.75, 2.86, 2.6, 2.66, 2.65, 2.66, 2.55, 2.45, 2.59, 2.53, 2.64, 2.44, 2.36, 2.42, 2.48, 2.44, 2.43, 2.57, 2.12, 2.21, 2.19, 2.11, 2.16, 2.29, 2.22, 2.23, 2.34, 2.33, 2.37, 2.41, 2.4, 2.41, 2.41, 2.4, 2.34, 2.42, 2.36, 2.34, 2.44, 2.41, 2.39, 2.42, 2.43, 2.42, 2.37, 2.38, 2.38, 2.48, 2.39, 2.35, 2.42, 2.48, 2.47, 2.46, 2.36, 2.38, 2.28, 2.44, 2.41, 2.38, 2.42, 2.34, 2.41, 2.37], [3.93, 4.28, 4.48, 4.68, 5.12, 3.05, 3.17, 3.03, 3.02, 2.91, 2.93, 2.99, 2.97, 2.79, 2.74, 2.76, 2.79, 2.78, 2.79, 2.64, 2.71, 2.73, 2.6, 2.71, 2.77, 2.78, 2.62, 2.67, 2.76, 2.75, 2.73, 2.79, 2.48, 2.53, 2.61, 2.55, 2.47, 2.53, 2.52, 2.64, 2.64, 2.4, 2.44, 2.49, 2.42, 2.5, 2.57, 2.52, 2.13, 2.21, 2.16, 2.19, 2.25, 2.2, 2.27, 2.21, 2.29, 2.38, 2.34, 2.34, 2.33, 2.35, 2.36, 2.41, 2.5, 2.5, 2.41, 2.44, 2.43, 2.43, 2.38, 2.37, 2.39, 2.37, 2.38, 2.34, 2.44, 2.35, 2.4, 2.4, 2.3, 2.43, 2.45, 2.42, 2.5, 2.48, 2.37, 2.47, 2.45, 2.39, 2.43, 2.48, 2.4, 2.4], [3.89, 4.22, 4.52, 4.77, 5.0, 3.13, 3.13, 3.09, 3.06, 3.02, 2.89, 3.02, 2.98, 2.83, 2.81, 2.81, 2.71, 2.82, 2.7, 2.57, 2.76, 2.79, 2.66, 2.66, 2.72, 2.85, 2.65, 2.71, 2.74, 2.74, 2.71, 2.8, 2.59, 2.57, 2.68, 2.64, 2.51, 2.54, 2.55, 2.56, 2.59, 2.34, 2.42, 2.42, 2.52, 2.59, 2.52, 2.55, 2.09, 2.21, 2.16, 2.24, 2.18, 2.17, 2.22, 2.25, 2.31, 2.29, 2.35, 2.37, 2.36, 2.39, 2.39, 2.42, 2.35, 2.45, 2.34, 2.42, 2.42, 2.4, 2.46, 2.44, 2.44, 2.49, 2.46, 2.45, 2.4, 2.47, 2.45, 2.46, 2.4, 2.39, 2.37, 2.35, 2.34, 2.44, 2.4, 2.38, 2.48, 2.44, 2.38, 2.39, 2.45, 2.45], [3.95, 4.29, 4.5, 4.85, 5.05, 3.05, 3.13, 2.99, 2.95, 2.9, 2.88, 2.94, 2.93, 2.85, 2.76, 2.87, 2.91, 2.81, 2.79, 2.69, 2.67, 2.74, 2.61, 2.7, 2.71, 2.78, 2.57, 2.64, 2.76, 2.66, 2.73, 2.75, 2.5, 2.56, 2.73, 2.7, 2.52, 2.54, 2.57, 2.6, 2.64, 2.36, 2.41, 2.43, 2.41, 2.48, 2.46, 2.55, 2.14, 2.17, 2.16, 2.24, 2.22, 2.23, 2.2, 2.32, 2.31, 2.31, 2.31, 2.39, 2.38, 2.35, 2.41, 2.39, 2.4, 2.43, 2.37, 2.36, 2.35, 2.41, 2.4, 2.39, 2.44, 2.35, 2.38, 2.44, 2.48, 2.4, 2.45, 2.58, 2.41, 2.55, 2.42, 2.42, 2.46, 2.37, 2.44, 2.4, 2.41, 2.42, 2.54, 2.45, 2.43, 2.36], [3.91, 4.24, 4.54, 4.83, 5.09, 3.04, 3.2, 3.04, 2.99, 2.84, 3.02, 2.95, 2.99, 2.77, 2.77, 2.85, 2.85, 2.75, 2.76, 2.63, 2.7, 2.71, 2.66, 2.73, 2.66, 2.8, 2.67, 2.7, 2.75, 2.65, 2.69, 2.85, 2.56, 2.59, 2.71, 2.64, 2.45, 2.57, 2.57, 2.64, 2.61, 2.4, 2.38, 2.46, 2.48, 2.52, 2.61, 2.55, 2.2, 2.22, 2.19, 2.21, 2.2, 2.36, 2.25, 2.31, 2.35, 2.27, 2.34, 2.32, 2.35, 2.37, 2.4, 2.38, 2.44, 2.44, 2.41, 2.51, 2.55, 2.44, 2.4, 2.39, 2.37, 2.41, 2.38, 2.41, 2.48, 2.42, 2.45, 2.44, 2.33, 2.42, 2.4, 2.4, 2.34, 2.42, 2.43, 2.48, 2.43, 2.41, 2.43, 2.46, 2.43, 2.38], [4.01, 4.23, 4.48, 4.74, 5.01, 3.05, 3.1, 3.08, 3.04, 2.93, 2.96, 3.06, 3.01, 2.83, 2.79, 2.78, 2.78, 2.81, 2.7, 2.64, 2.69, 2.74, 2.66, 2.64, 2.75, 2.88, 2.61, 2.71, 2.69, 2.66, 2.78, 2.82, 2.63, 2.67, 2.72, 2.7, 2.52, 2.59, 2.5, 2.6, 2.58, 2.36, 2.39, 2.42, 2.53, 2.46, 2.58, 2.44, 2.15, 2.2, 2.19, 2.21, 2.19, 2.24, 2.38, 2.31, 2.26, 2.32, 2.35, 2.44, 2.27, 2.42, 2.45, 2.49, 2.38, 2.47, 2.45, 2.37, 2.48, 2.41, 2.44, 2.41, 2.48, 2.4, 2.52, 2.54, 2.45, 2.43, 2.47, 2.44, 2.44, 2.42, 2.41, 2.33, 2.41, 2.44, 2.39, 2.46, 2.42, 2.41, 2.43, 2.39, 2.43, 2.45], [4.02, 4.27, 4.53, 4.78, 5.15, 3.04, 3.15, 2.99, 2.93, 3.0, 2.91, 2.97, 2.97, 2.78, 2.81, 2.85, 2.83, 2.71, 2.81, 2.67, 2.73, 2.72, 2.68, 2.75, 2.77, 2.77, 2.69, 2.63, 2.73, 2.74, 2.75, 2.83, 2.61, 2.64, 2.65, 2.67, 2.5, 2.57, 2.54, 2.61, 2.61, 2.45, 2.4, 2.38, 2.44, 2.52, 2.52, 2.53, 2.11, 2.14, 2.1, 2.21, 2.23, 2.21, 2.26, 2.33, 2.28, 2.37, 2.4, 2.33, 2.3, 2.33, 2.41, 2.41, 2.39, 2.43, 2.47, 2.38, 2.35, 2.4, 2.4, 2.43, 2.46, 2.43, 2.43, 2.38, 2.45, 2.41, 2.41, 2.44, 2.47, 2.41, 2.44, 2.4, 2.42, 2.4, 2.52, 2.62, 2.58, 2.57, 2.6, 2.69, 2.7, 2.67], [4.37, 4.63, 4.89, 5.13, 5.49, 3.38, 3.36, 3.32, 3.23, 3.18, 3.2, 3.44, 3.23, 3.08, 2.99, 3.12, 3.08, 3.05, 2.97, 2.84, 2.92, 2.95, 2.88, 2.85, 2.96, 2.97, 2.83, 2.84, 2.95, 2.86, 3.02, 2.93, 2.71, 2.84, 2.87, 2.95, 2.67, 2.68, 2.77, 2.82, 2.84, 2.62, 2.63, 2.66, 2.72, 2.7, 2.73, 2.83, 2.33, 2.37, 2.43, 2.4, 2.37, 2.46, 2.49, 2.43, 2.49, 2.51, 2.44, 2.5, 2.51, 2.54, 2.55, 2.43, 2.42, 2.44, 2.38, 2.49, 2.39, 2.4, 2.39, 2.42, 2.38, 2.36, 2.39, 2.37, 2.39, 2.47, 2.46, 2.5, 2.47, 2.36, 2.48, 2.44, 2.42, 2.44, 2.48, 2.38, 2.37, 2.44, 2.41, 2.47, 2.43, 2.36], [3.9, 4.3, 4.62, 4.76, 5.12, 5.34, 3.19, 3.03, 2.99, 2.91, 2.96, 2.98, 2.96, 2.87, 2.83, 2.8, 2.79, 2.8, 2.72, 2.64, 2.74, 2.81, 2.67, 2.69, 2.75, 2.85, 2.6, 2.65, 2.74, 2.7, 2.76, 2.75, 2.54, 2.6, 2.67, 2.73, 2.5, 2.57, 2.61, 2.6, 2.67, 2.44, 2.44, 2.48, 2.48, 2.5, 2.53, 2.52, 2.13, 2.24, 2.21, 2.27, 2.25, 2.19, 2.29, 2.3, 2.24, 2.37, 2.37, 2.37, 2.38, 2.46, 2.43, 2.41, 2.42, 2.41, 2.42, 2.47, 2.47, 2.42, 2.42, 2.5, 2.4, 2.39, 2.48, 2.43, 2.47, 2.44, 2.36, 2.45, 2.47, 2.46, 2.44, 2.41, 2.48, 2.4, 2.42, 2.39, 2.42, 2.5, 2.44, 2.34, 2.48, 2.44], [3.96, 4.29, 4.57, 4.79, 5.13, 5.36, 3.18, 3.13, 2.99, 2.95, 2.99, 2.98, 2.93, 2.81, 2.74, 2.8, 2.84, 2.74, 2.78, 2.59, 2.64, 2.69, 2.58, 2.66, 2.76, 2.83, 2.66, 2.66, 2.77, 2.77, 2.78, 2.83, 2.56, 2.55, 2.62, 2.63, 2.47, 2.5, 2.59, 2.58, 2.59, 2.45, 2.4, 2.44, 2.38, 2.48, 2.54, 2.52, 2.18, 2.19, 2.27, 2.26, 2.3, 2.29, 2.27, 2.25, 2.32, 2.3, 2.34, 2.34, 2.44, 2.44, 2.47, 2.44, 2.43, 2.42, 2.46, 2.44, 2.49, 2.45, 2.44, 2.43, 2.42, 2.36, 2.44, 2.47, 2.43, 2.37, 2.5, 2.43, 2.42, 2.34, 2.41, 2.47, 2.48, 2.39, 2.37, 2.44, 2.45, 2.5, 2.44, 2.48, 2.45, 2.49], [4.02, 4.25, 4.56, 4.77, 5.08, 5.38, 3.13, 3.03, 2.96, 2.97, 2.96, 3.01, 3.12, 2.79, 2.84, 2.87, 2.88, 2.85, 2.77, 2.6, 2.72, 2.76, 2.59, 2.74, 2.75, 2.85, 2.62, 2.71, 2.73, 2.68, 2.73, 2.72, 2.58, 2.57, 2.6, 2.71, 2.57, 2.48, 2.61, 2.61, 2.67, 2.42, 2.43, 2.51, 2.47, 2.53, 2.55, 2.6, 2.16, 2.16, 2.25, 2.21, 2.25, 2.21, 2.24, 2.2, 2.38, 2.33, 2.36, 2.37, 2.33, 2.37, 2.44, 2.44, 2.45, 2.42, 2.4, 2.39, 2.38, 2.43, 2.4, 2.42, 2.45, 2.48, 2.4, 2.45, 2.45, 2.4, 2.45, 2.56, 2.42, 2.38, 2.5, 2.5, 2.52, 2.43, 2.4, 2.46, 2.45, 2.36, 2.45, 2.43, 2.44, 2.38], [3.92, 4.27, 4.62, 4.79, 5.07, 5.36, 3.19, 3.07, 2.95, 2.9, 2.98, 3.0, 2.97, 2.85, 2.77, 2.86, 2.82, 2.77, 2.73, 2.63, 2.71, 2.85, 2.63, 2.8, 2.77, 2.79, 2.57, 2.71, 2.74, 2.72, 2.73, 2.8, 2.58, 2.62, 2.64, 2.69, 2.5, 2.51, 2.64, 2.63, 2.66, 2.47, 2.4, 2.47, 2.48, 2.56, 2.55, 2.6, 2.11, 2.16, 2.17, 2.16, 2.23, 2.24, 2.35, 2.26, 2.32, 2.36, 2.38, 2.44, 2.33, 2.44, 2.47, 2.49, 2.43, 2.43, 2.37, 2.42, 2.45, 2.42, 2.56, 2.49, 2.32, 2.43, 2.43, 2.45, 2.46, 2.42, 2.46, 2.42, 2.48, 2.43, 2.47, 2.44, 2.48, 2.37, 2.46, 2.4, 2.44, 2.42, 2.49, 2.48, 2.42, 2.43], [3.98, 4.28, 4.57, 4.88, 5.03, 5.47, 3.22, 3.09, 3.03, 2.96, 2.84, 3.02, 3.0, 2.83, 2.81, 2.82, 2.84, 2.73, 2.73, 2.66, 2.66, 2.77, 2.7, 2.73, 2.75, 2.87, 2.65, 2.71, 2.74, 2.69, 2.73, 2.86, 2.6, 2.57, 2.61, 2.6, 2.49, 2.58, 2.6, 2.58, 2.59, 2.46, 2.52, 2.52, 2.47, 2.56, 2.51, 2.54, 2.21, 2.15, 2.16, 2.18, 2.28, 2.22, 2.29, 2.29, 2.29, 2.41, 2.31, 2.31, 2.35, 2.44, 2.48, 2.42, 2.53, 2.48, 2.35, 2.45, 2.41, 2.43, 2.51, 2.44, 2.45, 2.4, 2.46, 2.45, 2.48, 2.43, 2.43, 2.42, 2.4, 2.42, 2.48, 2.52, 2.4, 2.48, 2.5, 2.49, 2.49, 2.36, 2.5, 2.51, 2.43, 2.49], [3.95, 4.25, 4.58, 4.78, 5.16, 5.34, 3.24, 3.13, 2.95, 3.04, 2.94, 3.01, 3.02, 2.78, 2.8, 2.84, 2.83, 2.73, 2.73, 2.66, 2.62, 2.77, 2.63, 2.64, 2.78, 2.9, 2.69, 2.72, 2.78, 2.7, 2.75, 2.79, 2.59, 2.64, 2.69, 2.7, 2.53, 2.52, 2.53, 2.61, 2.63, 2.35, 2.4, 2.45, 2.46, 2.52, 2.56, 2.53, 2.23, 2.22, 2.25, 2.19, 2.34, 2.21, 2.25, 2.29, 2.3, 2.33, 2.36, 2.29, 2.39, 2.33, 2.35, 2.45, 2.44, 2.43, 2.51, 2.45, 2.48, 2.45, 2.47, 2.52, 2.43, 2.5, 2.45, 2.44, 2.42, 2.46, 2.51, 2.43, 2.47, 2.41, 2.44, 2.44, 2.45, 2.47, 2.45, 2.48, 2.46, 2.49, 2.46, 2.48, 2.52, 2.37], [4.01, 4.28, 4.53, 4.73, 5.04, 5.35, 3.12, 3.02, 2.94, 2.9, 2.82, 3.05, 3.05, 2.85, 2.83, 2.84, 2.83, 2.78, 2.77, 2.65, 2.77, 2.78, 2.61, 2.69, 2.78, 2.82, 2.65, 2.72, 2.72, 2.7, 2.66, 2.81, 2.52, 2.56, 2.61, 2.77, 2.55, 2.53, 2.65, 2.62, 2.71, 2.4, 2.41, 2.47, 2.5, 2.49, 2.55, 2.53, 2.19, 2.19, 2.23, 2.26, 2.31, 2.25, 2.33, 2.24, 2.36, 2.37, 2.35, 2.38, 2.5, 2.4, 2.42, 2.53, 2.54, 2.46, 2.38, 2.45, 2.48, 2.41, 2.48, 2.46, 2.41, 2.44, 2.42, 2.42, 2.49, 2.41, 2.44, 2.38, 2.47, 2.43, 2.44, 2.51, 2.47, 2.45, 2.42, 2.44, 2.5, 2.34, 2.4, 2.37, 2.39, 2.38], [4.06, 4.29, 4.57, 4.86, 5.17, 5.46, 5.79, 3.04, 3.0, 3.04, 2.95, 3.05, 2.99, 2.82, 3.0, 2.74, 2.8, 2.77, 2.78, 2.66, 2.76, 2.78, 2.68, 2.66, 2.77, 2.84, 2.66, 2.7, 2.68, 2.72, 2.73, 2.78, 2.53, 2.6, 2.58, 2.63, 2.55, 2.59, 2.61, 2.59, 2.65, 2.5, 2.43, 2.48, 2.44, 2.54, 2.51, 2.56, 2.22, 2.23, 2.17, 2.22, 2.24, 2.28, 2.27, 2.36, 2.3, 2.32, 2.36, 2.38, 2.42, 2.41, 2.42, 2.45, 2.53, 2.42, 2.5, 2.46, 2.4, 2.44, 2.4, 2.36, 2.47, 2.43, 2.42, 2.41, 2.4, 2.45, 2.5, 2.51, 2.47, 2.36, 2.45, 2.52, 2.5, 2.47, 2.43, 2.51, 2.49, 2.46, 2.5, 2.49, 2.45, 2.4], [3.97, 4.37, 4.61, 4.85, 5.08, 5.4, 5.77, 3.11, 3.09, 3.01, 3.02, 3.01, 3.02, 2.87, 2.8, 2.81, 2.82, 2.72, 2.74, 2.65, 2.73, 2.82, 2.71, 2.66, 2.84, 2.83, 2.59, 2.72, 2.77, 2.7, 2.72, 2.8, 2.54, 2.55, 2.7, 2.68, 2.5, 2.53, 2.56, 2.6, 2.67, 2.49, 2.49, 2.43, 2.52, 2.47, 2.62, 2.63, 2.17, 2.12, 2.22, 2.27, 2.21, 2.34, 2.37, 2.28, 2.33, 2.24, 2.34, 2.34, 2.42, 2.46, 2.51, 2.39, 2.4, 2.37, 2.43, 2.47, 2.47, 2.43, 2.44, 2.43, 2.35, 2.39, 2.49, 2.41, 2.49, 2.36, 2.38, 2.47, 2.45, 2.46, 2.46, 2.47, 2.51, 2.39, 2.55, 2.48, 2.48, 2.45, 2.42, 2.44, 2.45, 2.48], [3.94, 4.29, 4.53, 4.75, 5.13, 5.47, 5.87, 3.07, 3.05, 3.0, 3.04, 2.98, 2.96, 2.86, 2.8, 2.73, 2.84, 2.76, 2.74, 2.64, 2.67, 2.85, 2.68, 2.71, 2.84, 2.88, 2.72, 2.8, 2.77, 2.73, 2.79, 2.77, 2.55, 2.57, 2.66, 2.7, 2.46, 2.51, 2.6, 2.6, 2.64, 2.44, 2.39, 2.45, 2.54, 2.5, 2.56, 2.59, 2.23, 2.26, 2.21, 2.26, 2.23, 2.25, 2.21, 2.28, 2.36, 2.34, 2.39, 2.32, 2.42, 2.49, 2.32, 2.43, 2.46, 2.47, 2.57, 2.48, 2.43, 2.5, 2.47, 2.5, 2.45, 2.41, 2.4, 2.54, 2.47, 2.41, 2.47, 2.4, 2.58, 2.43, 2.43, 2.41, 2.54, 2.52, 2.41, 2.47, 2.54, 2.46, 2.46, 2.48, 2.43, 2.44], [4.05, 4.32, 4.57, 4.87, 5.05, 5.4, 5.78, 3.08, 3.07, 3.08, 2.94, 3.02, 3.0, 2.85, 2.81, 2.85, 2.84, 2.8, 2.74, 2.6, 2.7, 2.75, 2.61, 2.67, 2.8, 2.91, 2.67, 2.76, 2.74, 2.77, 2.77, 2.85, 2.57, 2.59, 2.63, 2.67, 2.51, 2.54, 2.63, 2.64, 2.66, 2.39, 2.44, 2.47, 2.45, 2.56, 2.52, 2.56, 2.17, 2.21, 2.25, 2.21, 2.25, 2.28, 2.31, 2.31, 2.36, 2.32, 2.34, 2.37, 2.48, 2.37, 2.43, 2.46, 2.45, 2.36, 2.45, 2.48, 2.49, 2.53, 2.48, 2.48, 2.55, 2.47, 2.5, 2.5, 2.45, 2.41, 2.38, 2.49, 2.5, 2.45, 2.47, 2.52, 2.5, 2.45, 2.53, 2.53, 2.5, 2.52, 2.49, 2.53, 2.52, 2.43], [4.02, 4.29, 4.51, 4.74, 5.09, 5.38, 5.77, 3.09, 3.09, 3.0, 2.97, 3.08, 2.99, 2.84, 2.87, 2.84, 2.76, 2.76, 2.76, 2.57, 2.8, 2.8, 2.63, 2.7, 2.76, 2.83, 2.77, 2.73, 2.78, 2.71, 2.82, 2.86, 2.58, 2.6, 2.66, 2.72, 2.56, 2.57, 2.56, 2.66, 2.7, 2.42, 2.37, 2.48, 2.49, 2.53, 2.49, 2.6, 2.16, 2.28, 2.16, 2.25, 2.22, 2.18, 2.27, 2.34, 2.37, 2.25, 2.31, 2.4, 2.42, 2.41, 2.42, 2.45, 2.46, 2.46, 2.44, 2.47, 2.47, 2.51, 2.51, 2.47, 2.44, 2.5, 2.45, 2.41, 2.48, 2.47, 2.48, 2.49, 2.41, 2.35, 2.46, 2.38, 2.46, 2.56, 2.48, 2.36, 2.53, 2.46, 2.55, 2.47, 2.54, 2.58], [4.05, 4.37, 4.5, 4.79, 5.05, 5.39, 5.69, 3.11, 3.01, 3.03, 2.94, 3.1, 3.05, 2.84, 2.85, 2.86, 2.79, 2.78, 2.74, 2.68, 2.63, 2.81, 2.64, 2.72, 2.67, 2.81, 2.65, 2.71, 2.82, 2.74, 2.7, 2.82, 2.57, 2.67, 2.68, 2.73, 2.48, 2.58, 2.59, 2.63, 2.68, 2.48, 2.36, 2.42, 2.51, 2.59, 2.57, 2.56, 2.26, 2.23, 2.26, 2.24, 2.24, 2.31, 2.27, 2.34, 2.31, 2.41, 2.31, 2.39, 2.41, 2.5, 2.48, 2.39, 2.38, 2.44, 2.49, 2.47, 2.49, 2.45, 2.54, 2.44, 2.5, 2.42, 2.47, 2.52, 2.5, 2.42, 2.4, 2.52, 2.42, 2.41, 2.48, 2.44, 2.52, 2.55, 2.44, 2.52, 2.55, 2.52, 2.45, 2.49, 2.43, 2.37], [4.0, 4.29, 4.58, 4.84, 5.11, 5.41, 5.78, 6.15, 3.09, 2.95, 2.94, 3.06, 3.04, 2.87, 2.89, 2.92, 2.85, 2.76, 2.8, 2.62, 2.74, 2.8, 2.71, 2.8, 2.8, 2.79, 2.69, 2.71, 2.77, 2.65, 2.76, 2.8, 2.57, 2.63, 2.7, 2.75, 2.48, 2.54, 2.66, 2.64, 2.63, 2.45, 2.48, 2.47, 2.49, 2.56, 2.56, 2.62, 2.24, 2.26, 2.31, 2.3, 2.28, 2.31, 2.3, 2.28, 2.33, 2.36, 2.35, 2.4, 2.41, 2.48, 2.43, 2.47, 2.39, 2.51, 2.47, 2.4, 2.43, 2.45, 2.52, 2.42, 2.41, 2.48, 2.45, 2.51, 2.36, 2.47, 2.39, 2.34, 2.51, 2.48, 2.38, 2.49, 2.5, 2.43, 2.48, 2.52, 2.5, 2.49, 2.39, 2.43, 2.51, 2.42], [4.07, 4.3, 4.56, 4.76, 5.02, 5.41, 5.71, 6.0, 3.04, 2.93, 3.01, 3.1, 3.03, 2.84, 2.9, 2.84, 2.9, 2.77, 2.77, 2.6, 2.71, 2.9, 2.64, 2.74, 2.79, 2.88, 2.64, 2.72, 2.82, 2.78, 2.84, 2.85, 2.59, 2.6, 2.69, 2.65, 2.48, 2.56, 2.6, 2.64, 2.58, 2.45, 2.44, 2.38, 2.5, 2.56, 2.59, 2.54, 2.14, 2.25, 2.2, 2.26, 2.26, 2.32, 2.36, 2.31, 2.38, 2.37, 2.39, 2.37, 2.35, 2.49, 2.44, 2.44, 2.33, 2.44, 2.47, 2.41, 2.45, 2.48, 2.48, 2.46, 2.46, 2.47, 2.49, 2.53, 2.47, 2.45, 2.49, 2.48, 2.48, 2.49, 2.43, 2.46, 2.41, 2.52, 2.42, 2.41, 2.48, 2.4, 2.4, 2.48, 2.48, 2.48], [3.98, 4.38, 4.62, 4.86, 5.08, 5.46, 5.79, 6.04, 3.0, 2.92, 3.04, 2.97, 2.98, 2.79, 2.79, 2.85, 2.83, 2.84, 2.81, 2.67, 2.79, 2.83, 2.68, 2.78, 2.83, 2.82, 2.69, 2.71, 2.79, 2.79, 2.8, 2.81, 2.58, 2.69, 2.6, 2.72, 2.56, 2.61, 2.64, 2.7, 2.69, 2.44, 2.41, 2.47, 2.45, 2.5, 2.56, 2.63, 2.27, 2.19, 2.22, 2.23, 2.25, 2.3, 2.33, 2.33, 2.35, 2.34, 2.45, 2.42, 2.53, 2.5, 2.59, 2.51, 2.5, 2.48, 2.44, 2.45, 2.49, 2.38, 2.46, 2.48, 2.49, 2.46, 2.39, 2.4, 2.49, 2.52, 2.53, 2.52, 2.53, 2.59, 2.5, 2.42, 2.44, 2.42, 2.55, 2.57, 2.47, 2.38, 2.46, 2.46, 2.41, 2.36], [3.97, 4.29, 4.6, 4.84, 5.11, 5.48, 5.83, 6.05, 3.01, 2.97, 3.01, 3.02, 3.03, 2.81, 2.81, 2.89, 2.81, 2.75, 2.81, 2.74, 2.76, 2.82, 2.74, 2.78, 2.81, 2.81, 2.63, 2.76, 2.74, 2.72, 2.78, 2.78, 2.57, 2.63, 2.64, 2.73, 2.47, 2.58, 2.7, 2.64, 2.75, 2.41, 2.48, 2.5, 2.51, 2.55, 2.57, 2.59, 2.19, 2.3, 2.22, 2.29, 2.28, 2.25, 2.31, 2.28, 2.36, 2.32, 2.44, 2.4, 2.49, 2.44, 2.47, 2.49, 2.43, 2.52, 2.55, 2.54, 2.46, 2.37, 2.49, 2.43, 2.46, 2.46, 2.44, 2.5, 2.52, 2.46, 2.46, 2.45, 2.52, 2.5, 2.48, 2.4, 2.48, 2.46, 2.47, 2.43, 2.55, 2.5, 2.44, 2.39, 2.4, 2.4], [3.97, 4.34, 4.52, 4.84, 5.07, 5.49, 5.8, 6.03, 3.01, 3.04, 2.99, 3.01, 2.98, 2.89, 2.89, 2.85, 2.86, 2.86, 2.76, 2.71, 2.74, 2.75, 2.65, 2.74, 2.78, 2.79, 2.63, 2.67, 2.76, 2.71, 2.78, 2.82, 2.57, 2.69, 2.71, 2.67, 2.58, 2.55, 2.62, 2.69, 2.67, 2.5, 2.38, 2.57, 2.49, 2.54, 2.59, 2.58, 2.26, 2.26, 2.23, 2.24, 2.27, 2.37, 2.27, 2.26, 2.37, 2.35, 2.36, 2.47, 2.47, 2.49, 2.47, 2.46, 2.47, 2.54, 2.48, 2.51, 2.47, 2.46, 2.44, 2.54, 2.49, 2.52, 2.48, 2.4, 2.55, 2.38, 2.51, 2.54, 2.51, 2.46, 2.48, 2.54, 2.48, 2.52, 2.44, 2.47, 2.54, 2.43, 2.44, 2.43, 2.49, 2.47], [4.07, 4.33, 4.59, 4.9, 5.09, 5.48, 5.8, 6.05, 3.03, 2.99, 3.02, 3.04, 3.02, 2.84, 2.82, 2.82, 2.83, 2.82, 2.79, 2.67, 2.72, 2.82, 2.72, 2.71, 2.84, 2.88, 2.66, 2.64, 2.75, 2.73, 2.82, 2.83, 2.6, 2.67, 2.73, 2.75, 2.56, 2.63, 2.64, 2.64, 2.64, 2.47, 2.52, 2.58, 2.54, 2.63, 2.53, 2.64, 2.23, 2.2, 2.28, 2.28, 2.29, 2.31, 2.34, 2.34, 2.41, 2.36, 2.33, 2.45, 2.44, 2.48, 2.46, 2.49, 2.5, 2.47, 2.51, 2.41, 2.49, 2.4, 2.43, 2.43, 2.48, 2.43, 2.47, 2.49, 2.43, 2.49, 2.51, 2.47, 2.47, 2.52, 2.51, 2.53, 2.48, 2.49, 2.51, 2.38, 2.61, 2.56, 2.54, 2.46, 2.57, 2.44], [4.02, 4.38, 4.54, 4.81, 5.26, 5.35, 5.82, 6.08, 3.11, 3.03, 3.05, 3.03, 3.0, 2.84, 2.84, 2.84, 2.82, 2.79, 2.75, 2.64, 2.73, 2.77, 2.69, 2.72, 2.75, 2.9, 2.61, 2.72, 2.75, 2.82, 2.81, 2.8, 2.6, 2.65, 2.66, 2.71, 2.52, 2.58, 2.51, 2.71, 2.71, 2.45, 2.58, 2.58, 2.59, 2.59, 2.56, 2.61, 2.26, 2.25, 2.25, 2.26, 2.26, 2.28, 2.29, 2.29, 2.42, 2.37, 2.36, 2.42, 2.47, 2.48, 2.47, 2.48, 2.51, 2.51, 2.45, 2.55, 2.48, 2.42, 2.46, 2.36, 2.54, 2.43, 2.47, 2.45, 2.51, 2.45, 2.51, 2.53, 2.38, 2.58, 2.47, 2.51, 2.47, 2.54, 2.56, 2.46, 2.49, 2.39, 2.46, 2.51, 2.44, 2.54], [3.97, 4.38, 4.6, 4.81, 5.07, 5.5, 5.81, 6.01, 3.07, 3.06, 2.98, 3.03, 3.06, 2.9, 2.85, 2.84, 2.82, 2.79, 2.74, 2.68, 2.76, 2.72, 2.67, 2.74, 2.83, 2.92, 2.7, 2.71, 2.84, 2.76, 2.75, 2.9, 2.55, 2.64, 2.73, 2.69, 2.53, 2.59, 2.65, 2.65, 2.67, 2.48, 2.44, 2.5, 2.53, 2.6, 2.64, 2.59, 2.26, 2.21, 2.31, 2.23, 2.3, 2.31, 2.35, 2.36, 2.37, 2.34, 2.36, 2.39, 2.38, 2.49, 2.39, 2.47, 2.48, 2.5, 2.56, 2.46, 2.55, 2.51, 2.56, 2.53, 2.49, 2.45, 2.48, 2.52, 2.5, 2.46, 2.45, 2.45, 2.54, 2.47, 2.43, 2.54, 2.49, 2.45, 2.5, 2.45, 2.48, 2.46, 2.39, 2.46, 2.48, 2.48], [4.07, 4.28, 4.58, 4.88, 5.06, 5.31, 5.82, 6.09, 3.04, 2.99, 3.08, 3.04, 2.99, 2.91, 2.79, 2.86, 2.92, 2.86, 2.72, 2.66, 2.83, 2.86, 2.69, 2.77, 2.82, 2.9, 2.73, 2.74, 2.85, 2.74, 2.82, 2.86, 2.67, 2.67, 2.68, 2.65, 2.51, 2.55, 2.62, 2.65, 2.7, 2.49, 2.57, 2.58, 2.64, 2.55, 2.65, 2.63, 2.29, 2.25, 2.27, 2.29, 2.3, 2.29, 2.34, 2.36, 2.36, 2.34, 2.32, 2.34, 2.43, 2.43, 2.43, 2.49, 2.5, 2.57, 2.52, 2.5, 2.48, 2.55, 2.49, 2.55, 2.53, 2.52, 2.46, 2.39, 2.41, 2.5, 2.47, 2.47, 2.49, 2.43, 2.51, 2.62, 2.5, 2.5, 2.45, 2.56, 2.54, 2.49, 2.51, 2.55, 2.5, 2.5], [4.08, 4.33, 4.55, 4.81, 5.1, 5.39, 5.8, 6.11, 3.11, 3.0, 3.01, 3.12, 3.04, 2.87, 2.85, 2.88, 2.83, 2.83, 2.82, 2.7, 2.75, 2.74, 2.66, 2.75, 2.86, 2.93, 2.7, 2.82, 2.87, 2.73, 2.76, 2.81, 2.65, 2.72, 2.65, 2.71, 2.54, 2.64, 2.67, 2.61, 2.76, 2.47, 2.53, 2.51, 2.51, 2.5, 2.6, 2.63, 2.24, 2.24, 2.24, 2.3, 2.3, 2.34, 2.36, 2.35, 2.45, 2.4, 2.33, 2.45, 2.45, 2.4, 2.48, 2.52, 2.45, 2.46, 2.51, 2.51, 2.54, 2.47, 2.52, 2.5, 2.49, 2.47, 2.54, 2.58, 2.49, 2.39, 2.44, 2.54, 2.5, 2.44, 2.44, 2.54, 2.47, 2.51, 2.49, 2.49, 2.46, 2.52, 2.54, 2.47, 2.51, 2.57], [4.07, 4.32, 4.61, 4.86, 5.14, 5.4, 5.76, 6.11, 3.15, 2.96, 3.08, 3.11, 3.05, 2.89, 2.88, 2.86, 2.87, 2.82, 2.82, 2.63, 2.71, 2.89, 2.69, 2.79, 2.85, 2.88, 2.73, 2.74, 2.83, 2.83, 2.8, 2.84, 2.62, 2.74, 2.65, 2.75, 2.5, 2.58, 2.55, 2.67, 2.68, 2.4, 2.4, 2.53, 2.65, 2.6, 2.71, 2.63, 2.22, 2.23, 2.26, 2.24, 2.24, 2.25, 2.36, 2.32, 2.38, 2.47, 2.44, 2.37, 2.41, 2.43, 2.5, 2.52, 2.58, 2.46, 2.44, 2.61, 2.53, 2.51, 2.49, 2.49, 2.53, 2.47, 2.44, 2.51, 2.46, 2.49, 2.48, 2.49, 2.43, 2.42, 2.47, 2.47, 2.55, 2.55, 2.49, 2.5, 2.57, 2.45, 2.56, 2.5, 2.48, 2.48], [4.01, 4.3, 4.54, 4.85, 5.1, 5.35, 5.83, 6.07, 2.99, 2.97, 3.08, 3.06, 3.08, 2.92, 2.96, 2.76, 2.89, 2.77, 2.73, 2.66, 2.75, 2.81, 2.69, 2.77, 2.85, 2.85, 2.72, 2.82, 2.86, 2.88, 2.84, 2.9, 2.65, 2.68, 2.76, 2.74, 2.57, 2.58, 2.66, 2.77, 2.6, 2.52, 2.57, 2.49, 2.53, 2.59, 2.55, 2.52, 2.21, 2.26, 2.29, 2.3, 2.33, 2.32, 2.37, 2.31, 2.37, 2.31, 2.31, 2.49, 2.44, 2.49, 2.43, 2.46, 2.59, 2.5, 2.53, 2.49, 2.51, 2.45, 2.47, 2.53, 2.37, 2.58, 2.53, 2.49, 2.45, 2.46, 2.42, 2.39, 2.47, 2.44, 2.46, 2.5, 2.41, 2.5, 2.47, 2.49, 2.55, 2.47, 2.51, 2.51, 2.47, 2.46], [4.08, 4.33, 4.62, 4.85, 5.26, 5.47, 5.85, 6.03, 3.04, 2.99, 2.97, 3.1, 3.04, 2.9, 2.96, 2.87, 2.91, 2.81, 2.82, 2.72, 2.77, 2.73, 2.68, 2.76, 2.74, 2.88, 2.7, 2.75, 2.82, 2.75, 2.79, 2.92, 2.69, 2.68, 2.71, 2.69, 2.52, 2.65, 2.59, 2.62, 2.66, 2.43, 2.51, 2.48, 2.54, 2.57, 2.6, 2.66, 2.23, 2.2, 2.25, 2.28, 2.36, 2.4, 2.34, 2.39, 2.4, 2.37, 2.39, 2.43, 2.42, 2.51, 2.55, 2.42, 2.58, 2.48, 2.49, 2.51, 2.55, 2.46, 2.54, 2.54, 2.56, 2.54, 2.56, 2.53, 2.47, 2.49, 2.54, 2.51, 2.49, 2.53, 2.46, 2.37, 2.49, 2.45, 2.47, 2.48, 2.42, 2.48, 2.5, 2.5, 2.55, 2.44], [4.14, 4.37, 4.68, 4.8, 5.09, 5.42, 5.84, 5.98, 3.05, 3.05, 3.05, 3.08, 3.01, 2.88, 2.93, 2.88, 2.9, 2.84, 2.76, 2.64, 2.77, 2.75, 2.63, 2.74, 2.82, 2.84, 2.64, 2.65, 2.89, 2.82, 2.85, 2.84, 2.71, 2.66, 2.65, 2.73, 2.52, 2.55, 2.6, 2.67, 2.7, 2.45, 2.49, 2.49, 2.54, 2.58, 2.59, 2.59, 2.26, 2.25, 2.29, 2.3, 2.28, 2.35, 2.34, 2.36, 2.36, 2.37, 2.38, 2.47, 2.46, 2.45, 2.5, 2.49, 2.48, 2.49, 2.45, 2.47, 2.48, 2.56, 2.48, 2.56, 2.52, 2.49, 2.48, 2.5, 2.53, 2.5, 2.48, 2.54, 2.47, 2.49, 2.51, 2.44, 2.52, 2.42, 2.48, 2.46, 2.54, 2.44, 2.48, 2.51, 2.54, 2.5], [4.08, 4.39, 4.65, 4.88, 5.12, 5.42, 5.88, 6.14, 3.07, 3.1, 3.12, 3.09, 3.02, 2.87, 2.85, 2.88, 2.83, 2.84, 2.84, 2.67, 2.77, 2.82, 2.62, 2.8, 2.83, 2.84, 2.71, 2.76, 2.87, 2.79, 2.89, 2.86, 2.54, 2.62, 2.67, 2.76, 2.56, 2.57, 2.59, 2.65, 2.66, 2.49, 2.43, 2.49, 2.54, 2.65, 2.59, 2.59, 2.22, 2.25, 2.27, 2.21, 2.27, 2.3, 2.36, 2.37, 2.36, 2.39, 2.47, 2.4, 2.42, 2.44, 2.46, 2.52, 2.49, 2.47, 2.5, 2.53, 2.51, 2.54, 2.54, 2.51, 2.34, 2.47, 2.47, 2.48, 2.52, 2.53, 2.44, 2.52, 2.6, 2.48, 2.42, 2.41, 2.53, 2.46, 2.41, 2.52, 2.49, 2.5, 2.56, 2.51, 2.58, 2.54], [4.67, 4.31, 4.58, 4.88, 5.11, 5.47, 5.75, 5.95, 3.14, 3.03, 3.05, 3.13, 3.03, 2.95, 2.89, 2.82, 2.86, 2.81, 2.74, 2.7, 2.72, 2.78, 2.63, 2.77, 2.82, 2.86, 2.69, 2.73, 2.77, 2.75, 2.89, 2.86, 2.61, 2.66, 2.7, 2.79, 2.56, 2.62, 2.62, 2.68, 2.64, 2.44, 2.53, 2.58, 2.51, 2.56, 2.65, 2.61, 2.19, 2.2, 2.24, 2.37, 2.28, 2.28, 2.22, 2.38, 2.38, 2.42, 2.43, 2.43, 2.48, 2.45, 2.49, 2.52, 2.52, 2.57, 2.44, 2.51, 2.43, 2.61, 2.57, 2.53, 2.45, 2.52, 2.48, 2.48, 2.57, 2.47, 2.54, 2.54, 2.5, 2.56, 2.58, 2.49, 2.57, 2.41, 2.54, 2.5, 2.53, 2.61, 2.52, 2.51, 2.52, 2.49], [4.65, 4.41, 4.7, 4.83, 5.17, 5.43, 5.83, 6.1, 3.11, 3.06, 3.03, 3.1, 3.04, 2.95, 2.87, 2.93, 2.86, 2.86, 2.79, 2.72, 2.69, 2.82, 2.71, 2.74, 2.75, 2.86, 2.74, 2.72, 2.87, 2.82, 2.87, 2.88, 2.62, 2.74, 2.74, 2.8, 2.57, 2.6, 2.61, 2.59, 2.69, 2.46, 2.6, 2.48, 2.56, 2.55, 2.63, 2.55, 2.22, 2.23, 2.37, 2.36, 2.34, 2.32, 2.34, 2.34, 2.34, 2.37, 2.35, 2.39, 2.38, 2.49, 2.44, 2.54, 2.47, 2.44, 2.53, 2.54, 2.48, 2.49, 2.48, 2.53, 2.5, 2.51, 2.42, 2.47, 2.47, 2.48, 2.48, 2.45, 2.48, 2.56, 2.56, 2.51, 2.48, 2.52, 2.49, 2.56, 2.56, 2.53, 2.52, 2.58, 2.58, 2.51], [4.63, 4.37, 4.67, 4.9, 5.13, 5.35, 5.8, 6.07, 3.01, 3.09, 2.99, 3.1, 3.08, 2.86, 2.89, 2.83, 2.83, 2.81, 2.85, 2.72, 2.8, 2.79, 2.72, 2.7, 2.79, 2.81, 2.81, 2.78, 2.76, 2.79, 2.87, 2.92, 2.61, 2.66, 2.69, 2.76, 2.56, 2.53, 2.6, 2.69, 2.73, 2.45, 2.56, 2.54, 2.54, 2.65, 2.58, 2.68, 2.24, 2.23, 2.26, 2.31, 2.31, 2.33, 2.27, 2.34, 2.37, 2.39, 2.4, 2.32, 2.45, 2.44, 2.52, 2.52, 2.5, 2.52, 2.45, 2.6, 2.51, 2.52, 2.48, 2.47, 2.54, 2.49, 2.51, 2.49, 2.5, 2.49, 2.49, 2.48, 2.43, 2.5, 2.46, 2.53, 2.52, 2.49, 2.44, 2.54, 2.48, 2.52, 2.53, 2.43, 2.49, 2.49], [4.67, 4.39, 4.61, 4.9, 5.09, 5.39, 5.77, 6.05, 3.12, 3.0, 3.05, 3.1, 3.07, 2.94, 2.84, 2.85, 2.9, 2.83, 2.86, 2.73, 2.77, 2.83, 2.77, 2.72, 2.83, 2.91, 2.74, 2.87, 2.82, 2.81, 2.84, 2.9, 2.66, 2.73, 2.72, 2.74, 2.6, 2.57, 2.63, 2.69, 2.72, 2.46, 2.51, 2.45, 2.55, 2.57, 2.63, 2.57, 2.17, 2.24, 2.36, 2.34, 2.34, 2.35, 2.41, 2.32, 2.32, 2.35, 2.43, 2.49, 2.44, 2.48, 2.5, 2.48, 2.56, 2.47, 2.5, 2.56, 2.5, 2.41, 2.46, 2.51, 2.58, 2.52, 2.48, 2.57, 2.54, 2.5, 2.51, 2.49, 2.46, 2.52, 2.52, 2.47, 2.49, 2.52, 2.46, 2.54, 2.49, 2.45, 2.47, 2.53, 2.51, 2.45], [4.7, 4.38, 4.6, 4.91, 5.15, 5.46, 5.8, 6.15, 3.11, 3.11, 3.06, 3.15, 3.13, 2.92, 2.94, 2.9, 2.84, 2.88, 2.85, 2.66, 2.75, 2.84, 2.68, 2.74, 2.85, 2.92, 2.72, 2.76, 2.81, 2.8, 2.88, 2.91, 2.61, 2.63, 2.71, 2.74, 2.63, 2.62, 2.66, 2.56, 2.69, 2.45, 2.47, 2.54, 2.53, 2.58, 2.7, 2.69, 2.23, 2.25, 2.28, 2.31, 2.35, 2.39, 2.35, 2.36, 2.42, 2.47, 2.39, 2.48, 2.42, 2.49, 2.42, 2.53, 2.5, 2.46, 2.52, 2.49, 2.48, 2.52, 2.34, 2.45, 2.54, 2.51, 2.5, 2.49, 2.52, 2.49, 2.46, 2.51, 2.47, 2.51, 2.5, 2.47, 2.46, 2.44, 2.54, 2.51, 2.53, 2.5, 2.51, 2.44, 2.53, 2.5], [4.68, 4.4, 4.58, 4.87, 5.15, 5.45, 5.78, 6.13, 3.04, 3.01, 3.03, 3.09, 3.07, 2.96, 2.86, 2.91, 2.96, 2.81, 2.78, 2.75, 2.79, 2.84, 2.72, 2.7, 2.86, 2.9, 2.7, 2.77, 2.79, 2.8, 2.85, 2.8, 2.71, 2.62, 2.76, 2.78, 2.62, 2.65, 2.63, 2.64, 2.74, 2.45, 2.47, 2.54, 2.63, 2.6, 2.67, 2.56, 2.29, 2.23, 2.28, 2.3, 2.23, 2.31, 2.36, 2.31, 2.41, 2.47, 2.5, 2.52, 2.48, 2.53, 2.52, 2.51, 2.5, 2.46, 2.54, 2.48, 2.45, 2.5, 2.48, 2.55, 2.5, 2.54, 2.56, 2.41, 2.54, 2.46, 2.54, 2.54, 2.56, 2.47, 2.4, 2.48, 2.46, 2.46, 2.5, 2.5, 2.44, 2.54, 2.51, 2.56, 2.49, 2.45], [4.69, 4.43, 4.66, 4.97, 5.16, 5.45, 5.85, 6.11, 3.07, 3.04, 3.03, 3.16, 3.14, 2.9, 2.93, 2.92, 2.92, 2.84, 2.84, 2.73, 2.76, 2.77, 2.75, 2.71, 2.96, 2.9, 2.71, 2.75, 2.82, 2.84, 2.83, 2.91, 2.68, 2.69, 2.8, 2.69, 2.6, 2.6, 2.7, 2.69, 2.63, 2.41, 2.52, 2.58, 2.5, 2.56, 2.64, 2.66, 2.27, 2.35, 2.27, 2.26, 2.3, 2.37, 2.41, 2.36, 2.38, 2.33, 2.46, 2.43, 2.44, 2.44, 2.43, 2.52, 2.48, 2.49, 2.54, 2.51, 2.57, 2.5, 2.52, 2.54, 2.54, 2.51, 2.52, 2.45, 2.58, 2.57, 2.56, 2.4, 2.53, 2.52, 2.51, 2.43, 2.54, 2.48, 2.51, 2.48, 2.67, 2.48, 2.46, 2.52, 2.57, 2.49], [4.66, 4.39, 4.62, 4.88, 5.1, 5.52, 5.8, 6.07, 3.1, 3.07, 3.06, 3.08, 3.09, 2.98, 2.81, 2.95, 2.96, 2.84, 2.86, 2.73, 2.77, 2.92, 2.74, 2.75, 2.77, 2.88, 2.72, 2.75, 2.8, 2.78, 2.84, 2.88, 2.67, 2.66, 2.68, 2.73, 2.58, 2.57, 2.7, 2.67, 2.67, 2.51, 2.62, 2.53, 2.57, 2.63, 2.62, 2.68, 2.25, 2.31, 2.3, 2.33, 2.28, 2.3, 2.27, 2.31, 2.43, 2.31, 2.42, 2.44, 2.42, 2.46, 2.48, 2.49, 2.49, 2.55, 2.54, 2.57, 2.5, 2.51, 2.51, 2.52, 2.47, 2.58, 2.45, 2.56, 2.54, 2.56, 2.45, 2.48, 2.48, 2.49, 2.54, 2.44, 2.54, 2.53, 2.53, 2.56, 2.53, 2.52, 2.56, 2.55, 2.45, 2.49], [4.66, 4.36, 4.6, 4.87, 5.21, 5.44, 5.88, 6.12, 3.12, 3.05, 3.13, 3.13, 3.02, 2.87, 2.85, 2.93, 2.89, 2.72, 2.71, 2.74, 2.83, 2.89, 2.69, 2.81, 2.89, 2.95, 2.74, 2.89, 2.87, 2.69, 2.82, 2.87, 2.62, 2.61, 2.72, 2.78, 2.58, 2.67, 2.68, 2.69, 2.69, 2.51, 2.46, 2.54, 2.63, 2.61, 2.61, 2.62, 2.3, 2.22, 2.26, 2.29, 2.31, 2.37, 2.37, 2.43, 2.47, 2.4, 2.48, 2.48, 2.51, 2.41, 2.55, 2.58, 2.51, 2.53, 2.55, 2.49, 2.55, 2.55, 2.61, 2.54, 2.53, 2.57, 2.43, 2.5, 2.6, 2.5, 2.49, 2.48, 2.5, 2.5, 2.48, 2.49, 2.54, 2.53, 2.51, 2.54, 2.59, 2.58, 2.58, 2.56, 2.58, 2.55], [4.7, 4.41, 4.58, 4.85, 5.29, 5.52, 5.86, 6.15, 3.1, 3.01, 3.13, 3.08, 3.04, 2.87, 2.92, 2.91, 2.94, 2.83, 2.74, 2.74, 2.81, 2.82, 2.75, 2.79, 2.81, 2.96, 2.71, 2.76, 2.87, 2.83, 2.92, 2.93, 2.7, 2.74, 2.71, 2.76, 2.62, 2.6, 2.64, 2.7, 2.71, 2.48, 2.54, 2.51, 2.63, 2.62, 2.63, 2.71, 2.2, 2.26, 2.3, 2.26, 2.34, 2.28, 2.35, 2.33, 2.36, 2.43, 2.41, 2.39, 2.46, 2.49, 2.51, 2.54, 2.52, 2.53, 2.47, 2.55, 2.54, 2.47, 2.52, 2.56, 2.51, 2.47, 2.53, 2.58, 2.53, 2.47, 2.52, 2.49, 2.53, 2.55, 2.55, 2.49, 2.56, 2.5, 2.46, 2.5, 2.5, 2.45, 2.5, 2.53, 2.49, 2.44], [4.73, 4.45, 4.65, 4.95, 5.2, 5.52, 5.86, 6.07, 3.12, 3.0, 3.1, 3.1, 3.05, 2.88, 2.91, 2.91, 2.9, 2.8, 2.79, 2.69, 2.82, 2.95, 2.73, 2.8, 2.94, 2.92, 2.71, 2.78, 2.86, 2.92, 2.86, 2.88, 2.62, 2.67, 2.74, 2.75, 2.6, 2.67, 2.74, 2.68, 2.81, 2.52, 2.56, 2.51, 2.61, 2.59, 2.66, 2.68, 2.23, 2.25, 2.26, 2.31, 2.35, 2.41, 2.32, 2.38, 2.36, 2.35, 2.47, 2.5, 2.46, 2.56, 2.57, 2.49, 2.45, 2.56, 2.54, 2.52, 2.51, 2.56, 2.46, 2.56, 2.49, 2.54, 2.52, 2.52, 2.46, 2.49, 2.52, 2.55, 2.53, 2.66, 2.54, 2.57, 2.53, 2.49, 2.57, 2.42, 2.58, 2.49, 2.55, 2.54, 2.5, 2.47], [4.69, 4.43, 4.61, 4.94, 5.27, 5.52, 5.8, 6.09, 3.11, 3.01, 3.02, 3.13, 3.0, 2.91, 2.97, 2.88, 2.91, 2.8, 2.83, 2.79, 2.75, 2.86, 2.84, 2.81, 2.86, 2.91, 2.69, 2.81, 2.86, 2.77, 2.82, 2.91, 2.56, 2.7, 2.76, 2.77, 2.48, 2.65, 2.63, 2.76, 2.8, 2.57, 2.53, 2.59, 2.58, 2.71, 2.69, 2.72, 2.22, 2.24, 2.26, 2.23, 2.32, 2.42, 2.35, 2.41, 2.41, 2.41, 2.42, 2.4, 2.36, 2.48, 2.53, 2.53, 2.46, 2.62, 2.54, 2.54, 2.51, 2.53, 2.49, 2.55, 2.58, 2.49, 2.62, 2.53, 2.58, 2.49, 2.46, 2.56, 2.44, 2.49, 2.53, 2.61, 2.51, 2.57, 2.51, 2.46, 2.48, 2.42, 2.46, 2.51, 2.48, 2.5], [4.64, 4.4, 4.63, 4.9, 5.15, 5.47, 5.94, 6.15, 3.08, 3.01, 3.04, 3.12, 3.01, 2.9, 2.91, 2.94, 2.97, 2.81, 2.83, 2.71, 2.83, 2.84, 2.79, 2.77, 2.84, 2.9, 2.73, 2.81, 2.83, 2.74, 2.93, 2.91, 2.67, 2.69, 2.73, 2.78, 2.52, 2.67, 2.65, 2.66, 2.71, 2.54, 2.5, 2.47, 2.55, 2.61, 2.55, 2.61, 2.19, 2.2, 2.28, 2.34, 2.29, 2.3, 2.28, 2.23, 2.31, 2.34, 2.39, 2.46, 2.47, 2.49, 2.55, 2.54, 2.55, 2.59, 2.5, 2.62, 2.52, 2.54, 2.6, 2.5, 2.5, 2.53, 2.54, 2.51, 2.45, 2.45, 2.5, 2.62, 2.55, 2.57, 2.62, 2.59, 2.58, 2.43, 2.58, 2.48, 2.47, 2.54, 2.51, 2.6, 2.55, 2.51], [4.64, 4.43, 4.54, 4.91, 5.28, 5.57, 5.9, 6.18, 3.17, 3.08, 3.04, 3.13, 3.08, 2.89, 2.85, 2.9, 2.9, 2.83, 2.9, 2.82, 2.87, 2.86, 2.88, 2.83, 2.82, 2.88, 2.71, 2.8, 2.84, 2.76, 2.85, 2.95, 2.68, 2.69, 2.72, 2.82, 2.52, 2.63, 2.68, 2.66, 2.72, 2.55, 2.59, 2.56, 2.6, 2.57, 2.5, 2.62, 2.35, 2.32, 2.33, 2.32, 2.35, 2.41, 2.36, 2.39, 2.41, 2.42, 2.48, 2.55, 2.46, 2.49, 2.51, 2.58, 2.53, 2.5, 2.47, 2.5, 2.5, 2.58, 2.46, 2.52, 2.53, 2.57, 2.52, 2.52, 2.53, 2.49, 2.51, 2.58, 2.52, 2.49, 2.53, 2.54, 2.44, 2.49, 2.51, 2.53, 2.51, 2.52, 2.57, 2.55, 2.52, 2.47], [4.66, 4.52, 4.67, 4.86, 5.18, 5.51, 5.88, 6.18, 3.18, 3.04, 3.05, 3.16, 3.03, 2.92, 2.9, 2.99, 2.93, 2.82, 2.72, 2.76, 2.82, 2.88, 2.84, 2.86, 2.88, 2.98, 2.76, 2.78, 2.78, 2.77, 2.84, 2.88, 2.69, 2.68, 2.75, 2.77, 2.6, 2.57, 2.65, 2.65, 2.72, 2.55, 2.57, 2.57, 2.6, 2.65, 2.72, 2.65, 2.22, 2.24, 2.28, 2.29, 2.3, 2.47, 2.36, 2.39, 2.42, 2.41, 2.41, 2.38, 2.4, 2.44, 2.55, 2.54, 2.6, 2.57, 2.5, 2.62, 2.48, 2.54, 2.54, 2.5, 2.52, 2.54, 2.48, 2.47, 2.52, 2.59, 2.51, 2.42, 2.59, 2.55, 2.56, 2.58, 2.62, 2.5, 2.54, 2.54, 2.47, 2.51, 2.56, 2.52, 2.5, 2.52], [4.71, 4.39, 4.68, 4.91, 5.26, 5.56, 5.9, 6.14, 3.13, 3.11, 3.06, 3.06, 3.07, 2.89, 2.89, 2.9, 2.94, 2.86, 2.82, 2.69, 2.84, 2.81, 2.86, 2.78, 2.86, 2.88, 2.75, 2.77, 2.75, 2.8, 2.9, 2.85, 2.69, 2.74, 2.79, 2.74, 2.59, 2.61, 2.64, 2.66, 2.77, 2.47, 2.5, 2.56, 2.57, 2.63, 2.61, 2.65, 2.22, 2.28, 2.24, 2.33, 2.29, 2.34, 2.33, 2.39, 2.33, 2.51, 2.47, 2.41, 2.4, 2.47, 2.48, 2.56, 2.53, 2.55, 2.48, 2.53, 2.45, 2.49, 2.51, 2.56, 2.49, 2.49, 2.44, 2.52, 2.51, 2.55, 2.56, 2.53, 2.54, 2.55, 2.49, 2.53, 2.53, 2.56, 2.59, 2.47, 2.49, 2.48, 2.49, 2.61, 2.51, 2.47], [4.76, 4.38, 4.64, 4.95, 5.3, 5.54, 5.87, 6.08, 3.09, 3.06, 3.06, 3.06, 3.07, 2.92, 2.96, 2.95, 2.93, 2.8, 2.87, 2.73, 2.82, 2.9, 2.69, 2.84, 2.84, 2.89, 2.68, 2.8, 2.87, 2.77, 2.8, 2.96, 2.6, 2.72, 2.76, 2.76, 2.58, 2.65, 2.73, 2.66, 2.7, 2.49, 2.54, 2.57, 2.56, 2.63, 2.62, 2.65, 2.27, 2.28, 2.32, 2.38, 2.29, 2.37, 2.41, 2.42, 2.51, 2.41, 2.44, 2.49, 2.47, 2.54, 2.44, 2.56, 2.58, 2.5, 2.55, 2.48, 2.49, 2.54, 2.54, 2.46, 2.51, 2.58, 2.56, 2.51, 2.58, 2.59, 2.5, 2.54, 2.52, 2.53, 2.53, 2.53, 2.55, 2.52, 2.56, 2.48, 2.61, 2.58, 2.48, 2.5, 2.5, 2.58], [4.65, 4.33, 4.61, 4.97, 5.16, 5.48, 5.91, 6.12, 3.09, 2.98, 3.02, 3.15, 3.07, 2.95, 2.96, 2.86, 2.9, 2.87, 2.84, 2.73, 2.83, 2.86, 2.8, 2.81, 2.86, 2.95, 2.77, 2.7, 2.79, 2.76, 2.85, 2.82, 2.64, 2.63, 2.75, 2.76, 2.6, 2.59, 2.66, 2.76, 2.65, 2.56, 2.57, 2.62, 2.65, 2.66, 2.63, 2.66, 2.29, 2.27, 2.3, 2.36, 2.37, 2.32, 2.36, 2.34, 2.41, 2.39, 2.48, 2.44, 2.53, 2.52, 2.55, 2.57, 2.51, 2.59, 2.5, 2.56, 2.51, 2.54, 2.47, 2.52, 2.49, 2.61, 2.51, 2.56, 2.5, 2.55, 2.48, 2.43, 2.53, 2.5, 2.51, 2.53, 2.56, 2.58, 2.5, 2.5, 2.48, 2.53, 2.53, 2.61, 2.56, 2.53], [4.68, 4.43, 4.67, 4.92, 5.24, 5.5, 5.9, 6.08, 3.14, 3.09, 3.11, 3.05, 3.03, 2.89, 2.92, 2.85, 2.86, 2.93, 2.88, 2.74, 2.81, 2.89, 2.77, 2.8, 2.85, 2.97, 2.79, 2.78, 2.88, 2.78, 2.81, 2.9, 2.63, 2.74, 2.75, 2.75, 2.55, 2.65, 2.62, 2.64, 2.78, 2.5, 2.56, 2.51, 2.58, 2.64, 2.68, 2.76, 2.28, 2.26, 2.37, 2.29, 2.44, 2.31, 2.4, 2.35, 2.35, 2.42, 2.38, 2.45, 2.47, 2.5, 2.53, 2.51, 2.44, 2.55, 2.56, 2.54, 2.57, 2.58, 2.53, 2.6, 2.57, 2.5, 2.55, 2.53, 2.53, 2.47, 2.55, 2.52, 2.54, 2.57, 2.53, 2.53, 2.47, 2.54, 2.55, 2.59, 2.58, 2.63, 2.56, 2.57, 2.52, 2.56], [4.66, 4.44, 4.7, 4.93, 5.26, 5.52, 5.86, 6.15, 3.14, 3.09, 3.06, 3.14, 3.06, 2.94, 2.86, 2.88, 3.01, 2.86, 2.84, 2.71, 2.78, 2.82, 2.75, 2.77, 2.8, 2.94, 2.74, 2.8, 2.85, 2.85, 2.92, 2.88, 2.68, 2.71, 2.73, 2.75, 2.71, 2.58, 2.62, 2.77, 2.74, 2.5, 2.56, 2.55, 2.61, 2.61, 2.64, 2.63, 2.29, 2.32, 2.35, 2.34, 2.38, 2.35, 2.42, 2.46, 2.43, 2.42, 2.5, 2.42, 2.49, 2.47, 2.46, 2.55, 2.46, 2.55, 2.52, 2.61, 2.56, 2.52, 2.48, 2.47, 2.5, 2.46, 2.54, 2.56, 2.68, 2.55, 2.51, 2.52, 2.57, 2.53, 2.58, 2.52, 2.52, 2.47, 2.56, 2.56, 2.46, 2.47, 2.58, 2.53, 2.57, 2.65], [4.77, 4.46, 4.71, 4.88, 5.25, 5.58, 5.93, 6.1, 3.08, 3.06, 3.07, 3.11, 3.03, 2.91, 2.98, 2.97, 2.9, 2.84, 2.85, 2.75, 2.85, 2.91, 2.74, 2.76, 2.78, 2.86, 2.75, 2.8, 2.85, 2.8, 2.81, 2.92, 2.65, 2.7, 2.76, 2.86, 2.63, 2.64, 2.65, 2.77, 2.74, 2.51, 2.51, 2.54, 2.61, 2.67, 2.66, 2.63, 2.23, 2.27, 2.29, 2.39, 2.4, 2.36, 2.4, 2.42, 2.48, 2.39, 2.47, 2.48, 2.51, 2.5, 2.52, 2.55, 2.54, 2.5, 2.55, 2.43, 2.54, 2.6, 2.53, 2.53, 2.58, 2.6, 2.53, 2.57, 2.49, 2.48, 2.52, 2.51, 2.54, 2.47, 2.59, 2.6, 2.54, 2.49, 2.56, 2.51, 2.48, 2.49, 2.49, 2.53, 2.48, 2.5], [4.68, 4.39, 4.7, 4.94, 5.23, 5.52, 5.93, 6.24, 3.14, 3.03, 3.04, 3.12, 3.07, 2.88, 2.88, 2.97, 2.88, 2.83, 2.89, 2.74, 2.89, 2.94, 2.78, 2.8, 2.87, 2.92, 2.76, 2.81, 2.8, 2.78, 2.83, 2.88, 2.67, 2.66, 2.72, 2.72, 2.6, 2.66, 2.66, 2.75, 2.78, 2.56, 2.61, 2.51, 2.62, 2.64, 2.62, 2.67, 2.21, 2.3, 2.28, 2.36, 2.38, 2.39, 2.39, 2.36, 2.33, 2.51, 2.5, 2.42, 2.44, 2.52, 2.54, 2.53, 2.48, 2.55, 2.54, 2.56, 2.57, 2.56, 2.49, 2.6, 2.61, 2.52, 2.56, 2.55, 2.48, 2.55, 2.51, 2.6, 2.56, 2.51, 2.55, 2.56, 2.52, 2.58, 2.55, 2.49, 2.53, 2.52, 2.56, 2.54, 2.54, 2.53], [4.71, 4.46, 4.62, 4.86, 5.31, 5.46, 5.93, 6.21, 3.14, 3.09, 3.15, 3.14, 3.1, 2.91, 2.94, 2.93, 2.89, 2.83, 2.86, 2.79, 2.81, 2.91, 2.8, 2.86, 2.9, 2.87, 2.74, 2.8, 2.88, 2.79, 2.8, 2.87, 2.68, 2.76, 2.75, 2.71, 2.61, 2.65, 2.67, 2.69, 2.73, 2.58, 2.52, 2.63, 2.6, 2.66, 2.7, 2.63, 2.29, 2.3, 2.27, 2.35, 2.35, 2.39, 2.35, 2.4, 2.36, 2.39, 2.42, 2.41, 2.51, 2.55, 2.53, 2.59, 2.59, 2.54, 2.49, 2.49, 2.49, 2.52, 2.6, 2.54, 2.54, 2.5, 2.49, 2.52, 2.48, 2.62, 2.58, 2.6, 2.59, 2.56, 2.62, 2.54, 2.54, 2.49, 2.51, 2.42, 2.59, 2.53, 2.49, 2.59, 2.55, 2.5], [4.69, 4.42, 4.73, 4.99, 5.3, 5.51, 5.88, 6.17, 3.15, 3.08, 3.06, 3.17, 3.09, 2.88, 2.91, 2.92, 3.0, 2.93, 2.82, 2.74, 2.8, 2.89, 2.8, 2.79, 2.9, 2.93, 2.75, 2.78, 2.86, 2.79, 2.84, 2.92, 2.58, 2.67, 2.77, 2.85, 2.62, 2.66, 2.75, 2.74, 2.72, 2.56, 2.51, 2.55, 2.58, 2.56, 2.7, 2.62, 2.26, 2.28, 2.33, 2.37, 2.38, 2.38, 2.39, 2.36, 2.49, 2.37, 2.45, 2.47, 2.52, 2.5, 2.49, 2.58, 2.61, 2.55, 2.51, 2.56, 2.5, 2.53, 2.59, 2.53, 2.49, 2.58, 2.52, 2.49, 2.53, 2.53, 2.61, 2.58, 2.61, 2.49, 2.53, 2.61, 2.52, 2.51, 2.5, 2.53, 2.52, 2.55, 2.48, 2.5, 2.59, 2.62], [4.8, 4.41, 4.63, 4.95, 5.17, 5.53, 5.89, 6.23, 3.1, 3.03, 3.1, 3.12, 3.09, 3.03, 2.95, 2.95, 2.88, 2.91, 2.83, 2.79, 2.82, 2.84, 2.73, 2.81, 2.86, 2.9, 2.67, 2.78, 2.92, 2.81, 2.88, 2.91, 2.7, 2.72, 2.82, 2.79, 2.6, 2.69, 2.71, 2.69, 2.73, 2.55, 2.52, 2.59, 2.55, 2.56, 2.66, 2.69, 2.24, 2.28, 2.33, 2.36, 2.4, 2.48, 2.41, 2.45, 2.46, 2.39, 2.46, 2.49, 2.53, 2.43, 2.52, 2.48, 2.49, 2.62, 2.51, 2.55, 2.59, 2.66, 2.6, 2.62, 2.66, 2.6, 2.55, 2.5, 2.53, 2.53, 2.48, 2.56, 2.52, 2.47, 2.63, 2.53, 2.54, 2.51, 2.5, 2.56, 2.61, 2.61, 2.55, 2.53, 2.59, 2.57], [4.72, 4.42, 4.65, 4.87, 5.24, 5.49, 5.82, 6.1, 3.08, 3.1, 3.15, 3.21, 3.15, 3.01, 2.92, 2.98, 3.0, 2.93, 2.84, 2.78, 2.81, 2.92, 2.78, 2.79, 2.9, 2.89, 2.76, 2.85, 2.88, 2.86, 2.92, 2.96, 2.68, 2.67, 2.71, 2.82, 2.62, 2.66, 2.67, 2.73, 2.68, 2.48, 2.5, 2.55, 2.59, 2.64, 2.57, 2.6, 2.28, 2.31, 2.28, 2.29, 2.37, 2.33, 2.38, 2.41, 2.45, 2.41, 2.43, 2.52, 2.53, 2.53, 2.55, 2.56, 2.52, 2.52, 2.58, 2.62, 2.61, 2.54, 2.57, 2.58, 2.5, 2.53, 2.55, 2.6, 2.62, 2.55, 2.56, 2.51, 2.52, 2.55, 2.45, 2.56, 2.52, 2.57, 2.58, 2.62, 2.49, 2.59, 2.6, 2.53, 2.56, 2.52]]

# %%
yr = range(15,1430,15)
xr = range(4,380,4)

result = [[3.99, 3.61, 3.41, 3.36, 3.3, 3.29, 3.14, 3.19, 3.23, 3.23, 3.2, 3.17, 3.37, 3.11, 2.97, 2.9, 2.79, 2.74, 2.72, 2.73, 2.68, 2.74, 2.69, 2.64, 2.66, 2.67, 2.45, 2.52, 2.6, 2.69, 2.72, 2.69, 2.48, 2.55, 2.57, 2.65, 2.49, 2.57, 2.57, 2.65, 2.78, 2.4, 2.37, 2.42, 2.44, 2.5, 2.52, 2.5, 2.39, 2.48, 2.48, 2.43, 2.5, 2.79, 2.65, 2.41, 2.71, 2.64, 2.33, 2.25, 2.29, 2.3, 2.35, 2.32, 2.56, 2.38, 2.43, 2.4, 2.43, 2.41, 2.42, 2.39, 2.39, 2.39, 2.3, 2.47, 2.35, 2.41, 2.41, 2.46, 2.38, 2.37, 2.36, 2.35, 2.36, 2.36, 2.45, 2.37, 2.43, 2.37, 2.46, 2.48, 2.46, 2.4], [3.52, 3.54, 3.42, 3.25, 3.28, 3.12, 3.07, 3.18, 3.05, 3.01, 2.9, 2.93, 2.96, 2.97, 2.93, 2.92, 2.96, 2.69, 2.8, 2.67, 2.63, 2.75, 2.61, 2.6, 2.67, 2.82, 2.64, 2.6, 2.71, 2.64, 2.6, 2.73, 2.39, 2.63, 2.49, 2.5, 2.57, 2.55, 2.72, 2.65, 2.73, 2.41, 2.33, 2.42, 2.45, 2.54, 2.43, 2.47, 2.36, 2.41, 2.54, 2.48, 2.43, 2.54, 2.56, 2.51, 2.63, 2.63, 2.32, 2.32, 2.41, 2.32, 2.4, 2.33, 2.35, 2.39, 2.36, 2.47, 2.42, 2.31, 2.51, 2.51, 2.35, 2.45, 2.48, 2.45, 2.41, 2.29, 2.3, 2.38, 2.38, 2.45, 2.41, 2.65, 2.49, 2.27, 2.36, 2.39, 2.42, 2.41, 2.45, 2.37, 2.38, 2.5], [3.56, 3.58, 3.34, 3.31, 3.34, 3.11, 3.11, 3.13, 2.97, 2.99, 2.97, 2.93, 2.89, 2.9, 2.88, 2.91, 2.69, 2.82, 2.68, 2.66, 2.66, 2.77, 2.69, 2.72, 2.79, 2.78, 2.6, 2.68, 2.81, 2.64, 2.65, 2.68, 2.54, 2.58, 2.51, 2.54, 2.53, 2.53, 2.48, 2.47, 2.57, 2.48, 2.47, 2.53, 2.48, 2.54, 2.57, 2.56, 2.17, 2.17, 2.21, 2.29, 2.3, 2.35, 2.55, 2.54, 2.64, 2.64, 2.44, 2.45, 2.43, 2.57, 2.35, 2.51, 2.4, 2.39, 2.66, 2.42, 2.43, 2.47, 2.34, 2.43, 2.4, 2.54, 2.44, 2.38, 2.28, 2.35, 2.29, 2.46, 2.36, 2.39, 2.4, 2.4, 2.35, 2.45, 2.42, 2.52, 2.44, 2.4, 2.4, 2.34, 2.36, 2.42], [3.46, 3.37, 3.41, 3.2, 3.29, 3.08, 3.09, 3.13, 2.95, 2.99, 2.9, 2.93, 2.95, 2.95, 2.98, 2.97, 2.82, 2.86, 2.78, 2.64, 2.77, 2.72, 2.61, 2.7, 2.71, 2.64, 2.65, 2.71, 2.69, 2.6, 2.63, 2.69, 2.41, 2.56, 2.44, 2.51, 2.43, 2.53, 2.55, 2.57, 2.59, 2.39, 2.45, 2.44, 2.52, 2.45, 2.48, 2.51, 2.15, 2.18, 2.19, 2.16, 2.26, 2.19, 2.29, 2.38, 2.27, 2.29, 2.29, 2.3, 2.25, 2.37, 2.43, 2.43, 2.41, 2.39, 2.42, 2.43, 2.44, 2.43, 2.32, 2.39, 2.41, 2.39, 2.39, 2.3, 2.37, 2.4, 2.34, 2.29, 2.38, 2.39, 2.43, 2.4, 2.5, 2.47, 2.32, 2.36, 2.36, 2.43, 2.36, 2.36, 2.38, 2.42], [3.43, 3.42, 3.26, 3.22, 3.22, 3.02, 3.24, 3.12, 3.0, 3.05, 3.0, 3.03, 2.96, 2.96, 2.94, 2.86, 2.81, 2.83, 2.72, 2.68, 2.62, 2.71, 2.59, 2.64, 2.69, 2.71, 2.61, 2.66, 2.75, 2.62, 2.68, 2.58, 2.5, 2.43, 2.49, 2.63, 2.52, 2.53, 2.47, 2.6, 2.6, 2.48, 2.37, 2.47, 2.52, 2.5, 2.56, 2.6, 2.19, 2.22, 2.21, 2.22, 2.24, 2.3, 2.27, 2.28, 2.27, 2.29, 2.28, 2.35, 2.32, 2.34, 2.34, 2.32, 2.38, 2.38, 2.43, 2.41, 2.29, 2.31, 2.43, 2.37, 2.41, 2.37, 2.38, 2.41, 2.4, 2.32, 2.4, 2.36, 2.4, 2.29, 2.36, 2.36, 2.38, 2.37, 2.39, 2.36, 2.34, 2.38, 2.27, 2.34, 2.31, 2.4], [3.46, 3.4, 3.28, 3.23, 3.18, 3.0, 3.12, 3.07, 2.91, 2.94, 2.86, 2.91, 2.91, 2.88, 2.85, 2.67, 2.84, 2.8, 2.72, 2.6, 2.59, 2.74, 2.58, 2.63, 2.69, 2.75, 2.53, 2.63, 2.69, 2.59, 2.61, 2.55, 2.42, 2.47, 2.53, 2.54, 2.38, 2.45, 2.47, 2.51, 2.34, 2.33, 2.38, 2.41, 2.41, 2.43, 2.47, 2.56, 2.12, 2.13, 2.14, 2.21, 2.22, 2.27, 2.28, 2.22, 2.27, 2.37, 2.29, 2.31, 2.36, 2.34, 2.31, 2.33, 2.3, 2.36, 2.38, 2.3, 2.26, 2.33, 2.44, 2.38, 2.28, 2.3, 2.36, 2.29, 2.32, 2.4, 2.41, 2.37, 2.48, 2.37, 2.37, 2.3, 2.34, 2.46, 2.36, 2.35, 2.28, 2.28, 2.29, 2.36, 2.37, 2.38], [3.84, 3.38, 3.23, 3.13, 3.04, 3.03, 3.13, 2.96, 2.93, 2.94, 3.01, 2.93, 2.95, 2.8, 2.84, 2.71, 2.77, 2.75, 2.7, 2.61, 2.64, 2.74, 2.51, 2.63, 2.73, 2.78, 2.57, 2.61, 2.69, 2.6, 2.6, 2.66, 2.51, 2.53, 2.54, 2.55, 2.28, 2.5, 2.37, 2.35, 2.6, 2.36, 2.47, 2.42, 2.45, 2.61, 2.53, 2.6, 2.19, 2.23, 2.23, 2.21, 2.27, 2.21, 2.23, 2.23, 2.23, 2.34, 2.28, 2.28, 2.24, 2.3, 2.34, 2.37, 2.39, 2.35, 2.32, 2.37, 2.38, 2.35, 2.34, 2.41, 2.36, 2.42, 2.38, 2.41, 2.36, 2.35, 2.33, 2.34, 2.34, 2.31, 2.34, 2.38, 2.37, 2.32, 2.29, 2.43, 2.38, 2.34, 2.32, 2.34, 2.35, 2.33], [3.9, 3.46, 3.31, 3.24, 3.07, 3.05, 3.04, 2.95, 2.96, 2.86, 2.84, 2.91, 2.87, 2.71, 2.86, 2.84, 2.78, 2.78, 2.76, 2.66, 2.67, 2.74, 2.51, 2.62, 2.66, 2.73, 2.62, 2.57, 2.67, 2.63, 2.65, 2.71, 2.48, 2.49, 2.46, 2.56, 2.53, 2.5, 2.56, 2.52, 2.54, 2.38, 2.39, 2.4, 2.41, 2.44, 2.47, 2.48, 2.1, 2.1, 2.11, 2.18, 2.12, 2.14, 2.19, 2.22, 2.2, 2.28, 2.24, 2.27, 2.34, 2.32, 2.28, 2.41, 2.41, 2.28, 2.34, 2.28, 2.44, 2.31, 2.35, 2.32, 2.41, 2.36, 2.36, 2.38, 2.31, 2.38, 2.37, 2.38, 2.32, 2.44, 2.35, 2.44, 2.37, 2.41, 2.35, 2.39, 2.35, 2.38, 2.38, 2.32, 2.37, 2.37], [3.83, 3.4, 3.29, 3.16, 3.05, 3.03, 3.13, 2.98, 3.01, 2.92, 2.94, 2.98, 2.88, 2.71, 2.77, 2.76, 2.76, 2.77, 2.65, 2.6, 2.67, 2.74, 2.55, 2.53, 2.6, 2.69, 2.59, 2.63, 2.68, 2.64, 2.73, 2.73, 2.46, 2.47, 2.56, 2.61, 2.44, 2.48, 2.49, 2.54, 2.61, 2.35, 2.36, 2.35, 2.43, 2.46, 2.46, 2.51, 2.14, 2.23, 2.15, 2.16, 2.31, 2.23, 2.27, 2.34, 2.25, 2.28, 2.26, 2.26, 2.32, 2.26, 2.38, 2.36, 2.32, 2.31, 2.36, 2.35, 2.24, 2.32, 2.33, 2.37, 2.27, 2.37, 2.35, 2.37, 2.39, 2.39, 2.48, 2.38, 2.34, 2.28, 2.27, 2.33, 2.42, 2.34, 2.29, 2.43, 2.3, 2.33, 2.43, 2.46, 2.34, 2.41], [3.8, 3.39, 3.31, 3.25, 3.07, 3.07, 3.1, 2.95, 2.91, 2.84, 2.88, 2.87, 2.91, 2.72, 2.74, 2.68, 2.76, 2.7, 2.69, 2.51, 2.65, 2.7, 2.52, 2.62, 2.66, 2.78, 2.56, 2.7, 2.64, 2.64, 2.7, 2.7, 2.46, 2.52, 2.59, 2.6, 2.42, 2.44, 2.48, 2.46, 2.62, 2.32, 2.38, 2.38, 2.42, 2.44, 2.5, 2.42, 2.13, 2.12, 2.15, 2.19, 2.35, 2.38, 2.59, 2.25, 2.31, 2.32, 2.29, 2.29, 2.37, 2.35, 2.29, 2.34, 2.45, 2.42, 2.43, 2.41, 2.35, 2.34, 2.47, 2.4, 2.46, 2.41, 2.42, 2.47, 2.35, 2.34, 2.39, 2.44, 2.39, 2.33, 2.39, 2.4, 2.4, 2.33, 2.51, 2.45, 2.4, 2.37, 2.38, 2.49, 2.44, 2.48], [3.91, 3.43, 3.38, 3.28, 3.09, 2.98, 3.16, 2.99, 2.96, 2.9, 2.88, 3.02, 2.96, 2.76, 2.77, 2.85, 2.81, 2.76, 2.76, 2.64, 2.71, 2.77, 2.63, 2.67, 2.72, 2.82, 2.64, 2.62, 2.67, 2.66, 2.75, 2.77, 2.5, 2.55, 2.62, 2.66, 2.5, 2.52, 2.5, 2.62, 2.55, 2.37, 2.45, 2.48, 2.45, 2.51, 2.54, 2.56, 2.11, 2.15, 2.17, 2.13, 2.21, 2.24, 2.23, 2.22, 2.28, 2.26, 2.37, 2.35, 2.33, 2.39, 2.4, 2.42, 2.42, 2.39, 2.36, 2.28, 2.37, 2.45, 2.47, 2.39, 2.36, 2.4, 2.35, 2.37, 2.38, 2.37, 2.32, 2.37, 2.37, 2.44, 2.45, 2.47, 2.37, 2.43, 2.39, 2.41, 2.39, 2.36, 2.39, 2.38, 2.43, 2.39], [3.92, 3.4, 3.27, 3.16, 3.1, 3.04, 3.13, 3.02, 3.02, 2.95, 2.97, 2.97, 2.99, 2.81, 2.82, 2.73, 2.76, 2.65, 2.66, 2.5, 2.68, 2.78, 2.59, 2.66, 2.66, 2.85, 2.59, 2.64, 2.69, 2.77, 2.77, 2.71, 2.56, 2.55, 2.6, 2.71, 2.51, 2.52, 2.49, 2.54, 2.55, 2.4, 2.4, 2.45, 2.44, 2.5, 2.53, 2.56, 2.08, 2.21, 2.2, 2.29, 2.14, 2.25, 2.28, 2.21, 2.21, 2.21, 2.3, 2.26, 2.27, 2.38, 2.35, 2.36, 2.37, 2.43, 2.33, 2.36, 2.33, 2.29, 2.27, 2.43, 2.45, 2.37, 2.29, 2.36, 2.42, 2.38, 2.41, 2.32, 2.36, 2.36, 2.39, 2.36, 2.37, 2.4, 2.41, 2.39, 2.34, 2.34, 2.37, 2.37, 2.35, 2.36], [3.86, 3.41, 3.35, 3.22, 3.17, 3.01, 3.09, 2.98, 2.94, 2.86, 2.89, 2.92, 2.91, 2.75, 2.77, 2.76, 2.74, 2.66, 2.66, 2.65, 2.68, 2.76, 2.53, 2.65, 2.73, 2.71, 2.57, 2.57, 2.62, 2.63, 2.76, 2.7, 2.48, 2.53, 2.55, 2.5, 2.5, 2.39, 2.57, 2.58, 2.59, 2.36, 2.35, 2.45, 2.45, 2.45, 2.47, 2.5, 2.05, 2.18, 2.11, 2.2, 2.12, 2.23, 2.14, 2.26, 2.25, 2.31, 2.28, 2.4, 2.25, 2.31, 2.36, 2.34, 2.35, 2.43, 2.4, 2.44, 2.34, 2.41, 2.32, 2.31, 2.36, 2.39, 2.31, 2.44, 2.35, 2.35, 2.28, 2.45, 2.34, 2.33, 2.38, 2.38, 2.38, 2.32, 2.34, 2.41, 2.38, 2.4, 2.33, 2.41, 2.45, 2.4], [3.86, 4.2, 3.27, 3.23, 3.1, 3.09, 3.03, 2.97, 2.88, 2.87, 2.84, 2.95, 2.93, 2.8, 2.77, 2.79, 2.8, 2.78, 2.72, 2.56, 2.71, 2.72, 2.55, 2.66, 2.71, 2.76, 2.5, 2.56, 2.71, 2.63, 2.68, 2.75, 2.47, 2.57, 2.61, 2.62, 2.41, 2.47, 2.49, 2.57, 2.56, 2.35, 2.37, 2.37, 2.43, 2.43, 2.47, 2.48, 2.11, 2.16, 2.18, 2.1, 2.19, 2.22, 2.27, 2.23, 2.27, 2.3, 2.26, 2.31, 2.26, 2.32, 2.3, 2.33, 2.31, 2.3, 2.33, 2.31, 2.36, 2.35, 2.37, 2.39, 2.42, 2.37, 2.3, 2.35, 2.3, 2.4, 2.38, 2.34, 2.43, 2.38, 2.35, 2.4, 2.3, 2.36, 2.4, 2.38, 2.33, 2.4, 2.37, 2.33, 2.42, 2.37], [3.8, 4.1, 3.25, 3.15, 3.09, 3.07, 3.15, 3.08, 2.97, 2.92, 2.91, 2.97, 2.9, 2.73, 2.76, 2.75, 2.78, 2.68, 2.74, 2.53, 2.69, 2.68, 2.55, 2.58, 2.75, 2.83, 2.62, 2.65, 2.73, 2.65, 2.74, 2.67, 2.45, 2.58, 2.58, 2.51, 2.51, 2.46, 2.52, 2.51, 2.69, 2.37, 2.28, 2.4, 2.42, 2.51, 2.48, 2.48, 2.08, 2.09, 2.13, 2.19, 2.2, 2.27, 2.2, 2.23, 2.26, 2.27, 2.23, 2.27, 2.36, 2.29, 2.37, 2.39, 2.47, 2.4, 2.3, 2.36, 2.27, 2.34, 2.42, 2.41, 2.46, 2.38, 2.36, 2.44, 2.41, 2.4, 2.39, 2.33, 2.35, 2.35, 2.39, 2.39, 2.34, 2.36, 2.45, 2.32, 2.38, 2.4, 2.32, 2.39, 2.45, 2.42], [3.97, 4.22, 3.29, 3.18, 3.08, 3.02, 3.15, 3.0, 2.86, 2.9, 2.89, 2.93, 2.97, 2.78, 2.73, 2.73, 2.71, 2.74, 2.66, 2.58, 2.65, 2.78, 2.58, 2.67, 2.68, 2.74, 2.59, 2.59, 2.69, 2.7, 2.65, 2.68, 2.51, 2.57, 2.67, 2.56, 2.5, 2.45, 2.51, 2.55, 2.66, 2.41, 2.33, 2.44, 2.41, 2.44, 2.47, 2.47, 2.07, 2.11, 2.06, 2.09, 2.18, 2.24, 2.18, 2.23, 2.24, 2.31, 2.27, 2.36, 2.38, 2.24, 2.34, 2.4, 2.41, 2.36, 2.34, 2.4, 2.39, 2.38, 2.39, 2.37, 2.43, 2.42, 2.35, 2.38, 2.4, 2.4, 2.37, 2.4, 2.41, 2.43, 2.34, 2.33, 2.35, 2.36, 2.42, 2.34, 2.35, 2.41, 2.44, 2.41, 2.4, 2.36], [3.83, 4.16, 3.26, 3.22, 3.09, 3.06, 3.05, 3.01, 2.93, 2.87, 2.87, 2.96, 2.89, 2.8, 2.74, 2.8, 2.83, 2.81, 2.73, 2.59, 2.71, 2.73, 2.57, 2.59, 2.73, 2.73, 2.53, 2.65, 2.66, 2.64, 2.67, 2.8, 2.54, 2.5, 2.57, 2.67, 2.46, 2.46, 2.52, 2.55, 2.57, 2.33, 2.39, 2.36, 2.38, 2.43, 2.48, 2.51, 2.11, 2.17, 2.07, 2.11, 2.12, 2.2, 2.21, 2.21, 2.18, 2.38, 2.25, 2.32, 2.36, 2.43, 2.38, 2.44, 2.36, 2.41, 2.37, 2.38, 2.38, 2.39, 2.33, 2.37, 2.34, 2.38, 2.37, 2.33, 2.37, 2.31, 2.39, 2.42, 2.39, 2.4, 2.37, 2.45, 2.43, 2.33, 2.4, 2.32, 2.4, 2.26, 2.31, 2.35, 2.36, 2.42], [3.86, 4.13, 3.27, 3.29, 3.16, 3.07, 3.16, 3.05, 2.92, 2.85, 2.9, 2.9, 2.86, 2.79, 2.69, 2.76, 2.8, 2.7, 2.66, 2.59, 2.65, 2.69, 2.57, 2.63, 2.77, 2.73, 2.62, 2.68, 2.7, 2.75, 2.67, 2.73, 2.54, 2.5, 2.6, 2.66, 2.38, 2.52, 2.5, 2.52, 2.62, 2.36, 2.4, 2.42, 2.43, 2.42, 2.5, 2.57, 2.12, 2.17, 2.18, 2.17, 2.14, 2.15, 2.18, 2.2, 2.26, 2.29, 2.25, 2.23, 2.36, 2.33, 2.3, 2.35, 2.34, 2.41, 2.35, 2.41, 2.44, 2.37, 2.44, 2.44, 2.43, 2.45, 2.41, 2.4, 2.35, 2.4, 2.39, 2.37, 2.4, 2.29, 2.41, 2.37, 2.39, 2.39, 2.35, 2.43, 2.4, 2.41, 2.43, 2.43, 2.41, 2.39], [3.88, 4.16, 3.26, 3.21, 3.11, 3.04, 3.08, 2.99, 2.88, 2.84, 2.86, 2.96, 2.92, 2.8, 2.81, 2.79, 2.75, 2.72, 2.66, 2.61, 2.65, 2.7, 2.6, 2.65, 2.7, 2.75, 2.62, 2.65, 2.64, 2.67, 2.72, 2.71, 2.42, 2.52, 2.64, 2.7, 2.44, 2.51, 2.53, 2.6, 2.57, 2.36, 2.37, 2.47, 2.47, 2.54, 2.47, 2.49, 2.08, 2.12, 2.09, 2.25, 2.17, 2.25, 2.22, 2.22, 2.29, 2.35, 2.33, 2.32, 2.38, 2.28, 2.4, 2.3, 2.33, 2.32, 2.42, 2.4, 2.33, 2.39, 2.38, 2.42, 2.41, 2.38, 2.36, 2.36, 2.3, 2.36, 2.39, 2.44, 2.45, 2.4, 2.43, 2.49, 2.37, 2.38, 2.36, 2.32, 2.38, 2.43, 2.4, 2.31, 2.45, 2.37], [3.88, 4.15, 3.28, 3.18, 3.14, 3.07, 3.18, 3.08, 2.92, 2.84, 2.9, 2.97, 2.91, 2.76, 2.7, 2.76, 2.77, 2.7, 2.68, 2.54, 2.63, 2.72, 2.5, 2.69, 2.73, 2.78, 2.69, 2.7, 2.71, 2.71, 2.67, 2.83, 2.51, 2.57, 2.51, 2.54, 2.44, 2.49, 2.43, 2.52, 2.59, 2.32, 2.38, 2.39, 2.44, 2.43, 2.53, 2.6, 2.16, 2.09, 2.21, 2.22, 2.2, 2.22, 2.21, 2.29, 2.29, 2.3, 2.38, 2.24, 2.25, 2.36, 2.37, 2.42, 2.39, 2.39, 2.36, 2.36, 2.4, 2.35, 2.45, 2.4, 2.42, 2.33, 2.4, 2.41, 2.34, 2.49, 2.37, 2.3, 2.31, 2.46, 2.37, 2.36, 2.41, 2.32, 2.41, 2.39, 2.33, 2.4, 2.36, 2.39, 2.45, 2.37], [3.95, 4.25, 4.44, 3.19, 3.08, 3.08, 3.1, 3.0, 2.91, 2.96, 2.84, 2.99, 2.87, 2.72, 2.78, 2.79, 2.8, 2.78, 2.71, 2.63, 2.66, 2.73, 2.63, 2.68, 2.69, 2.75, 2.59, 2.65, 2.68, 2.64, 2.75, 2.8, 2.51, 2.49, 2.59, 2.6, 2.47, 2.5, 2.52, 2.56, 2.64, 2.43, 2.39, 2.41, 2.43, 2.42, 2.45, 2.48, 2.12, 2.16, 2.19, 2.14, 2.25, 2.25, 2.23, 2.29, 2.26, 2.28, 2.32, 2.34, 2.32, 2.42, 2.46, 2.4, 2.38, 2.39, 2.37, 2.43, 2.34, 2.4, 2.41, 2.37, 2.48, 2.37, 2.37, 2.35, 2.43, 2.37, 2.29, 2.36, 2.4, 2.36, 2.32, 2.34, 2.41, 2.37, 2.43, 2.47, 2.43, 2.36, 2.34, 2.41, 2.38, 2.36], [3.85, 4.19, 4.51, 3.25, 3.13, 3.12, 3.16, 3.01, 2.91, 2.92, 2.88, 2.99, 2.96, 2.77, 2.77, 2.72, 2.76, 2.69, 2.61, 2.6, 2.67, 2.66, 2.61, 2.65, 2.75, 2.8, 2.61, 2.69, 2.75, 2.65, 2.68, 2.69, 2.49, 2.57, 2.6, 2.59, 2.42, 2.5, 2.54, 2.57, 2.58, 2.38, 2.37, 2.34, 2.53, 2.47, 2.53, 2.61, 2.06, 2.25, 2.16, 2.16, 2.21, 2.21, 2.26, 2.29, 2.22, 2.27, 2.33, 2.35, 2.36, 2.35, 2.34, 2.32, 2.47, 2.39, 2.41, 2.43, 2.41, 2.39, 2.41, 2.45, 2.37, 2.34, 2.41, 2.37, 2.35, 2.39, 2.41, 2.37, 2.36, 2.33, 2.4, 2.35, 2.36, 2.38, 2.39, 2.42, 2.43, 2.31, 2.42, 2.39, 2.4, 2.41], [3.88, 4.22, 4.45, 3.15, 3.09, 2.99, 3.1, 3.08, 2.99, 2.86, 2.98, 2.96, 2.92, 2.71, 2.74, 2.74, 2.78, 2.73, 2.71, 2.64, 2.67, 2.69, 2.61, 2.69, 2.74, 2.78, 2.61, 2.65, 2.71, 2.67, 2.72, 2.77, 2.52, 2.59, 2.56, 2.54, 2.38, 2.37, 2.59, 2.63, 2.65, 2.35, 2.4, 2.42, 2.44, 2.47, 2.46, 2.45, 2.14, 2.12, 2.12, 2.21, 2.26, 2.22, 2.24, 2.22, 2.24, 2.32, 2.33, 2.35, 2.34, 2.42, 2.37, 2.34, 2.4, 2.4, 2.39, 2.39, 2.45, 2.38, 2.38, 2.33, 2.39, 2.33, 2.4, 2.37, 2.37, 2.42, 2.43, 2.31, 2.34, 2.46, 2.37, 2.4, 2.48, 2.43, 2.44, 2.4, 2.43, 2.34, 2.47, 2.42, 2.37, 2.38], [3.86, 4.15, 4.5, 3.24, 3.1, 3.08, 3.04, 3.04, 2.92, 2.89, 2.9, 3.05, 2.96, 2.73, 2.76, 2.75, 2.76, 2.66, 2.63, 2.57, 2.68, 2.73, 2.61, 2.59, 2.73, 2.76, 2.6, 2.66, 2.72, 2.65, 2.74, 2.84, 2.5, 2.57, 2.62, 2.69, 2.53, 2.56, 2.64, 2.54, 2.6, 2.36, 2.47, 2.35, 2.5, 2.46, 2.45, 2.51, 2.17, 2.12, 2.21, 2.13, 2.21, 2.23, 2.31, 2.28, 2.29, 2.34, 2.33, 2.34, 2.33, 2.32, 2.38, 2.39, 2.56, 2.38, 2.43, 2.38, 2.42, 2.37, 2.39, 2.41, 2.3, 2.36, 2.46, 2.43, 2.36, 2.46, 2.41, 2.32, 2.42, 2.4, 2.34, 2.43, 2.42, 2.34, 2.38, 2.37, 2.45, 2.33, 2.38, 2.34, 2.51, 2.32], [3.87, 4.18, 4.41, 3.24, 3.14, 3.09, 3.19, 3.08, 2.96, 2.88, 2.84, 2.92, 2.9, 2.77, 2.7, 2.77, 2.72, 2.74, 2.65, 2.64, 2.68, 2.66, 2.59, 2.63, 2.72, 2.87, 2.56, 2.68, 2.78, 2.68, 2.74, 2.73, 2.5, 2.55, 2.65, 2.64, 2.49, 2.52, 2.56, 2.53, 2.64, 2.32, 2.41, 2.38, 2.55, 2.46, 2.43, 2.51, 2.15, 2.14, 2.18, 2.18, 2.28, 2.17, 2.23, 2.3, 2.28, 2.34, 2.37, 2.3, 2.37, 2.32, 2.39, 2.36, 2.4, 2.39, 2.38, 2.36, 2.34, 2.37, 2.31, 2.47, 2.36, 2.42, 2.46, 2.39, 2.46, 2.4, 2.41, 2.4, 2.37, 2.46, 2.42, 2.4, 2.41, 2.35, 2.42, 2.39, 2.37, 2.4, 2.38, 2.35, 2.37, 2.46], [3.94, 4.22, 4.52, 3.31, 3.11, 3.03, 3.11, 2.97, 2.95, 2.9, 2.88, 2.97, 2.92, 2.74, 2.71, 2.76, 2.75, 2.72, 2.69, 2.59, 2.68, 2.78, 2.68, 2.65, 2.74, 2.82, 2.56, 2.61, 2.72, 2.61, 2.74, 2.76, 2.56, 2.53, 2.56, 2.63, 2.43, 2.55, 2.56, 2.58, 2.62, 2.41, 2.43, 2.44, 2.44, 2.53, 2.49, 2.52, 2.15, 2.21, 2.2, 2.19, 2.23, 2.19, 2.15, 2.19, 2.3, 2.28, 2.31, 2.34, 2.38, 2.33, 2.43, 2.41, 2.38, 2.41, 2.4, 2.43, 2.44, 2.44, 2.32, 2.41, 2.4, 2.38, 2.42, 2.38, 2.35, 2.41, 2.46, 2.38, 2.33, 2.48, 2.45, 2.45, 2.45, 2.4, 2.46, 2.45, 2.47, 2.29, 2.43, 2.53, 2.39, 2.29], [3.85, 4.17, 4.5, 3.18, 3.08, 3.04, 3.16, 3.07, 2.97, 2.94, 3.04, 2.98, 2.98, 2.81, 2.81, 2.74, 2.72, 2.71, 2.75, 2.6, 2.61, 2.74, 2.56, 2.7, 2.69, 2.79, 2.58, 2.65, 2.64, 2.7, 2.72, 2.81, 2.56, 2.66, 2.71, 2.64, 2.44, 2.55, 2.56, 2.63, 2.6, 2.35, 2.4, 2.36, 2.39, 2.46, 2.51, 2.54, 2.09, 2.13, 2.25, 2.13, 2.24, 2.17, 2.31, 2.25, 2.29, 2.29, 2.3, 2.31, 2.33, 2.44, 2.4, 2.42, 2.41, 2.34, 2.43, 2.39, 2.38, 2.42, 2.37, 2.37, 2.44, 2.42, 2.42, 2.5, 2.47, 2.42, 2.47, 2.47, 2.39, 2.32, 2.44, 2.39, 2.33, 2.4, 2.42, 2.37, 2.39, 2.43, 2.37, 2.37, 2.4, 2.41], [3.91, 4.3, 4.52, 4.77, 3.12, 3.05, 3.18, 2.99, 2.91, 2.89, 2.91, 3.01, 2.89, 2.75, 2.81, 2.79, 2.77, 2.72, 2.71, 2.58, 2.62, 2.76, 2.65, 2.73, 2.67, 2.77, 2.69, 2.62, 2.64, 2.62, 2.66, 2.75, 2.52, 2.54, 2.54, 2.69, 2.5, 2.54, 2.51, 2.56, 2.62, 2.33, 2.42, 2.47, 2.47, 2.48, 2.47, 2.56, 2.12, 2.14, 2.18, 2.19, 2.21, 2.25, 2.25, 2.29, 2.27, 2.24, 2.3, 2.32, 2.34, 2.3, 2.39, 2.35, 2.33, 2.42, 2.4, 2.53, 2.5, 2.46, 2.44, 2.43, 2.45, 2.34, 2.41, 2.45, 2.41, 2.46, 2.35, 2.4, 2.37, 2.35, 2.37, 2.42, 2.31, 2.41, 2.36, 2.48, 2.44, 2.45, 2.43, 2.41, 2.47, 2.43], [3.88, 4.08, 4.5, 4.69, 3.15, 3.08, 3.13, 3.05, 2.96, 2.91, 3.0, 2.94, 2.99, 2.85, 2.82, 2.86, 2.77, 2.67, 2.79, 2.59, 2.63, 2.74, 2.67, 2.69, 2.65, 2.81, 2.62, 2.65, 2.72, 2.67, 2.68, 2.83, 2.52, 2.69, 2.64, 2.66, 2.49, 2.51, 2.54, 2.56, 2.57, 2.4, 2.39, 2.42, 2.49, 2.48, 2.52, 2.61, 2.09, 2.14, 2.21, 2.28, 2.24, 2.31, 2.25, 2.25, 2.35, 2.29, 2.36, 2.26, 2.36, 2.32, 2.38, 2.31, 2.34, 2.36, 2.38, 2.37, 2.34, 2.46, 2.33, 2.38, 2.48, 2.41, 2.43, 2.41, 2.35, 2.38, 2.41, 2.39, 2.44, 2.35, 2.4, 2.38, 2.38, 2.37, 2.34, 2.38, 2.36, 2.37, 2.41, 2.43, 2.55, 2.42], [3.97, 4.25, 4.55, 4.76, 3.11, 3.08, 3.06, 3.03, 3.0, 2.88, 2.85, 2.92, 2.97, 2.78, 2.81, 2.76, 2.77, 2.74, 2.69, 2.66, 2.72, 2.79, 2.66, 2.64, 2.66, 2.74, 2.63, 2.66, 2.7, 2.69, 2.68, 2.72, 2.49, 2.61, 2.58, 2.62, 2.49, 2.53, 2.56, 2.53, 2.7, 2.39, 2.39, 2.47, 2.45, 2.56, 2.56, 2.53, 2.1, 2.19, 2.21, 2.26, 2.23, 2.17, 2.19, 2.28, 2.32, 2.31, 2.31, 2.34, 2.36, 2.38, 2.38, 2.45, 2.46, 2.46, 2.4, 2.51, 2.38, 2.4, 2.5, 2.38, 2.32, 2.38, 2.45, 2.45, 2.44, 2.35, 2.43, 2.37, 2.38, 2.41, 2.43, 2.37, 2.42, 2.43, 2.44, 2.45, 2.45, 2.48, 2.41, 2.37, 2.42, 2.44], [3.96, 4.24, 4.45, 4.66, 3.18, 3.08, 3.07, 2.99, 2.91, 2.93, 2.94, 3.12, 2.97, 2.8, 2.77, 2.79, 2.85, 2.78, 2.71, 2.58, 2.7, 2.67, 2.59, 2.72, 2.78, 2.81, 2.61, 2.67, 2.79, 2.69, 2.76, 2.81, 2.55, 2.6, 2.65, 2.6, 2.42, 2.55, 2.56, 2.61, 2.66, 2.35, 2.45, 2.42, 2.43, 2.54, 2.53, 2.58, 2.21, 2.16, 2.22, 2.19, 2.16, 2.24, 2.36, 2.36, 2.33, 2.3, 2.34, 2.3, 2.42, 2.44, 2.4, 2.42, 2.46, 2.5, 2.39, 2.4, 2.37, 2.41, 2.39, 2.36, 2.45, 2.38, 2.43, 2.46, 2.36, 2.42, 2.41, 2.41, 2.44, 2.39, 2.34, 2.35, 2.3, 2.35, 2.4, 2.43, 2.32, 2.39, 2.41, 2.4, 2.38, 2.42], [3.89, 4.28, 4.5, 4.8, 3.14, 3.07, 3.26, 3.02, 2.94, 2.93, 2.9, 3.02, 2.91, 2.81, 2.77, 2.84, 2.81, 2.76, 2.68, 2.61, 2.7, 2.8, 2.6, 2.7, 2.74, 2.83, 2.66, 2.71, 2.8, 2.74, 2.76, 2.79, 2.58, 2.61, 2.65, 2.62, 2.49, 2.46, 2.49, 2.62, 2.66, 2.4, 2.44, 2.49, 2.54, 2.54, 2.54, 2.53, 2.17, 2.2, 2.21, 2.16, 2.14, 2.21, 2.21, 2.23, 2.34, 2.23, 2.32, 2.33, 2.32, 2.36, 2.38, 2.4, 2.36, 2.37, 2.5, 2.47, 2.36, 2.35, 2.4, 2.45, 2.4, 2.43, 2.47, 2.42, 2.37, 2.43, 2.43, 2.43, 2.4, 2.43, 2.34, 2.37, 2.34, 2.43, 2.37, 2.41, 2.43, 2.41, 2.37, 2.47, 2.52, 2.43], [3.97, 4.26, 4.49, 4.7, 3.1, 3.08, 3.14, 3.06, 3.05, 2.91, 2.93, 2.96, 2.87, 2.79, 2.86, 2.78, 2.86, 2.83, 2.72, 2.64, 2.74, 2.73, 2.65, 2.68, 2.73, 2.76, 2.64, 2.65, 2.74, 2.66, 2.75, 2.77, 2.54, 2.57, 2.64, 2.63, 2.41, 2.47, 2.56, 2.63, 2.61, 2.46, 2.4, 2.41, 2.45, 2.53, 2.58, 2.55, 2.15, 2.24, 2.19, 2.17, 2.2, 2.27, 2.29, 2.31, 2.3, 2.19, 2.36, 2.29, 2.4, 2.38, 2.43, 2.34, 2.43, 2.49, 2.42, 2.45, 2.37, 2.38, 2.4, 2.4, 2.45, 2.45, 2.37, 2.39, 2.39, 2.32, 2.36, 2.4, 2.39, 2.24, 2.45, 2.49, 2.45, 2.43, 2.49, 2.51, 2.41, 2.42, 2.38, 2.36, 2.35, 2.37], [3.89, 4.23, 4.48, 4.78, 3.11, 3.18, 3.12, 3.05, 2.99, 2.95, 2.98, 2.99, 2.99, 2.82, 2.73, 2.75, 2.78, 2.69, 2.66, 2.59, 2.69, 2.74, 2.54, 2.73, 2.74, 2.73, 2.6, 2.65, 2.71, 2.72, 2.75, 2.86, 2.6, 2.66, 2.65, 2.66, 2.55, 2.45, 2.59, 2.53, 2.64, 2.44, 2.36, 2.42, 2.48, 2.44, 2.43, 2.57, 2.12, 2.21, 2.19, 2.11, 2.16, 2.29, 2.22, 2.23, 2.34, 2.33, 2.37, 2.41, 2.4, 2.41, 2.41, 2.4, 2.34, 2.42, 2.36, 2.34, 2.44, 2.41, 2.39, 2.42, 2.43, 2.42, 2.37, 2.38, 2.38, 2.48, 2.39, 2.35, 2.42, 2.48, 2.47, 2.46, 2.36, 2.38, 2.28, 2.44, 2.41, 2.38, 2.42, 2.34, 2.41, 2.37], [3.93, 4.28, 4.48, 4.68, 5.12, 3.05, 3.17, 3.03, 3.02, 2.91, 2.93, 2.99, 2.97, 2.79, 2.74, 2.76, 2.79, 2.78, 2.79, 2.64, 2.71, 2.73, 2.6, 2.71, 2.77, 2.78, 2.62, 2.67, 2.76, 2.75, 2.73, 2.79, 2.48, 2.53, 2.61, 2.55, 2.47, 2.53, 2.52, 2.64, 2.64, 2.4, 2.44, 2.49, 2.42, 2.5, 2.57, 2.52, 2.13, 2.21, 2.16, 2.19, 2.25, 2.2, 2.27, 2.21, 2.29, 2.38, 2.34, 2.34, 2.33, 2.35, 2.36, 2.41, 2.5, 2.5, 2.41, 2.44, 2.43, 2.43, 2.38, 2.37, 2.39, 2.37, 2.38, 2.34, 2.44, 2.35, 2.4, 2.4, 2.3, 2.43, 2.45, 2.42, 2.5, 2.48, 2.37, 2.47, 2.45, 2.39, 2.43, 2.48, 2.4, 2.4], [3.89, 4.22, 4.52, 4.77, 5.0, 3.13, 3.13, 3.09, 3.06, 3.02, 2.89, 3.02, 2.98, 2.83, 2.81, 2.81, 2.71, 2.82, 2.7, 2.57, 2.76, 2.79, 2.66, 2.66, 2.72, 2.85, 2.65, 2.71, 2.74, 2.74, 2.71, 2.8, 2.59, 2.57, 2.68, 2.64, 2.51, 2.54, 2.55, 2.56, 2.59, 2.34, 2.42, 2.42, 2.52, 2.59, 2.52, 2.55, 2.09, 2.21, 2.16, 2.24, 2.18, 2.17, 2.22, 2.25, 2.31, 2.29, 2.35, 2.37, 2.36, 2.39, 2.39, 2.42, 2.35, 2.45, 2.34, 2.42, 2.42, 2.4, 2.46, 2.44, 2.44, 2.49, 2.46, 2.45, 2.4, 2.47, 2.45, 2.46, 2.4, 2.39, 2.37, 2.35, 2.34, 2.44, 2.4, 2.38, 2.48, 2.44, 2.38, 2.39, 2.45, 2.45], [3.95, 4.29, 4.5, 4.85, 5.05, 3.05, 3.13, 2.99, 2.95, 2.9, 2.88, 2.94, 2.93, 2.85, 2.76, 2.87, 2.91, 2.81, 2.79, 2.69, 2.67, 2.74, 2.61, 2.7, 2.71, 2.78, 2.57, 2.64, 2.76, 2.66, 2.73, 2.75, 2.5, 2.56, 2.73, 2.7, 2.52, 2.54, 2.57, 2.6, 2.64, 2.36, 2.41, 2.43, 2.41, 2.48, 2.46, 2.55, 2.14, 2.17, 2.16, 2.24, 2.22, 2.23, 2.2, 2.32, 2.31, 2.31, 2.31, 2.39, 2.38, 2.35, 2.41, 2.39, 2.4, 2.43, 2.37, 2.36, 2.35, 2.41, 2.4, 2.39, 2.44, 2.35, 2.38, 2.44, 2.48, 2.4, 2.45, 2.58, 2.41, 2.55, 2.42, 2.42, 2.46, 2.37, 2.44, 2.4, 2.41, 2.42, 2.54, 2.45, 2.43, 2.36], [3.91, 4.24, 4.54, 4.83, 5.09, 3.04, 3.2, 3.04, 2.99, 2.84, 3.02, 2.95, 2.99, 2.77, 2.77, 2.85, 2.85, 2.75, 2.76, 2.63, 2.7, 2.71, 2.66, 2.73, 2.66, 2.8, 2.67, 2.7, 2.75, 2.65, 2.69, 2.85, 2.56, 2.59, 2.71, 2.64, 2.45, 2.57, 2.57, 2.64, 2.61, 2.4, 2.38, 2.46, 2.48, 2.52, 2.61, 2.55, 2.2, 2.22, 2.19, 2.21, 2.2, 2.36, 2.25, 2.31, 2.35, 2.27, 2.34, 2.32, 2.35, 2.37, 2.4, 2.38, 2.44, 2.44, 2.41, 2.51, 2.55, 2.44, 2.4, 2.39, 2.37, 2.41, 2.38, 2.41, 2.48, 2.42, 2.45, 2.44, 2.33, 2.42, 2.4, 2.4, 2.34, 2.42, 2.43, 2.48, 2.43, 2.41, 2.43, 2.46, 2.43, 2.38], [4.01, 4.23, 4.48, 4.74, 5.01, 3.05, 3.1, 3.08, 3.04, 2.93, 2.96, 3.06, 3.01, 2.83, 2.79, 2.78, 2.78, 2.81, 2.7, 2.64, 2.69, 2.74, 2.66, 2.64, 2.75, 2.88, 2.61, 2.71, 2.69, 2.66, 2.78, 2.82, 2.63, 2.67, 2.72, 2.7, 2.52, 2.59, 2.5, 2.6, 2.58, 2.36, 2.39, 2.42, 2.53, 2.46, 2.58, 2.44, 2.15, 2.2, 2.19, 2.21, 2.19, 2.24, 2.38, 2.31, 2.26, 2.32, 2.35, 2.44, 2.27, 2.42, 2.45, 2.49, 2.38, 2.47, 2.45, 2.37, 2.48, 2.41, 2.44, 2.41, 2.48, 2.4, 2.52, 2.54, 2.45, 2.43, 2.47, 2.44, 2.44, 2.42, 2.41, 2.33, 2.41, 2.44, 2.39, 2.46, 2.42, 2.41, 2.43, 2.39, 2.43, 2.45], [4.02, 4.27, 4.53, 4.78, 5.15, 3.04, 3.15, 2.99, 2.93, 3.0, 2.91, 2.97, 2.97, 2.78, 2.81, 2.85, 2.83, 2.71, 2.81, 2.67, 2.73, 2.72, 2.68, 2.75, 2.77, 2.77, 2.69, 2.63, 2.73, 2.74, 2.75, 2.83, 2.61, 2.64, 2.65, 2.67, 2.5, 2.57, 2.54, 2.61, 2.61, 2.45, 2.4, 2.38, 2.44, 2.52, 2.52, 2.53, 2.11, 2.14, 2.1, 2.21, 2.23, 2.21, 2.26, 2.33, 2.28, 2.37, 2.4, 2.33, 2.3, 2.33, 2.41, 2.41, 2.39, 2.43, 2.47, 2.38, 2.35, 2.4, 2.4, 2.43, 2.46, 2.43, 2.43, 2.38, 2.45, 2.41, 2.41, 2.44, 2.47, 2.41, 2.44, 2.4, 2.42, 2.4, 2.52, 2.62, 2.58, 2.57, 2.6, 2.69, 2.7, 2.67], [4.37, 4.63, 4.89, 5.13, 5.49, 3.38, 3.36, 3.32, 3.23, 3.18, 3.2, 3.44, 3.23, 3.08, 2.99, 3.12, 3.08, 3.05, 2.97, 2.84, 2.92, 2.95, 2.88, 2.85, 2.96, 2.97, 2.83, 2.84, 2.95, 2.86, 3.02, 2.93, 2.71, 2.84, 2.87, 2.95, 2.67, 2.68, 2.77, 2.82, 2.84, 2.62, 2.63, 2.66, 2.72, 2.7, 2.73, 2.83, 2.33, 2.37, 2.43, 2.4, 2.37, 2.46, 2.49, 2.43, 2.49, 2.51, 2.44, 2.5, 2.51, 2.54, 2.55, 2.43, 2.42, 2.44, 2.38, 2.49, 2.39, 2.4, 2.39, 2.42, 2.38, 2.36, 2.39, 2.37, 2.39, 2.47, 2.46, 2.5, 2.47, 2.36, 2.48, 2.44, 2.42, 2.44, 2.48, 2.38, 2.37, 2.44, 2.41, 2.47, 2.43, 2.36], [3.9, 4.3, 4.62, 4.76, 5.12, 5.34, 3.19, 3.03, 2.99, 2.91, 2.96, 2.98, 2.96, 2.87, 2.83, 2.8, 2.79, 2.8, 2.72, 2.64, 2.74, 2.81, 2.67, 2.69, 2.75, 2.85, 2.6, 2.65, 2.74, 2.7, 2.76, 2.75, 2.54, 2.6, 2.67, 2.73, 2.5, 2.57, 2.61, 2.6, 2.67, 2.44, 2.44, 2.48, 2.48, 2.5, 2.53, 2.52, 2.13, 2.24, 2.21, 2.27, 2.25, 2.19, 2.29, 2.3, 2.24, 2.37, 2.37, 2.37, 2.38, 2.46, 2.43, 2.41, 2.42, 2.41, 2.42, 2.47, 2.47, 2.42, 2.42, 2.5, 2.4, 2.39, 2.48, 2.43, 2.47, 2.44, 2.36, 2.45, 2.47, 2.46, 2.44, 2.41, 2.48, 2.4, 2.42, 2.39, 2.42, 2.5, 2.44, 2.34, 2.48, 2.44], [3.96, 4.29, 4.57, 4.79, 5.13, 5.36, 3.18, 3.13, 2.99, 2.95, 2.99, 2.98, 2.93, 2.81, 2.74, 2.8, 2.84, 2.74, 2.78, 2.59, 2.64, 2.69, 2.58, 2.66, 2.76, 2.83, 2.66, 2.66, 2.77, 2.77, 2.78, 2.83, 2.56, 2.55, 2.62, 2.63, 2.47, 2.5, 2.59, 2.58, 2.59, 2.45, 2.4, 2.44, 2.38, 2.48, 2.54, 2.52, 2.18, 2.19, 2.27, 2.26, 2.3, 2.29, 2.27, 2.25, 2.32, 2.3, 2.34, 2.34, 2.44, 2.44, 2.47, 2.44, 2.43, 2.42, 2.46, 2.44, 2.49, 2.45, 2.44, 2.43, 2.42, 2.36, 2.44, 2.47, 2.43, 2.37, 2.5, 2.43, 2.42, 2.34, 2.41, 2.47, 2.48, 2.39, 2.37, 2.44, 2.45, 2.5, 2.44, 2.48, 2.45, 2.49], [4.02, 4.25, 4.56, 4.77, 5.08, 5.38, 3.13, 3.03, 2.96, 2.97, 2.96, 3.01, 3.12, 2.79, 2.84, 2.87, 2.88, 2.85, 2.77, 2.6, 2.72, 2.76, 2.59, 2.74, 2.75, 2.85, 2.62, 2.71, 2.73, 2.68, 2.73, 2.72, 2.58, 2.57, 2.6, 2.71, 2.57, 2.48, 2.61, 2.61, 2.67, 2.42, 2.43, 2.51, 2.47, 2.53, 2.55, 2.6, 2.16, 2.16, 2.25, 2.21, 2.25, 2.21, 2.24, 2.2, 2.38, 2.33, 2.36, 2.37, 2.33, 2.37, 2.44, 2.44, 2.45, 2.42, 2.4, 2.39, 2.38, 2.43, 2.4, 2.42, 2.45, 2.48, 2.4, 2.45, 2.45, 2.4, 2.45, 2.56, 2.42, 2.38, 2.5, 2.5, 2.52, 2.43, 2.4, 2.46, 2.45, 2.36, 2.45, 2.43, 2.44, 2.38], [3.92, 4.27, 4.62, 4.79, 5.07, 5.36, 3.19, 3.07, 2.95, 2.9, 2.98, 3.0, 2.97, 2.85, 2.77, 2.86, 2.82, 2.77, 2.73, 2.63, 2.71, 2.85, 2.63, 2.8, 2.77, 2.79, 2.57, 2.71, 2.74, 2.72, 2.73, 2.8, 2.58, 2.62, 2.64, 2.69, 2.5, 2.51, 2.64, 2.63, 2.66, 2.47, 2.4, 2.47, 2.48, 2.56, 2.55, 2.6, 2.11, 2.16, 2.17, 2.16, 2.23, 2.24, 2.35, 2.26, 2.32, 2.36, 2.38, 2.44, 2.33, 2.44, 2.47, 2.49, 2.43, 2.43, 2.37, 2.42, 2.45, 2.42, 2.56, 2.49, 2.32, 2.43, 2.43, 2.45, 2.46, 2.42, 2.46, 2.42, 2.48, 2.43, 2.47, 2.44, 2.48, 2.37, 2.46, 2.4, 2.44, 2.42, 2.49, 2.48, 2.42, 2.43], [3.98, 4.28, 4.57, 4.88, 5.03, 5.47, 3.22, 3.09, 3.03, 2.96, 2.84, 3.02, 3.0, 2.83, 2.81, 2.82, 2.84, 2.73, 2.73, 2.66, 2.66, 2.77, 2.7, 2.73, 2.75, 2.87, 2.65, 2.71, 2.74, 2.69, 2.73, 2.86, 2.6, 2.57, 2.61, 2.6, 2.49, 2.58, 2.6, 2.58, 2.59, 2.46, 2.52, 2.52, 2.47, 2.56, 2.51, 2.54, 2.21, 2.15, 2.16, 2.18, 2.28, 2.22, 2.29, 2.29, 2.29, 2.41, 2.31, 2.31, 2.35, 2.44, 2.48, 2.42, 2.53, 2.48, 2.35, 2.45, 2.41, 2.43, 2.51, 2.44, 2.45, 2.4, 2.46, 2.45, 2.48, 2.43, 2.43, 2.42, 2.4, 2.42, 2.48, 2.52, 2.4, 2.48, 2.5, 2.49, 2.49, 2.36, 2.5, 2.51, 2.43, 2.49], [3.95, 4.25, 4.58, 4.78, 5.16, 5.34, 3.24, 3.13, 2.95, 3.04, 2.94, 3.01, 3.02, 2.78, 2.8, 2.84, 2.83, 2.73, 2.73, 2.66, 2.62, 2.77, 2.63, 2.64, 2.78, 2.9, 2.69, 2.72, 2.78, 2.7, 2.75, 2.79, 2.59, 2.64, 2.69, 2.7, 2.53, 2.52, 2.53, 2.61, 2.63, 2.35, 2.4, 2.45, 2.46, 2.52, 2.56, 2.53, 2.23, 2.22, 2.25, 2.19, 2.34, 2.21, 2.25, 2.29, 2.3, 2.33, 2.36, 2.29, 2.39, 2.33, 2.35, 2.45, 2.44, 2.43, 2.51, 2.45, 2.48, 2.45, 2.47, 2.52, 2.43, 2.5, 2.45, 2.44, 2.42, 2.46, 2.51, 2.43, 2.47, 2.41, 2.44, 2.44, 2.45, 2.47, 2.45, 2.48, 2.46, 2.49, 2.46, 2.48, 2.52, 2.37], [4.01, 4.28, 4.53, 4.73, 5.04, 5.35, 3.12, 3.02, 2.94, 2.9, 2.82, 3.05, 3.05, 2.85, 2.83, 2.84, 2.83, 2.78, 2.77, 2.65, 2.77, 2.78, 2.61, 2.69, 2.78, 2.82, 2.65, 2.72, 2.72, 2.7, 2.66, 2.81, 2.52, 2.56, 2.61, 2.77, 2.55, 2.53, 2.65, 2.62, 2.71, 2.4, 2.41, 2.47, 2.5, 2.49, 2.55, 2.53, 2.19, 2.19, 2.23, 2.26, 2.31, 2.25, 2.33, 2.24, 2.36, 2.37, 2.35, 2.38, 2.5, 2.4, 2.42, 2.53, 2.54, 2.46, 2.38, 2.45, 2.48, 2.41, 2.48, 2.46, 2.41, 2.44, 2.42, 2.42, 2.49, 2.41, 2.44, 2.38, 2.47, 2.43, 2.44, 2.51, 2.47, 2.45, 2.42, 2.44, 2.5, 2.34, 2.4, 2.37, 2.39, 2.38], [4.06, 4.29, 4.57, 4.86, 5.17, 5.46, 5.79, 3.04, 3.0, 3.04, 2.95, 3.05, 2.99, 2.82, 3.0, 2.74, 2.8, 2.77, 2.78, 2.66, 2.76, 2.78, 2.68, 2.66, 2.77, 2.84, 2.66, 2.7, 2.68, 2.72, 2.73, 2.78, 2.53, 2.6, 2.58, 2.63, 2.55, 2.59, 2.61, 2.59, 2.65, 2.5, 2.43, 2.48, 2.44, 2.54, 2.51, 2.56, 2.22, 2.23, 2.17, 2.22, 2.24, 2.28, 2.27, 2.36, 2.3, 2.32, 2.36, 2.38, 2.42, 2.41, 2.42, 2.45, 2.53, 2.42, 2.5, 2.46, 2.4, 2.44, 2.4, 2.36, 2.47, 2.43, 2.42, 2.41, 2.4, 2.45, 2.5, 2.51, 2.47, 2.36, 2.45, 2.52, 2.5, 2.47, 2.43, 2.51, 2.49, 2.46, 2.5, 2.49, 2.45, 2.4], [3.97, 4.37, 4.61, 4.85, 5.08, 5.4, 5.77, 3.11, 3.09, 3.01, 3.02, 3.01, 3.02, 2.87, 2.8, 2.81, 2.82, 2.72, 2.74, 2.65, 2.73, 2.82, 2.71, 2.66, 2.84, 2.83, 2.59, 2.72, 2.77, 2.7, 2.72, 2.8, 2.54, 2.55, 2.7, 2.68, 2.5, 2.53, 2.56, 2.6, 2.67, 2.49, 2.49, 2.43, 2.52, 2.47, 2.62, 2.63, 2.17, 2.12, 2.22, 2.27, 2.21, 2.34, 2.37, 2.28, 2.33, 2.24, 2.34, 2.34, 2.42, 2.46, 2.51, 2.39, 2.4, 2.37, 2.43, 2.47, 2.47, 2.43, 2.44, 2.43, 2.35, 2.39, 2.49, 2.41, 2.49, 2.36, 2.38, 2.47, 2.45, 2.46, 2.46, 2.47, 2.51, 2.39, 2.55, 2.48, 2.48, 2.45, 2.42, 2.44, 2.45, 2.48], [3.94, 4.29, 4.53, 4.75, 5.13, 5.47, 5.87, 3.07, 3.05, 3.0, 3.04, 2.98, 2.96, 2.86, 2.8, 2.73, 2.84, 2.76, 2.74, 2.64, 2.67, 2.85, 2.68, 2.71, 2.84, 2.88, 2.72, 2.8, 2.77, 2.73, 2.79, 2.77, 2.55, 2.57, 2.66, 2.7, 2.46, 2.51, 2.6, 2.6, 2.64, 2.44, 2.39, 2.45, 2.54, 2.5, 2.56, 2.59, 2.23, 2.26, 2.21, 2.26, 2.23, 2.25, 2.21, 2.28, 2.36, 2.34, 2.39, 2.32, 2.42, 2.49, 2.32, 2.43, 2.46, 2.47, 2.57, 2.48, 2.43, 2.5, 2.47, 2.5, 2.45, 2.41, 2.4, 2.54, 2.47, 2.41, 2.47, 2.4, 2.58, 2.43, 2.43, 2.41, 2.54, 2.52, 2.41, 2.47, 2.54, 2.46, 2.46, 2.48, 2.43, 2.44], [4.05, 4.32, 4.57, 4.87, 5.05, 5.4, 5.78, 3.08, 3.07, 3.08, 2.94, 3.02, 3.0, 2.85, 2.81, 2.85, 2.84, 2.8, 2.74, 2.6, 2.7, 2.75, 2.61, 2.67, 2.8, 2.91, 2.67, 2.76, 2.74, 2.77, 2.77, 2.85, 2.57, 2.59, 2.63, 2.67, 2.51, 2.54, 2.63, 2.64, 2.66, 2.39, 2.44, 2.47, 2.45, 2.56, 2.52, 2.56, 2.17, 2.21, 2.25, 2.21, 2.25, 2.28, 2.31, 2.31, 2.36, 2.32, 2.34, 2.37, 2.48, 2.37, 2.43, 2.46, 2.45, 2.36, 2.45, 2.48, 2.49, 2.53, 2.48, 2.48, 2.55, 2.47, 2.5, 2.5, 2.45, 2.41, 2.38, 2.49, 2.5, 2.45, 2.47, 2.52, 2.5, 2.45, 2.53, 2.53, 2.5, 2.52, 2.49, 2.53, 2.52, 2.43], [4.02, 4.29, 4.51, 4.74, 5.09, 5.38, 5.77, 3.09, 3.09, 3.0, 2.97, 3.08, 2.99, 2.84, 2.87, 2.84, 2.76, 2.76, 2.76, 2.57, 2.8, 2.8, 2.63, 2.7, 2.76, 2.83, 2.77, 2.73, 2.78, 2.71, 2.82, 2.86, 2.58, 2.6, 2.66, 2.72, 2.56, 2.57, 2.56, 2.66, 2.7, 2.42, 2.37, 2.48, 2.49, 2.53, 2.49, 2.6, 2.16, 2.28, 2.16, 2.25, 2.22, 2.18, 2.27, 2.34, 2.37, 2.25, 2.31, 2.4, 2.42, 2.41, 2.42, 2.45, 2.46, 2.46, 2.44, 2.47, 2.47, 2.51, 2.51, 2.47, 2.44, 2.5, 2.45, 2.41, 2.48, 2.47, 2.48, 2.49, 2.41, 2.35, 2.46, 2.38, 2.46, 2.56, 2.48, 2.36, 2.53, 2.46, 2.55, 2.47, 2.54, 2.58], [4.05, 4.37, 4.5, 4.79, 5.05, 5.39, 5.69, 3.11, 3.01, 3.03, 2.94, 3.1, 3.05, 2.84, 2.85, 2.86, 2.79, 2.78, 2.74, 2.68, 2.63, 2.81, 2.64, 2.72, 2.67, 2.81, 2.65, 2.71, 2.82, 2.74, 2.7, 2.82, 2.57, 2.67, 2.68, 2.73, 2.48, 2.58, 2.59, 2.63, 2.68, 2.48, 2.36, 2.42, 2.51, 2.59, 2.57, 2.56, 2.26, 2.23, 2.26, 2.24, 2.24, 2.31, 2.27, 2.34, 2.31, 2.41, 2.31, 2.39, 2.41, 2.5, 2.48, 2.39, 2.38, 2.44, 2.49, 2.47, 2.49, 2.45, 2.54, 2.44, 2.5, 2.42, 2.47, 2.52, 2.5, 2.42, 2.4, 2.52, 2.42, 2.41, 2.48, 2.44, 2.52, 2.55, 2.44, 2.52, 2.55, 2.52, 2.45, 2.49, 2.43, 2.37], [4.0, 4.29, 4.58, 4.84, 5.11, 5.41, 5.78, 6.15, 3.09, 2.95, 2.94, 3.06, 3.04, 2.87, 2.89, 2.92, 2.85, 2.76, 2.8, 2.62, 2.74, 2.8, 2.71, 2.8, 2.8, 2.79, 2.69, 2.71, 2.77, 2.65, 2.76, 2.8, 2.57, 2.63, 2.7, 2.75, 2.48, 2.54, 2.66, 2.64, 2.63, 2.45, 2.48, 2.47, 2.49, 2.56, 2.56, 2.62, 2.24, 2.26, 2.31, 2.3, 2.28, 2.31, 2.3, 2.28, 2.33, 2.36, 2.35, 2.4, 2.41, 2.48, 2.43, 2.47, 2.39, 2.51, 2.47, 2.4, 2.43, 2.45, 2.52, 2.42, 2.41, 2.48, 2.45, 2.51, 2.36, 2.47, 2.39, 2.34, 2.51, 2.48, 2.38, 2.49, 2.5, 2.43, 2.48, 2.52, 2.5, 2.49, 2.39, 2.43, 2.51, 2.42], [4.07, 4.3, 4.56, 4.76, 5.02, 5.41, 5.71, 6.0, 3.04, 2.93, 3.01, 3.1, 3.03, 2.84, 2.9, 2.84, 2.9, 2.77, 2.77, 2.6, 2.71, 2.9, 2.64, 2.74, 2.79, 2.88, 2.64, 2.72, 2.82, 2.78, 2.84, 2.85, 2.59, 2.6, 2.69, 2.65, 2.48, 2.56, 2.6, 2.64, 2.58, 2.45, 2.44, 2.38, 2.5, 2.56, 2.59, 2.54, 2.14, 2.25, 2.2, 2.26, 2.26, 2.32, 2.36, 2.31, 2.38, 2.37, 2.39, 2.37, 2.35, 2.49, 2.44, 2.44, 2.33, 2.44, 2.47, 2.41, 2.45, 2.48, 2.48, 2.46, 2.46, 2.47, 2.49, 2.53, 2.47, 2.45, 2.49, 2.48, 2.48, 2.49, 2.43, 2.46, 2.41, 2.52, 2.42, 2.41, 2.48, 2.4, 2.4, 2.48, 2.48, 2.48], [3.98, 4.38, 4.62, 4.86, 5.08, 5.46, 5.79, 6.04, 3.0, 2.92, 3.04, 2.97, 2.98, 2.79, 2.79, 2.85, 2.83, 2.84, 2.81, 2.67, 2.79, 2.83, 2.68, 2.78, 2.83, 2.82, 2.69, 2.71, 2.79, 2.79, 2.8, 2.81, 2.58, 2.69, 2.6, 2.72, 2.56, 2.61, 2.64, 2.7, 2.69, 2.44, 2.41, 2.47, 2.45, 2.5, 2.56, 2.63, 2.27, 2.19, 2.22, 2.23, 2.25, 2.3, 2.33, 2.33, 2.35, 2.34, 2.45, 2.42, 2.53, 2.5, 2.59, 2.51, 2.5, 2.48, 2.44, 2.45, 2.49, 2.38, 2.46, 2.48, 2.49, 2.46, 2.39, 2.4, 2.49, 2.52, 2.53, 2.52, 2.53, 2.59, 2.5, 2.42, 2.44, 2.42, 2.55, 2.57, 2.47, 2.38, 2.46, 2.46, 2.41, 2.36], [3.97, 4.29, 4.6, 4.84, 5.11, 5.48, 5.83, 6.05, 3.01, 2.97, 3.01, 3.02, 3.03, 2.81, 2.81, 2.89, 2.81, 2.75, 2.81, 2.74, 2.76, 2.82, 2.74, 2.78, 2.81, 2.81, 2.63, 2.76, 2.74, 2.72, 2.78, 2.78, 2.57, 2.63, 2.64, 2.73, 2.47, 2.58, 2.7, 2.64, 2.75, 2.41, 2.48, 2.5, 2.51, 2.55, 2.57, 2.59, 2.19, 2.3, 2.22, 2.29, 2.28, 2.25, 2.31, 2.28, 2.36, 2.32, 2.44, 2.4, 2.49, 2.44, 2.47, 2.49, 2.43, 2.52, 2.55, 2.54, 2.46, 2.37, 2.49, 2.43, 2.46, 2.46, 2.44, 2.5, 2.52, 2.46, 2.46, 2.45, 2.52, 2.5, 2.48, 2.4, 2.48, 2.46, 2.47, 2.43, 2.55, 2.5, 2.44, 2.39, 2.4, 2.4], [3.97, 4.34, 4.52, 4.84, 5.07, 5.49, 5.8, 6.03, 3.01, 3.04, 2.99, 3.01, 2.98, 2.89, 2.89, 2.85, 2.86, 2.86, 2.76, 2.71, 2.74, 2.75, 2.65, 2.74, 2.78, 2.79, 2.63, 2.67, 2.76, 2.71, 2.78, 2.82, 2.57, 2.69, 2.71, 2.67, 2.58, 2.55, 2.62, 2.69, 2.67, 2.5, 2.38, 2.57, 2.49, 2.54, 2.59, 2.58, 2.26, 2.26, 2.23, 2.24, 2.27, 2.37, 2.27, 2.26, 2.37, 2.35, 2.36, 2.47, 2.47, 2.49, 2.47, 2.46, 2.47, 2.54, 2.48, 2.51, 2.47, 2.46, 2.44, 2.54, 2.49, 2.52, 2.48, 2.4, 2.55, 2.38, 2.51, 2.54, 2.51, 2.46, 2.48, 2.54, 2.48, 2.52, 2.44, 2.47, 2.54, 2.43, 2.44, 2.43, 2.49, 2.47], [4.07, 4.33, 4.59, 4.9, 5.09, 5.48, 5.8, 6.05, 3.03, 2.99, 3.02, 3.04, 3.02, 2.84, 2.82, 2.82, 2.83, 2.82, 2.79, 2.67, 2.72, 2.82, 2.72, 2.71, 2.84, 2.88, 2.66, 2.64, 2.75, 2.73, 2.82, 2.83, 2.6, 2.67, 2.73, 2.75, 2.56, 2.63, 2.64, 2.64, 2.64, 2.47, 2.52, 2.58, 2.54, 2.63, 2.53, 2.64, 2.23, 2.2, 2.28, 2.28, 2.29, 2.31, 2.34, 2.34, 2.41, 2.36, 2.33, 2.45, 2.44, 2.48, 2.46, 2.49, 2.5, 2.47, 2.51, 2.41, 2.49, 2.4, 2.43, 2.43, 2.48, 2.43, 2.47, 2.49, 2.43, 2.49, 2.51, 2.47, 2.47, 2.52, 2.51, 2.53, 2.48, 2.49, 2.51, 2.38, 2.61, 2.56, 2.54, 2.46, 2.57, 2.44], [4.02, 4.38, 4.54, 4.81, 5.26, 5.35, 5.82, 6.08, 3.11, 3.03, 3.05, 3.03, 3.0, 2.84, 2.84, 2.84, 2.82, 2.79, 2.75, 2.64, 2.73, 2.77, 2.69, 2.72, 2.75, 2.9, 2.61, 2.72, 2.75, 2.82, 2.81, 2.8, 2.6, 2.65, 2.66, 2.71, 2.52, 2.58, 2.51, 2.71, 2.71, 2.45, 2.58, 2.58, 2.59, 2.59, 2.56, 2.61, 2.26, 2.25, 2.25, 2.26, 2.26, 2.28, 2.29, 2.29, 2.42, 2.37, 2.36, 2.42, 2.47, 2.48, 2.47, 2.48, 2.51, 2.51, 2.45, 2.55, 2.48, 2.42, 2.46, 2.36, 2.54, 2.43, 2.47, 2.45, 2.51, 2.45, 2.51, 2.53, 2.38, 2.58, 2.47, 2.51, 2.47, 2.54, 2.56, 2.46, 2.49, 2.39, 2.46, 2.51, 2.44, 2.54], [3.97, 4.38, 4.6, 4.81, 5.07, 5.5, 5.81, 6.01, 3.07, 3.06, 2.98, 3.03, 3.06, 2.9, 2.85, 2.84, 2.82, 2.79, 2.74, 2.68, 2.76, 2.72, 2.67, 2.74, 2.83, 2.92, 2.7, 2.71, 2.84, 2.76, 2.75, 2.9, 2.55, 2.64, 2.73, 2.69, 2.53, 2.59, 2.65, 2.65, 2.67, 2.48, 2.44, 2.5, 2.53, 2.6, 2.64, 2.59, 2.26, 2.21, 2.31, 2.23, 2.3, 2.31, 2.35, 2.36, 2.37, 2.34, 2.36, 2.39, 2.38, 2.49, 2.39, 2.47, 2.48, 2.5, 2.56, 2.46, 2.55, 2.51, 2.56, 2.53, 2.49, 2.45, 2.48, 2.52, 2.5, 2.46, 2.45, 2.45, 2.54, 2.47, 2.43, 2.54, 2.49, 2.45, 2.5, 2.45, 2.48, 2.46, 2.39, 2.46, 2.48, 2.48], [4.07, 4.28, 4.58, 4.88, 5.06, 5.31, 5.82, 6.09, 3.04, 2.99, 3.08, 3.04, 2.99, 2.91, 2.79, 2.86, 2.92, 2.86, 2.72, 2.66, 2.83, 2.86, 2.69, 2.77, 2.82, 2.9, 2.73, 2.74, 2.85, 2.74, 2.82, 2.86, 2.67, 2.67, 2.68, 2.65, 2.51, 2.55, 2.62, 2.65, 2.7, 2.49, 2.57, 2.58, 2.64, 2.55, 2.65, 2.63, 2.29, 2.25, 2.27, 2.29, 2.3, 2.29, 2.34, 2.36, 2.36, 2.34, 2.32, 2.34, 2.43, 2.43, 2.43, 2.49, 2.5, 2.57, 2.52, 2.5, 2.48, 2.55, 2.49, 2.55, 2.53, 2.52, 2.46, 2.39, 2.41, 2.5, 2.47, 2.47, 2.49, 2.43, 2.51, 2.62, 2.5, 2.5, 2.45, 2.56, 2.54, 2.49, 2.51, 2.55, 2.5, 2.5], [4.08, 4.33, 4.55, 4.81, 5.1, 5.39, 5.8, 6.11, 3.11, 3.0, 3.01, 3.12, 3.04, 2.87, 2.85, 2.88, 2.83, 2.83, 2.82, 2.7, 2.75, 2.74, 2.66, 2.75, 2.86, 2.93, 2.7, 2.82, 2.87, 2.73, 2.76, 2.81, 2.65, 2.72, 2.65, 2.71, 2.54, 2.64, 2.67, 2.61, 2.76, 2.47, 2.53, 2.51, 2.51, 2.5, 2.6, 2.63, 2.24, 2.24, 2.24, 2.3, 2.3, 2.34, 2.36, 2.35, 2.45, 2.4, 2.33, 2.45, 2.45, 2.4, 2.48, 2.52, 2.45, 2.46, 2.51, 2.51, 2.54, 2.47, 2.52, 2.5, 2.49, 2.47, 2.54, 2.58, 2.49, 2.39, 2.44, 2.54, 2.5, 2.44, 2.44, 2.54, 2.47, 2.51, 2.49, 2.49, 2.46, 2.52, 2.54, 2.47, 2.51, 2.57], [4.07, 4.32, 4.61, 4.86, 5.14, 5.4, 5.76, 6.11, 3.15, 2.96, 3.08, 3.11, 3.05, 2.89, 2.88, 2.86, 2.87, 2.82, 2.82, 2.63, 2.71, 2.89, 2.69, 2.79, 2.85, 2.88, 2.73, 2.74, 2.83, 2.83, 2.8, 2.84, 2.62, 2.74, 2.65, 2.75, 2.5, 2.58, 2.55, 2.67, 2.68, 2.4, 2.4, 2.53, 2.65, 2.6, 2.71, 2.63, 2.22, 2.23, 2.26, 2.24, 2.24, 2.25, 2.36, 2.32, 2.38, 2.47, 2.44, 2.37, 2.41, 2.43, 2.5, 2.52, 2.58, 2.46, 2.44, 2.61, 2.53, 2.51, 2.49, 2.49, 2.53, 2.47, 2.44, 2.51, 2.46, 2.49, 2.48, 2.49, 2.43, 2.42, 2.47, 2.47, 2.55, 2.55, 2.49, 2.5, 2.57, 2.45, 2.56, 2.5, 2.48, 2.48], [4.01, 4.3, 4.54, 4.85, 5.1, 5.35, 5.83, 6.07, 2.99, 2.97, 3.08, 3.06, 3.08, 2.92, 2.96, 2.76, 2.89, 2.77, 2.73, 2.66, 2.75, 2.81, 2.69, 2.77, 2.85, 2.85, 2.72, 2.82, 2.86, 2.88, 2.84, 2.9, 2.65, 2.68, 2.76, 2.74, 2.57, 2.58, 2.66, 2.77, 2.6, 2.52, 2.57, 2.49, 2.53, 2.59, 2.55, 2.52, 2.21, 2.26, 2.29, 2.3, 2.33, 2.32, 2.37, 2.31, 2.37, 2.31, 2.31, 2.49, 2.44, 2.49, 2.43, 2.46, 2.59, 2.5, 2.53, 2.49, 2.51, 2.45, 2.47, 2.53, 2.37, 2.58, 2.53, 2.49, 2.45, 2.46, 2.42, 2.39, 2.47, 2.44, 2.46, 2.5, 2.41, 2.5, 2.47, 2.49, 2.55, 2.47, 2.51, 2.51, 2.47, 2.46], [4.08, 4.33, 4.62, 4.85, 5.26, 5.47, 5.85, 6.03, 3.04, 2.99, 2.97, 3.1, 3.04, 2.9, 2.96, 2.87, 2.91, 2.81, 2.82, 2.72, 2.77, 2.73, 2.68, 2.76, 2.74, 2.88, 2.7, 2.75, 2.82, 2.75, 2.79, 2.92, 2.69, 2.68, 2.71, 2.69, 2.52, 2.65, 2.59, 2.62, 2.66, 2.43, 2.51, 2.48, 2.54, 2.57, 2.6, 2.66, 2.23, 2.2, 2.25, 2.28, 2.36, 2.4, 2.34, 2.39, 2.4, 2.37, 2.39, 2.43, 2.42, 2.51, 2.55, 2.42, 2.58, 2.48, 2.49, 2.51, 2.55, 2.46, 2.54, 2.54, 2.56, 2.54, 2.56, 2.53, 2.47, 2.49, 2.54, 2.51, 2.49, 2.53, 2.46, 2.37, 2.49, 2.45, 2.47, 2.48, 2.42, 2.48, 2.5, 2.5, 2.55, 2.44], [4.14, 4.37, 4.68, 4.8, 5.09, 5.42, 5.84, 5.98, 3.05, 3.05, 3.05, 3.08, 3.01, 2.88, 2.93, 2.88, 2.9, 2.84, 2.76, 2.64, 2.77, 2.75, 2.63, 2.74, 2.82, 2.84, 2.64, 2.65, 2.89, 2.82, 2.85, 2.84, 2.71, 2.66, 2.65, 2.73, 2.52, 2.55, 2.6, 2.67, 2.7, 2.45, 2.49, 2.49, 2.54, 2.58, 2.59, 2.59, 2.26, 2.25, 2.29, 2.3, 2.28, 2.35, 2.34, 2.36, 2.36, 2.37, 2.38, 2.47, 2.46, 2.45, 2.5, 2.49, 2.48, 2.49, 2.45, 2.47, 2.48, 2.56, 2.48, 2.56, 2.52, 2.49, 2.48, 2.5, 2.53, 2.5, 2.48, 2.54, 2.47, 2.49, 2.51, 2.44, 2.52, 2.42, 2.48, 2.46, 2.54, 2.44, 2.48, 2.51, 2.54, 2.5], [4.08, 4.39, 4.65, 4.88, 5.12, 5.42, 5.88, 6.14, 3.07, 3.1, 3.12, 3.09, 3.02, 2.87, 2.85, 2.88, 2.83, 2.84, 2.84, 2.67, 2.77, 2.82, 2.62, 2.8, 2.83, 2.84, 2.71, 2.76, 2.87, 2.79, 2.89, 2.86, 2.54, 2.62, 2.67, 2.76, 2.56, 2.57, 2.59, 2.65, 2.66, 2.49, 2.43, 2.49, 2.54, 2.65, 2.59, 2.59, 2.22, 2.25, 2.27, 2.21, 2.27, 2.3, 2.36, 2.37, 2.36, 2.39, 2.47, 2.4, 2.42, 2.44, 2.46, 2.52, 2.49, 2.47, 2.5, 2.53, 2.51, 2.54, 2.54, 2.51, 2.34, 2.47, 2.47, 2.48, 2.52, 2.53, 2.44, 2.52, 2.6, 2.48, 2.42, 2.41, 2.53, 2.46, 2.41, 2.52, 2.49, 2.5, 2.56, 2.51, 2.58, 2.54], [4.67, 4.31, 4.58, 4.88, 5.11, 5.47, 5.75, 5.95, 3.14, 3.03, 3.05, 3.13, 3.03, 2.95, 2.89, 2.82, 2.86, 2.81, 2.74, 2.7, 2.72, 2.78, 2.63, 2.77, 2.82, 2.86, 2.69, 2.73, 2.77, 2.75, 2.89, 2.86, 2.61, 2.66, 2.7, 2.79, 2.56, 2.62, 2.62, 2.68, 2.64, 2.44, 2.53, 2.58, 2.51, 2.56, 2.65, 2.61, 2.19, 2.2, 2.24, 2.37, 2.28, 2.28, 2.22, 2.38, 2.38, 2.42, 2.43, 2.43, 2.48, 2.45, 2.49, 2.52, 2.52, 2.57, 2.44, 2.51, 2.43, 2.61, 2.57, 2.53, 2.45, 2.52, 2.48, 2.48, 2.57, 2.47, 2.54, 2.54, 2.5, 2.56, 2.58, 2.49, 2.57, 2.41, 2.54, 2.5, 2.53, 2.61, 2.52, 2.51, 2.52, 2.49], [4.65, 4.41, 4.7, 4.83, 5.17, 5.43, 5.83, 6.1, 3.11, 3.06, 3.03, 3.1, 3.04, 2.95, 2.87, 2.93, 2.86, 2.86, 2.79, 2.72, 2.69, 2.82, 2.71, 2.74, 2.75, 2.86, 2.74, 2.72, 2.87, 2.82, 2.87, 2.88, 2.62, 2.74, 2.74, 2.8, 2.57, 2.6, 2.61, 2.59, 2.69, 2.46, 2.6, 2.48, 2.56, 2.55, 2.63, 2.55, 2.22, 2.23, 2.37, 2.36, 2.34, 2.32, 2.34, 2.34, 2.34, 2.37, 2.35, 2.39, 2.38, 2.49, 2.44, 2.54, 2.47, 2.44, 2.53, 2.54, 2.48, 2.49, 2.48, 2.53, 2.5, 2.51, 2.42, 2.47, 2.47, 2.48, 2.48, 2.45, 2.48, 2.56, 2.56, 2.51, 2.48, 2.52, 2.49, 2.56, 2.56, 2.53, 2.52, 2.58, 2.58, 2.51], [4.63, 4.37, 4.67, 4.9, 5.13, 5.35, 5.8, 6.07, 3.01, 3.09, 2.99, 3.1, 3.08, 2.86, 2.89, 2.83, 2.83, 2.81, 2.85, 2.72, 2.8, 2.79, 2.72, 2.7, 2.79, 2.81, 2.81, 2.78, 2.76, 2.79, 2.87, 2.92, 2.61, 2.66, 2.69, 2.76, 2.56, 2.53, 2.6, 2.69, 2.73, 2.45, 2.56, 2.54, 2.54, 2.65, 2.58, 2.68, 2.24, 2.23, 2.26, 2.31, 2.31, 2.33, 2.27, 2.34, 2.37, 2.39, 2.4, 2.32, 2.45, 2.44, 2.52, 2.52, 2.5, 2.52, 2.45, 2.6, 2.51, 2.52, 2.48, 2.47, 2.54, 2.49, 2.51, 2.49, 2.5, 2.49, 2.49, 2.48, 2.43, 2.5, 2.46, 2.53, 2.52, 2.49, 2.44, 2.54, 2.48, 2.52, 2.53, 2.43, 2.49, 2.49], [4.67, 4.39, 4.61, 4.9, 5.09, 5.39, 5.77, 6.05, 3.12, 3.0, 3.05, 3.1, 3.07, 2.94, 2.84, 2.85, 2.9, 2.83, 2.86, 2.73, 2.77, 2.83, 2.77, 2.72, 2.83, 2.91, 2.74, 2.87, 2.82, 2.81, 2.84, 2.9, 2.66, 2.73, 2.72, 2.74, 2.6, 2.57, 2.63, 2.69, 2.72, 2.46, 2.51, 2.45, 2.55, 2.57, 2.63, 2.57, 2.17, 2.24, 2.36, 2.34, 2.34, 2.35, 2.41, 2.32, 2.32, 2.35, 2.43, 2.49, 2.44, 2.48, 2.5, 2.48, 2.56, 2.47, 2.5, 2.56, 2.5, 2.41, 2.46, 2.51, 2.58, 2.52, 2.48, 2.57, 2.54, 2.5, 2.51, 2.49, 2.46, 2.52, 2.52, 2.47, 2.49, 2.52, 2.46, 2.54, 2.49, 2.45, 2.47, 2.53, 2.51, 2.45], [4.7, 4.38, 4.6, 4.91, 5.15, 5.46, 5.8, 6.15, 3.11, 3.11, 3.06, 3.15, 3.13, 2.92, 2.94, 2.9, 2.84, 2.88, 2.85, 2.66, 2.75, 2.84, 2.68, 2.74, 2.85, 2.92, 2.72, 2.76, 2.81, 2.8, 2.88, 2.91, 2.61, 2.63, 2.71, 2.74, 2.63, 2.62, 2.66, 2.56, 2.69, 2.45, 2.47, 2.54, 2.53, 2.58, 2.7, 2.69, 2.23, 2.25, 2.28, 2.31, 2.35, 2.39, 2.35, 2.36, 2.42, 2.47, 2.39, 2.48, 2.42, 2.49, 2.42, 2.53, 2.5, 2.46, 2.52, 2.49, 2.48, 2.52, 2.34, 2.45, 2.54, 2.51, 2.5, 2.49, 2.52, 2.49, 2.46, 2.51, 2.47, 2.51, 2.5, 2.47, 2.46, 2.44, 2.54, 2.51, 2.53, 2.5, 2.51, 2.44, 2.53, 2.5], [4.68, 4.4, 4.58, 4.87, 5.15, 5.45, 5.78, 6.13, 3.04, 3.01, 3.03, 3.09, 3.07, 2.96, 2.86, 2.91, 2.96, 2.81, 2.78, 2.75, 2.79, 2.84, 2.72, 2.7, 2.86, 2.9, 2.7, 2.77, 2.79, 2.8, 2.85, 2.8, 2.71, 2.62, 2.76, 2.78, 2.62, 2.65, 2.63, 2.64, 2.74, 2.45, 2.47, 2.54, 2.63, 2.6, 2.67, 2.56, 2.29, 2.23, 2.28, 2.3, 2.23, 2.31, 2.36, 2.31, 2.41, 2.47, 2.5, 2.52, 2.48, 2.53, 2.52, 2.51, 2.5, 2.46, 2.54, 2.48, 2.45, 2.5, 2.48, 2.55, 2.5, 2.54, 2.56, 2.41, 2.54, 2.46, 2.54, 2.54, 2.56, 2.47, 2.4, 2.48, 2.46, 2.46, 2.5, 2.5, 2.44, 2.54, 2.51, 2.56, 2.49, 2.45], [4.69, 4.43, 4.66, 4.97, 5.16, 5.45, 5.85, 6.11, 3.07, 3.04, 3.03, 3.16, 3.14, 2.9, 2.93, 2.92, 2.92, 2.84, 2.84, 2.73, 2.76, 2.77, 2.75, 2.71, 2.96, 2.9, 2.71, 2.75, 2.82, 2.84, 2.83, 2.91, 2.68, 2.69, 2.8, 2.69, 2.6, 2.6, 2.7, 2.69, 2.63, 2.41, 2.52, 2.58, 2.5, 2.56, 2.64, 2.66, 2.27, 2.35, 2.27, 2.26, 2.3, 2.37, 2.41, 2.36, 2.38, 2.33, 2.46, 2.43, 2.44, 2.44, 2.43, 2.52, 2.48, 2.49, 2.54, 2.51, 2.57, 2.5, 2.52, 2.54, 2.54, 2.51, 2.52, 2.45, 2.58, 2.57, 2.56, 2.4, 2.53, 2.52, 2.51, 2.43, 2.54, 2.48, 2.51, 2.48, 2.67, 2.48, 2.46, 2.52, 2.57, 2.49], [4.66, 4.39, 4.62, 4.88, 5.1, 5.52, 5.8, 6.07, 3.1, 3.07, 3.06, 3.08, 3.09, 2.98, 2.81, 2.95, 2.96, 2.84, 2.86, 2.73, 2.77, 2.92, 2.74, 2.75, 2.77, 2.88, 2.72, 2.75, 2.8, 2.78, 2.84, 2.88, 2.67, 2.66, 2.68, 2.73, 2.58, 2.57, 2.7, 2.67, 2.67, 2.51, 2.62, 2.53, 2.57, 2.63, 2.62, 2.68, 2.25, 2.31, 2.3, 2.33, 2.28, 2.3, 2.27, 2.31, 2.43, 2.31, 2.42, 2.44, 2.42, 2.46, 2.48, 2.49, 2.49, 2.55, 2.54, 2.57, 2.5, 2.51, 2.51, 2.52, 2.47, 2.58, 2.45, 2.56, 2.54, 2.56, 2.45, 2.48, 2.48, 2.49, 2.54, 2.44, 2.54, 2.53, 2.53, 2.56, 2.53, 2.52, 2.56, 2.55, 2.45, 2.49], [4.66, 4.36, 4.6, 4.87, 5.21, 5.44, 5.88, 6.12, 3.12, 3.05, 3.13, 3.13, 3.02, 2.87, 2.85, 2.93, 2.89, 2.72, 2.71, 2.74, 2.83, 2.89, 2.69, 2.81, 2.89, 2.95, 2.74, 2.89, 2.87, 2.69, 2.82, 2.87, 2.62, 2.61, 2.72, 2.78, 2.58, 2.67, 2.68, 2.69, 2.69, 2.51, 2.46, 2.54, 2.63, 2.61, 2.61, 2.62, 2.3, 2.22, 2.26, 2.29, 2.31, 2.37, 2.37, 2.43, 2.47, 2.4, 2.48, 2.48, 2.51, 2.41, 2.55, 2.58, 2.51, 2.53, 2.55, 2.49, 2.55, 2.55, 2.61, 2.54, 2.53, 2.57, 2.43, 2.5, 2.6, 2.5, 2.49, 2.48, 2.5, 2.5, 2.48, 2.49, 2.54, 2.53, 2.51, 2.54, 2.59, 2.58, 2.58, 2.56, 2.58, 2.55], [4.7, 4.41, 4.58, 4.85, 5.29, 5.52, 5.86, 6.15, 3.1, 3.01, 3.13, 3.08, 3.04, 2.87, 2.92, 2.91, 2.94, 2.83, 2.74, 2.74, 2.81, 2.82, 2.75, 2.79, 2.81, 2.96, 2.71, 2.76, 2.87, 2.83, 2.92, 2.93, 2.7, 2.74, 2.71, 2.76, 2.62, 2.6, 2.64, 2.7, 2.71, 2.48, 2.54, 2.51, 2.63, 2.62, 2.63, 2.71, 2.2, 2.26, 2.3, 2.26, 2.34, 2.28, 2.35, 2.33, 2.36, 2.43, 2.41, 2.39, 2.46, 2.49, 2.51, 2.54, 2.52, 2.53, 2.47, 2.55, 2.54, 2.47, 2.52, 2.56, 2.51, 2.47, 2.53, 2.58, 2.53, 2.47, 2.52, 2.49, 2.53, 2.55, 2.55, 2.49, 2.56, 2.5, 2.46, 2.5, 2.5, 2.45, 2.5, 2.53, 2.49, 2.44], [4.73, 4.45, 4.65, 4.95, 5.2, 5.52, 5.86, 6.07, 3.12, 3.0, 3.1, 3.1, 3.05, 2.88, 2.91, 2.91, 2.9, 2.8, 2.79, 2.69, 2.82, 2.95, 2.73, 2.8, 2.94, 2.92, 2.71, 2.78, 2.86, 2.92, 2.86, 2.88, 2.62, 2.67, 2.74, 2.75, 2.6, 2.67, 2.74, 2.68, 2.81, 2.52, 2.56, 2.51, 2.61, 2.59, 2.66, 2.68, 2.23, 2.25, 2.26, 2.31, 2.35, 2.41, 2.32, 2.38, 2.36, 2.35, 2.47, 2.5, 2.46, 2.56, 2.57, 2.49, 2.45, 2.56, 2.54, 2.52, 2.51, 2.56, 2.46, 2.56, 2.49, 2.54, 2.52, 2.52, 2.46, 2.49, 2.52, 2.55, 2.53, 2.66, 2.54, 2.57, 2.53, 2.49, 2.57, 2.42, 2.58, 2.49, 2.55, 2.54, 2.5, 2.47], [4.69, 4.43, 4.61, 4.94, 5.27, 5.52, 5.8, 6.09, 3.11, 3.01, 3.02, 3.13, 3.0, 2.91, 2.97, 2.88, 2.91, 2.8, 2.83, 2.79, 2.75, 2.86, 2.84, 2.81, 2.86, 2.91, 2.69, 2.81, 2.86, 2.77, 2.82, 2.91, 2.56, 2.7, 2.76, 2.77, 2.48, 2.65, 2.63, 2.76, 2.8, 2.57, 2.53, 2.59, 2.58, 2.71, 2.69, 2.72, 2.22, 2.24, 2.26, 2.23, 2.32, 2.42, 2.35, 2.41, 2.41, 2.41, 2.42, 2.4, 2.36, 2.48, 2.53, 2.53, 2.46, 2.62, 2.54, 2.54, 2.51, 2.53, 2.49, 2.55, 2.58, 2.49, 2.62, 2.53, 2.58, 2.49, 2.46, 2.56, 2.44, 2.49, 2.53, 2.61, 2.51, 2.57, 2.51, 2.46, 2.48, 2.42, 2.46, 2.51, 2.48, 2.5], [4.64, 4.4, 4.63, 4.9, 5.15, 5.47, 5.94, 6.15, 3.08, 3.01, 3.04, 3.12, 3.01, 2.9, 2.91, 2.94, 2.97, 2.81, 2.83, 2.71, 2.83, 2.84, 2.79, 2.77, 2.84, 2.9, 2.73, 2.81, 2.83, 2.74, 2.93, 2.91, 2.67, 2.69, 2.73, 2.78, 2.52, 2.67, 2.65, 2.66, 2.71, 2.54, 2.5, 2.47, 2.55, 2.61, 2.55, 2.61, 2.19, 2.2, 2.28, 2.34, 2.29, 2.3, 2.28, 2.23, 2.31, 2.34, 2.39, 2.46, 2.47, 2.49, 2.55, 2.54, 2.55, 2.59, 2.5, 2.62, 2.52, 2.54, 2.6, 2.5, 2.5, 2.53, 2.54, 2.51, 2.45, 2.45, 2.5, 2.62, 2.55, 2.57, 2.62, 2.59, 2.58, 2.43, 2.58, 2.48, 2.47, 2.54, 2.51, 2.6, 2.55, 2.51], [4.64, 4.43, 4.54, 4.91, 5.28, 5.57, 5.9, 6.18, 3.17, 3.08, 3.04, 3.13, 3.08, 2.89, 2.85, 2.9, 2.9, 2.83, 2.9, 2.82, 2.87, 2.86, 2.88, 2.83, 2.82, 2.88, 2.71, 2.8, 2.84, 2.76, 2.85, 2.95, 2.68, 2.69, 2.72, 2.82, 2.52, 2.63, 2.68, 2.66, 2.72, 2.55, 2.59, 2.56, 2.6, 2.57, 2.5, 2.62, 2.35, 2.32, 2.33, 2.32, 2.35, 2.41, 2.36, 2.39, 2.41, 2.42, 2.48, 2.55, 2.46, 2.49, 2.51, 2.58, 2.53, 2.5, 2.47, 2.5, 2.5, 2.58, 2.46, 2.52, 2.53, 2.57, 2.52, 2.52, 2.53, 2.49, 2.51, 2.58, 2.52, 2.49, 2.53, 2.54, 2.44, 2.49, 2.51, 2.53, 2.51, 2.52, 2.57, 2.55, 2.52, 2.47], [4.66, 4.52, 4.67, 4.86, 5.18, 5.51, 5.88, 6.18, 3.18, 3.04, 3.05, 3.16, 3.03, 2.92, 2.9, 2.99, 2.93, 2.82, 2.72, 2.76, 2.82, 2.88, 2.84, 2.86, 2.88, 2.98, 2.76, 2.78, 2.78, 2.77, 2.84, 2.88, 2.69, 2.68, 2.75, 2.77, 2.6, 2.57, 2.65, 2.65, 2.72, 2.55, 2.57, 2.57, 2.6, 2.65, 2.72, 2.65, 2.22, 2.24, 2.28, 2.29, 2.3, 2.47, 2.36, 2.39, 2.42, 2.41, 2.41, 2.38, 2.4, 2.44, 2.55, 2.54, 2.6, 2.57, 2.5, 2.62, 2.48, 2.54, 2.54, 2.5, 2.52, 2.54, 2.48, 2.47, 2.52, 2.59, 2.51, 2.42, 2.59, 2.55, 2.56, 2.58, 2.62, 2.5, 2.54, 2.54, 2.47, 2.51, 2.56, 2.52, 2.5, 2.52], [4.71, 4.39, 4.68, 4.91, 5.26, 5.56, 5.9, 6.14, 3.13, 3.11, 3.06, 3.06, 3.07, 2.89, 2.89, 2.9, 2.94, 2.86, 2.82, 2.69, 2.84, 2.81, 2.86, 2.78, 2.86, 2.88, 2.75, 2.77, 2.75, 2.8, 2.9, 2.85, 2.69, 2.74, 2.79, 2.74, 2.59, 2.61, 2.64, 2.66, 2.77, 2.47, 2.5, 2.56, 2.57, 2.63, 2.61, 2.65, 2.22, 2.28, 2.24, 2.33, 2.29, 2.34, 2.33, 2.39, 2.33, 2.51, 2.47, 2.41, 2.4, 2.47, 2.48, 2.56, 2.53, 2.55, 2.48, 2.53, 2.45, 2.49, 2.51, 2.56, 2.49, 2.49, 2.44, 2.52, 2.51, 2.55, 2.56, 2.53, 2.54, 2.55, 2.49, 2.53, 2.53, 2.56, 2.59, 2.47, 2.49, 2.48, 2.49, 2.61, 2.51, 2.47], [4.76, 4.38, 4.64, 4.95, 5.3, 5.54, 5.87, 6.08, 3.09, 3.06, 3.06, 3.06, 3.07, 2.92, 2.96, 2.95, 2.93, 2.8, 2.87, 2.73, 2.82, 2.9, 2.69, 2.84, 2.84, 2.89, 2.68, 2.8, 2.87, 2.77, 2.8, 2.96, 2.6, 2.72, 2.76, 2.76, 2.58, 2.65, 2.73, 2.66, 2.7, 2.49, 2.54, 2.57, 2.56, 2.63, 2.62, 2.65, 2.27, 2.28, 2.32, 2.38, 2.29, 2.37, 2.41, 2.42, 2.51, 2.41, 2.44, 2.49, 2.47, 2.54, 2.44, 2.56, 2.58, 2.5, 2.55, 2.48, 2.49, 2.54, 2.54, 2.46, 2.51, 2.58, 2.56, 2.51, 2.58, 2.59, 2.5, 2.54, 2.52, 2.53, 2.53, 2.53, 2.55, 2.52, 2.56, 2.48, 2.61, 2.58, 2.48, 2.5, 2.5, 2.58], [4.65, 4.33, 4.61, 4.97, 5.16, 5.48, 5.91, 6.12, 3.09, 2.98, 3.02, 3.15, 3.07, 2.95, 2.96, 2.86, 2.9, 2.87, 2.84, 2.73, 2.83, 2.86, 2.8, 2.81, 2.86, 2.95, 2.77, 2.7, 2.79, 2.76, 2.85, 2.82, 2.64, 2.63, 2.75, 2.76, 2.6, 2.59, 2.66, 2.76, 2.65, 2.56, 2.57, 2.62, 2.65, 2.66, 2.63, 2.66, 2.29, 2.27, 2.3, 2.36, 2.37, 2.32, 2.36, 2.34, 2.41, 2.39, 2.48, 2.44, 2.53, 2.52, 2.55, 2.57, 2.51, 2.59, 2.5, 2.56, 2.51, 2.54, 2.47, 2.52, 2.49, 2.61, 2.51, 2.56, 2.5, 2.55, 2.48, 2.43, 2.53, 2.5, 2.51, 2.53, 2.56, 2.58, 2.5, 2.5, 2.48, 2.53, 2.53, 2.61, 2.56, 2.53], [4.68, 4.43, 4.67, 4.92, 5.24, 5.5, 5.9, 6.08, 3.14, 3.09, 3.11, 3.05, 3.03, 2.89, 2.92, 2.85, 2.86, 2.93, 2.88, 2.74, 2.81, 2.89, 2.77, 2.8, 2.85, 2.97, 2.79, 2.78, 2.88, 2.78, 2.81, 2.9, 2.63, 2.74, 2.75, 2.75, 2.55, 2.65, 2.62, 2.64, 2.78, 2.5, 2.56, 2.51, 2.58, 2.64, 2.68, 2.76, 2.28, 2.26, 2.37, 2.29, 2.44, 2.31, 2.4, 2.35, 2.35, 2.42, 2.38, 2.45, 2.47, 2.5, 2.53, 2.51, 2.44, 2.55, 2.56, 2.54, 2.57, 2.58, 2.53, 2.6, 2.57, 2.5, 2.55, 2.53, 2.53, 2.47, 2.55, 2.52, 2.54, 2.57, 2.53, 2.53, 2.47, 2.54, 2.55, 2.59, 2.58, 2.63, 2.56, 2.57, 2.52, 2.56], [4.66, 4.44, 4.7, 4.93, 5.26, 5.52, 5.86, 6.15, 3.14, 3.09, 3.06, 3.14, 3.06, 2.94, 2.86, 2.88, 3.01, 2.86, 2.84, 2.71, 2.78, 2.82, 2.75, 2.77, 2.8, 2.94, 2.74, 2.8, 2.85, 2.85, 2.92, 2.88, 2.68, 2.71, 2.73, 2.75, 2.71, 2.58, 2.62, 2.77, 2.74, 2.5, 2.56, 2.55, 2.61, 2.61, 2.64, 2.63, 2.29, 2.32, 2.35, 2.34, 2.38, 2.35, 2.42, 2.46, 2.43, 2.42, 2.5, 2.42, 2.49, 2.47, 2.46, 2.55, 2.46, 2.55, 2.52, 2.61, 2.56, 2.52, 2.48, 2.47, 2.5, 2.46, 2.54, 2.56, 2.68, 2.55, 2.51, 2.52, 2.57, 2.53, 2.58, 2.52, 2.52, 2.47, 2.56, 2.56, 2.46, 2.47, 2.58, 2.53, 2.57, 2.65], [4.77, 4.46, 4.71, 4.88, 5.25, 5.58, 5.93, 6.1, 3.08, 3.06, 3.07, 3.11, 3.03, 2.91, 2.98, 2.97, 2.9, 2.84, 2.85, 2.75, 2.85, 2.91, 2.74, 2.76, 2.78, 2.86, 2.75, 2.8, 2.85, 2.8, 2.81, 2.92, 2.65, 2.7, 2.76, 2.86, 2.63, 2.64, 2.65, 2.77, 2.74, 2.51, 2.51, 2.54, 2.61, 2.67, 2.66, 2.63, 2.23, 2.27, 2.29, 2.39, 2.4, 2.36, 2.4, 2.42, 2.48, 2.39, 2.47, 2.48, 2.51, 2.5, 2.52, 2.55, 2.54, 2.5, 2.55, 2.43, 2.54, 2.6, 2.53, 2.53, 2.58, 2.6, 2.53, 2.57, 2.49, 2.48, 2.52, 2.51, 2.54, 2.47, 2.59, 2.6, 2.54, 2.49, 2.56, 2.51, 2.48, 2.49, 2.49, 2.53, 2.48, 2.5], [4.68, 4.39, 4.7, 4.94, 5.23, 5.52, 5.93, 6.24, 3.14, 3.03, 3.04, 3.12, 3.07, 2.88, 2.88, 2.97, 2.88, 2.83, 2.89, 2.74, 2.89, 2.94, 2.78, 2.8, 2.87, 2.92, 2.76, 2.81, 2.8, 2.78, 2.83, 2.88, 2.67, 2.66, 2.72, 2.72, 2.6, 2.66, 2.66, 2.75, 2.78, 2.56, 2.61, 2.51, 2.62, 2.64, 2.62, 2.67, 2.21, 2.3, 2.28, 2.36, 2.38, 2.39, 2.39, 2.36, 2.33, 2.51, 2.5, 2.42, 2.44, 2.52, 2.54, 2.53, 2.48, 2.55, 2.54, 2.56, 2.57, 2.56, 2.49, 2.6, 2.61, 2.52, 2.56, 2.55, 2.48, 2.55, 2.51, 2.6, 2.56, 2.51, 2.55, 2.56, 2.52, 2.58, 2.55, 2.49, 2.53, 2.52, 2.56, 2.54, 2.54, 2.53], [4.71, 4.46, 4.62, 4.86, 5.31, 5.46, 5.93, 6.21, 3.14, 3.09, 3.15, 3.14, 3.1, 2.91, 2.94, 2.93, 2.89, 2.83, 2.86, 2.79, 2.81, 2.91, 2.8, 2.86, 2.9, 2.87, 2.74, 2.8, 2.88, 2.79, 2.8, 2.87, 2.68, 2.76, 2.75, 2.71, 2.61, 2.65, 2.67, 2.69, 2.73, 2.58, 2.52, 2.63, 2.6, 2.66, 2.7, 2.63, 2.29, 2.3, 2.27, 2.35, 2.35, 2.39, 2.35, 2.4, 2.36, 2.39, 2.42, 2.41, 2.51, 2.55, 2.53, 2.59, 2.59, 2.54, 2.49, 2.49, 2.49, 2.52, 2.6, 2.54, 2.54, 2.5, 2.49, 2.52, 2.48, 2.62, 2.58, 2.6, 2.59, 2.56, 2.62, 2.54, 2.54, 2.49, 2.51, 2.42, 2.59, 2.53, 2.49, 2.59, 2.55, 2.5], [4.69, 4.42, 4.73, 4.99, 5.3, 5.51, 5.88, 6.17, 3.15, 3.08, 3.06, 3.17, 3.09, 2.88, 2.91, 2.92, 3.0, 2.93, 2.82, 2.74, 2.8, 2.89, 2.8, 2.79, 2.9, 2.93, 2.75, 2.78, 2.86, 2.79, 2.84, 2.92, 2.58, 2.67, 2.77, 2.85, 2.62, 2.66, 2.75, 2.74, 2.72, 2.56, 2.51, 2.55, 2.58, 2.56, 2.7, 2.62, 2.26, 2.28, 2.33, 2.37, 2.38, 2.38, 2.39, 2.36, 2.49, 2.37, 2.45, 2.47, 2.52, 2.5, 2.49, 2.58, 2.61, 2.55, 2.51, 2.56, 2.5, 2.53, 2.59, 2.53, 2.49, 2.58, 2.52, 2.49, 2.53, 2.53, 2.61, 2.58, 2.61, 2.49, 2.53, 2.61, 2.52, 2.51, 2.5, 2.53, 2.52, 2.55, 2.48, 2.5, 2.59, 2.62], [4.8, 4.41, 4.63, 4.95, 5.17, 5.53, 5.89, 6.23, 3.1, 3.03, 3.1, 3.12, 3.09, 3.03, 2.95, 2.95, 2.88, 2.91, 2.83, 2.79, 2.82, 2.84, 2.73, 2.81, 2.86, 2.9, 2.67, 2.78, 2.92, 2.81, 2.88, 2.91, 2.7, 2.72, 2.82, 2.79, 2.6, 2.69, 2.71, 2.69, 2.73, 2.55, 2.52, 2.59, 2.55, 2.56, 2.66, 2.69, 2.24, 2.28, 2.33, 2.36, 2.4, 2.48, 2.41, 2.45, 2.46, 2.39, 2.46, 2.49, 2.53, 2.43, 2.52, 2.48, 2.49, 2.62, 2.51, 2.55, 2.59, 2.66, 2.6, 2.62, 2.66, 2.6, 2.55, 2.5, 2.53, 2.53, 2.48, 2.56, 2.52, 2.47, 2.63, 2.53, 2.54, 2.51, 2.5, 2.56, 2.61, 2.61, 2.55, 2.53, 2.59, 2.57], [4.72, 4.42, 4.65, 4.87, 5.24, 5.49, 5.82, 6.1, 3.08, 3.1, 3.15, 3.21, 3.15, 3.01, 2.92, 2.98, 3.0, 2.93, 2.84, 2.78, 2.81, 2.92, 2.78, 2.79, 2.9, 2.89, 2.76, 2.85, 2.88, 2.86, 2.92, 2.96, 2.68, 2.67, 2.71, 2.82, 2.62, 2.66, 2.67, 2.73, 2.68, 2.48, 2.5, 2.55, 2.59, 2.64, 2.57, 2.6, 2.28, 2.31, 2.28, 2.29, 2.37, 2.33, 2.38, 2.41, 2.45, 2.41, 2.43, 2.52, 2.53, 2.53, 2.55, 2.56, 2.52, 2.52, 2.58, 2.62, 2.61, 2.54, 2.57, 2.58, 2.5, 2.53, 2.55, 2.6, 2.62, 2.55, 2.56, 2.51, 2.52, 2.55, 2.45, 2.56, 2.52, 2.57, 2.58, 2.62, 2.49, 2.59, 2.6, 2.53, 2.56, 2.52]]


newres = []
for i in range(len(result)):
    newres += [result[i][8:]]


m = 0 
for i in range(len(newres)):
    m = max(m,max(newres[i]))
    
for i in range(len(newres)):
    if (max(newres[i]) == m):
        newres[i] = [(newres[i-1][x] + newres[i+1][x])/2  for x in range(len(newres[i-1])) ]
    
#fig, ax = plt.subplots(figsize=(7,4))
fig, ax = plt.subplots(figsize=(10.1,3))


xlabel = xr
ylabel = yr[::-1]
ax = seaborn.heatmap(newres,
                     xticklabels=xlabel[8:],
                     ax=ax,
                     yticklabels=ylabel,cmap="magma",cbar_kws={
                         'label': 'Execution time / s',
#                         "orientation" : "horizontal",
                     })
ax.set_xlabel("Initial minor heap size / Mb")
ax.set_ylabel("Initial major heap size / Mb")


for label in ax.yaxis.get_ticklabels():
    label.set_visible(False)

for label in ax.xaxis.get_ticklabels():
    label.set_visible(False)

    
for label in ax.yaxis.get_ticklabels()[::10]:
    label.set_visible(True)

for label in ax.xaxis.get_ticklabels()[6::20]:
    label.set_visible(True)
    label.set_rotation(0)

plt.savefig((loc + "/gc_heat_map.png"),dpi=800,bbox_inches='tight')

# %%
index = int(len(result)*0.6)
print(index)
extracted = result[index]
print(len(extracted))
# Out:
# 57
# 94

# %%
top = 3000
xr = range(0,380,2)

def getResult():
    result = []
    major = 525
    for minor in xr:

            run = subprocess.check_output([command, str(major)+"M", str(minor)+"M", testcase],
                                          stderr=subprocess.STDOUT).decode('ascii')

            f = float(run)
            print(str(major)+","+str(minor))
            print(f)
            print()
            result += [f]
    print(result)
    return result

# res1 = getResult()
# res2 = getResult()
# res3 = getResult()
# res4 = getResult()

# %%
res1 = [4.19, 3.89, 4.22, 4.18, 4.55, 4.67, 4.66, 4.78, 4.97, 5.09, 5.11, 3.23, 3.02, 3.16, 3.24, 3.18, 3.1, 3.03, 2.95, 3.04, 3.07, 3.0, 2.96, 3.07, 3.05, 2.98, 2.96, 2.99, 2.93, 2.99, 2.87, 2.79, 2.88, 2.8, 2.86, 2.82, 2.8, 2.68, 2.75, 2.84, 2.69, 2.62, 2.8, 2.83, 2.89, 2.92, 2.74, 2.71, 2.76, 2.86, 2.75, 2.87, 2.84, 2.83, 2.7, 2.72, 2.76, 2.69, 2.74, 2.73, 2.7, 2.78, 2.82, 2.89, 2.95, 2.79, 2.65, 2.7, 2.69, 2.69, 2.72, 2.62, 2.73, 2.72, 2.51, 2.53, 2.55, 2.57, 2.55, 2.62, 2.68, 2.59, 2.64, 2.7, 2.5, 2.59, 2.5, 2.58, 2.42, 2.49, 2.56, 2.53, 2.58, 2.53, 2.64, 2.58, 2.57, 2.58, 2.27, 2.17, 2.28, 2.23, 2.26, 2.2, 2.22, 2.33, 2.29, 2.3, 2.35, 2.26, 2.41, 2.42, 2.23, 2.32, 2.3, 2.41, 2.41, 2.31, 2.34, 2.39, 2.34, 2.37, 2.48, 2.39, 2.46, 2.49, 2.43, 2.45, 2.57, 2.46, 2.5, 2.48, 2.5, 2.45, 2.51, 2.46, 2.48, 2.38, 2.5, 2.52, 2.43, 2.52, 2.48, 2.46, 2.42, 2.57, 2.48, 2.46, 2.45, 2.52, 2.49, 2.37, 2.48, 2.51, 2.43, 2.44, 2.41, 2.36, 2.42, 2.49, 2.35, 2.42, 2.4, 2.44, 2.47, 2.39, 2.45, 2.47, 2.52, 2.44, 2.43, 2.42, 2.43, 2.41, 2.41, 2.44, 2.41, 2.42, 2.44, 2.45, 2.36, 2.54, 2.44, 2.44, 2.44, 2.44, 2.47, 2.52, 2.35, 2.46]

# %%
res2 = [3.73, 3.7, 3.94, 4.16, 4.29, 4.37, 4.48, 4.62, 4.75, 4.93, 5.33, 3.06, 3.08, 3.17, 3.1, 3.14, 3.04, 2.99, 2.98, 2.92, 2.92, 2.86, 2.95, 2.89, 2.99, 2.94, 2.93, 2.88, 3.1, 3.12, 3.06, 3.22, 3.01, 2.87, 3.0, 2.84, 2.74, 2.75, 2.74, 2.75, 2.6, 2.67, 2.73, 2.72, 2.74, 2.78, 2.63, 2.58, 2.64, 2.88, 2.82, 2.86, 2.84, 2.77, 2.91, 2.94, 3.0, 3.1, 3.01, 2.95, 3.02, 2.99, 2.72, 2.76, 2.76, 2.83, 2.51, 2.52, 2.62, 2.65, 2.73, 2.69, 2.62, 2.65, 2.54, 2.42, 2.47, 2.54, 2.59, 2.55, 2.65, 2.58, 2.71, 2.76, 2.89, 2.68, 2.45, 2.4, 2.43, 2.5, 2.42, 2.45, 2.48, 2.42, 2.56, 2.5, 2.51, 2.56, 2.13, 2.17, 2.16, 2.22, 2.25, 2.15, 2.23, 2.21, 2.22, 2.23, 2.28, 2.28, 2.24, 2.24, 2.35, 2.21, 2.3, 2.29, 2.29, 2.31, 2.29, 2.35, 2.3, 2.35, 2.38, 2.46, 2.34, 2.35, 2.31, 2.43, 2.37, 2.36, 2.47, 2.4, 2.43, 2.42, 2.38, 2.45, 2.53, 2.42, 2.38, 2.4, 2.37, 2.42, 2.49, 2.35, 2.42, 2.42, 2.47, 2.39, 2.42, 2.41, 2.31, 2.42, 2.4, 2.43, 2.45, 2.35, 2.38, 2.45, 2.49, 2.5, 2.41, 2.42, 2.43, 2.39, 2.39, 2.4, 2.47, 2.32, 2.41, 2.36, 2.42, 2.39, 2.39, 2.51, 2.45, 2.4, 2.34, 2.4, 2.44, 2.39, 2.42, 2.37, 2.45, 2.41, 2.43, 2.46, 2.39, 2.42, 2.4, 2.38]

# %%
res3 = [3.62, 3.73, 3.93, 4.14, 4.3, 4.35, 4.5, 4.59, 4.82, 5.07, 5.07, 3.14, 3.11, 3.11, 3.15, 3.15, 3.01, 3.01, 2.97, 2.83, 2.93, 2.9, 2.92, 2.94, 2.98, 3.01, 2.94, 2.93, 2.79, 2.87, 2.86, 2.79, 2.77, 2.75, 2.77, 2.66, 2.8, 2.65, 2.76, 2.77, 2.55, 2.68, 2.74, 2.73, 2.75, 2.85, 2.62, 2.61, 2.67, 2.7, 2.77, 2.78, 2.84, 2.81, 2.65, 2.68, 2.69, 2.65, 2.68, 2.67, 2.75, 2.64, 2.75, 2.76, 2.72, 2.81, 2.49, 2.65, 2.68, 2.63, 2.67, 2.63, 2.69, 2.69, 2.44, 2.57, 2.47, 2.5, 2.5, 2.55, 2.56, 2.53, 2.56, 2.58, 2.45, 2.43, 2.34, 2.42, 2.38, 2.42, 2.44, 2.44, 2.48, 2.47, 2.43, 2.48, 2.53, 2.57, 2.18, 2.12, 2.17, 2.09, 2.14, 2.09, 2.25, 2.23, 2.25, 2.19, 2.18, 2.18, 2.27, 2.25, 2.27, 2.3, 2.23, 2.23, 2.27, 2.31, 2.34, 2.29, 2.23, 2.36, 2.35, 2.32, 2.36, 2.46, 2.42, 2.34, 2.43, 2.46, 2.37, 2.46, 2.35, 2.44, 2.44, 2.34, 2.43, 2.49, 2.36, 2.4, 2.38, 2.35, 2.41, 2.38, 2.42, 2.43, 2.4, 2.37, 2.38, 2.33, 2.43, 2.36, 2.33, 2.36, 2.44, 2.32, 2.35, 2.65, 2.39, 2.38, 2.36, 2.34, 2.33, 2.34, 2.42, 2.3, 2.42, 2.37, 2.38, 2.39, 2.45, 2.4, 2.36, 2.42, 2.3, 2.35, 2.38, 2.37, 2.48, 2.39, 2.36, 2.42, 2.46, 2.39, 2.4, 2.43, 2.45, 2.44, 2.3, 2.43]

# %%
res4 = [3.57, 3.63, 3.93, 3.98, 4.22, 4.31, 4.45, 4.56, 4.71, 4.88, 5.03, 3.1, 3.04, 3.08, 3.13, 3.16, 2.99, 2.99, 2.92, 2.87, 2.85, 2.81, 2.9, 2.94, 2.98, 2.93, 2.88, 2.9, 2.79, 2.84, 2.78, 2.71, 2.74, 2.67, 2.83, 2.68, 2.8, 2.74, 2.99, 3.11, 2.83, 3.01, 2.96, 3.04, 3.2, 3.14, 2.6, 2.6, 2.71, 2.69, 2.75, 2.76, 2.83, 2.81, 2.64, 2.71, 2.68, 2.68, 2.77, 2.63, 2.77, 2.71, 2.67, 2.73, 2.87, 2.82, 2.6, 2.58, 2.55, 2.6, 2.63, 2.61, 2.68, 2.66, 2.44, 2.5, 2.47, 2.56, 2.57, 2.53, 2.61, 2.58, 2.57, 2.64, 2.36, 2.37, 2.45, 2.45, 2.42, 2.47, 2.51, 2.52, 2.51, 2.49, 2.57, 2.53, 2.53, 2.58, 2.13, 2.12, 2.18, 2.19, 2.21, 2.2, 2.26, 2.23, 2.22, 2.21, 2.21, 2.29, 2.29, 2.19, 2.35, 2.3, 2.31, 2.44, 2.3, 2.36, 2.31, 2.32, 2.4, 2.29, 2.4, 2.46, 2.28, 2.4, 2.44, 2.46, 2.36, 2.43, 2.43, 2.55, 2.46, 2.42, 2.39, 2.34, 2.45, 2.66, 2.46, 2.41, 2.42, 2.43, 2.52, 2.4, 2.43, 2.4, 2.39, 2.37, 2.34, 2.43, 2.47, 2.49, 2.46, 2.38, 2.46, 2.35, 2.41, 2.39, 2.37, 2.39, 2.4, 2.35, 2.45, 2.42, 2.38, 2.5, 2.44, 2.38, 2.43, 2.41, 2.34, 2.37, 2.4, 2.4, 2.45, 2.41, 2.4, 2.46, 2.43, 2.4, 2.38, 2.41, 2.38, 2.38, 2.41, 2.41, 2.41, 2.35, 2.46, 2.46]

# %%
stripe = [3.7, 3.93, 3.91, 3.95, 4.07, 4.14, 4.16, 4.22, 4.28, 4.27, 4.45, 4.56, 4.61, 4.54, 4.71, 4.88, 4.92, 5.06, 5.07, 5.17, 5.26, 3.12, 3.25, 3.2, 3.11, 3.08, 3.17, 3.25, 3.26, 3.27, 3.27, 3.1, 3.16, 3.15, 3.01, 3.09, 3.0, 2.99, 3.01, 3.08, 2.98, 3.01, 2.9, 2.94, 2.99, 3.04, 2.99, 3.04, 3.05, 3.14, 3.04, 3.09, 3.08, 3.02, 3.02, 2.96, 2.93, 2.9, 2.91, 2.77, 2.84, 2.88, 2.8, 2.82, 2.87, 2.88, 2.87, 2.87, 2.96, 2.96, 2.72, 2.82, 2.85, 2.94, 2.72, 2.72, 2.69, 2.76, 2.79, 2.68, 2.73, 2.68, 2.73, 2.65, 2.81, 2.77, 2.76, 2.79, 2.82, 2.84, 2.86, 2.65, 2.73, 2.76, 2.75, 2.72, 2.83, 2.75, 2.82, 2.78, 2.77, 2.75, 2.86, 2.88, 2.82, 2.89, 2.89, 2.64, 2.66, 2.7, 2.77, 2.68, 2.77, 2.7, 2.77, 2.82, 2.83, 2.93, 2.81, 2.72, 2.74, 2.77, 2.86, 2.75, 2.86, 2.79, 2.87, 2.79, 2.76, 2.89, 2.89, 2.59, 2.66, 2.54, 2.64, 2.74, 2.7, 2.61, 2.71, 2.65, 2.69, 2.61, 2.69, 2.69, 2.76, 2.68, 2.74, 2.51, 2.54, 2.52, 2.5, 2.65, 2.56, 2.56, 2.62, 2.58, 2.64, 2.64, 2.77, 2.74, 2.66, 2.61, 2.66, 2.68, 2.62, 2.72, 2.86, 2.78, 2.5, 2.36, 2.4, 2.48, 2.43, 2.51, 2.53, 2.55, 2.49, 2.54, 2.48, 2.54, 2.57, 2.54, 2.49, 2.55, 2.57, 2.46, 2.53, 2.54, 2.54, 2.54, 2.58, 2.59, 2.6, 2.55, 2.62, 2.58, 2.3, 2.2, 2.26, 2.21, 2.24, 2.17, 2.25, 2.12, 2.18, 2.15, 2.21, 2.19, 2.2, 2.32, 2.35, 2.24, 2.31, 2.31, 2.18, 2.35, 2.17, 2.22, 2.37, 2.38, 2.3, 2.3, 2.31, 2.28, 2.42, 2.32, 2.26, 2.33, 2.35, 2.41, 2.29, 2.36, 2.34, 2.44, 2.39, 2.34, 2.39, 2.42, 2.37, 2.33, 2.36, 2.43, 2.46, 2.49, 2.47, 2.47, 2.45, 2.49, 2.42, 2.44, 2.41, 2.4, 2.51, 2.5, 2.48, 2.52, 2.5, 2.4, 2.45, 2.54, 2.46, 2.42, 2.39, 2.46, 2.44, 2.58, 2.57, 2.48, 2.49, 2.52, 2.5, 2.43, 2.46, 2.46, 2.5, 2.44, 2.42, 2.46, 2.49, 2.46, 2.39, 2.45, 2.42, 2.41, 2.58, 2.5, 2.46, 2.57, 2.51, 2.55, 2.47, 2.54, 2.51, 2.49, 2.37, 2.47, 2.46, 2.45, 2.42, 2.52, 2.45, 2.44, 2.52, 2.43, 2.56, 2.57, 2.46, 2.45, 2.5, 2.55, 2.48, 2.51, 2.52, 2.44, 2.53, 2.51, 2.49, 2.41, 2.51, 2.41, 2.45, 2.49, 2.47, 2.47, 2.56, 2.52, 2.47, 2.47, 2.6, 2.8, 2.81, 2.45, 2.77, 2.82, 2.61, 2.95, 3.02, 2.94, 2.87, 2.73, 2.53, 2.86, 2.6, 2.63, 2.56, 3.21, 2.86, 2.54, 2.55, 2.93, 2.72, 3.06, 2.5, 2.45, 2.51, 2.58, 2.69, 2.58, 2.51, 2.72, 2.55, 2.67, 2.61, 2.71, 2.73, 2.67, 2.66, 2.74, 2.63, 2.87, 2.51, 2.68, 2.45, 2.51, 2.72, 2.53, 2.54, 2.55, 2.51, 2.52]


res0 = [3.96, 3.84, 4.03, 4.21, 4.29, 4.44, 4.55, 4.62, 4.83, 5.24, 5.2, 3.12, 3.08, 3.33, 3.19, 3.27, 3.09, 3.0, 3.09, 3.0, 3.03, 3.02, 3.0, 3.02, 3.12, 3.06, 3.03, 2.93, 2.87, 2.9, 2.8, 2.73, 2.79, 2.78, 2.85, 2.79, 2.79, 2.74, 2.79, 2.85, 2.62, 2.74, 2.84, 2.87, 2.9, 2.86, 2.66, 2.71, 2.73, 2.8, 2.79, 2.8, 2.9, 2.93, 2.62, 2.69, 2.69, 2.7, 2.69, 2.79, 2.76, 2.83, 2.79, 2.9, 2.84, 2.86, 2.58, 2.6, 2.73, 2.74, 2.75, 2.71, 2.67, 2.69, 2.53, 2.52, 2.58, 2.66, 2.58, 2.65, 2.68, 2.69, 2.72, 2.78, 2.53, 2.5, 2.5, 2.48, 2.51, 2.51, 2.49, 2.51, 2.59, 2.5, 2.45, 2.63, 2.57, 2.65, 2.21, 2.23, 2.24, 2.21, 2.22, 2.38, 2.32, 2.31, 2.23, 2.31, 2.32, 2.28, 2.15, 2.32, 2.38, 2.35, 2.42, 2.53, 2.38, 2.68, 2.53, 2.44, 2.46, 2.47, 2.4, 2.52, 2.28, 2.47, 2.6, 2.43, 2.51, 2.48, 2.51, 2.47, 2.54, 2.46, 2.4, 2.49, 2.43, 2.43, 2.7, 2.43, 2.49, 2.54, 2.47, 2.44, 2.54, 2.45, 2.44, 2.41, 2.47, 2.49, 2.47, 2.48, 2.47, 2.48, 2.51, 2.41, 2.41, 2.52, 2.51, 2.5, 2.47, 2.41, 2.45, 2.46, 2.39, 2.5, 2.51, 2.52, 2.5, 2.51, 2.42, 2.37, 2.48, 2.51, 2.59, 2.5, 2.53, 2.48, 2.45, 2.41, 2.46, 2.43, 2.43, 2.43, 2.52, 2.52, 2.56, 2.54, 2.51, 2.5]

xr = range(0,380,2)

seaborn.set_style("white")


#fig, ax = plt.subplots(figsize=(5.7,4.2))


plt.rc('axes', linewidth=1)

fig, ax = plt.subplots(figsize=(8,3))


results = [res0,res1,res2,res3,res4]
means = []
stdevs = []
for i in range(len(res0)):
    crossection = []
    for j in range(len(results)):
        crossection += [ results[j][i] ]
    means += [statistics.mean(crossection)]
    stdevs += [statistics.stdev(crossection)]
        
        
upper = [means[i] + stdevs[i] for i in range(len(means))]
lower = [means[i] - stdevs[i] for i in range(len(means))]


cut = 11
xr = xr[cut:]
lower = lower[cut:]
upper = upper[cut:]
means = means[cut:]

ax.fill_between(xr,lower,upper,alpha=1,color="#8cdcff",label="$\pm 1 \sigma$")
plt.plot(xr, means,linewidth=0.6,color="black")
plt.legend(frameon=False)
plt.xlabel("Initial minor heap size / Mb")
plt.ylabel("Execution time / s")
plt.margins(
#     x=0
)


# plt.plot(upper,linewidth=0.5)
# plt.plot(lower,linewidth=0.5)


plt.savefig((loc + "/gc_time_series.png"),dpi=800,bbox_inches='tight')

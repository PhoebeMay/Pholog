# %%
import statistics
import matplotlib.pyplot as plt

plt.rc('text', usetex=True)

# %%
pho = [0.52, 1.01, 1.56, 1.92, 2.48]
swi = [1.28, 5.18, 11.20, 19.73, 29.51]
gnu = [1.58, 2.52, 3.97, 4.81, 6.73]


x = [i for i in range(500000, 3000000, 500000)]

# %%
fig, ax = plt.subplots()

def addline(mean,stdev,name,color): 
    ax.errorbar(x,mean,yerr=stdev,label=name, fmt='x', 
                capsize=4,
                markersize=8,
                markeredgewidth=0.5,
                capthick=0.5,
                linestyle='solid',linewidth=0.5,color=color)

addline(pho_mean,pho_stdev,"Pholog",'#00a030')
addline(swi_mean,swi_stdev,"SWI",'#ce0000')
addline(gnu_mean,gnu_stdev,"GNU x 100",'#0091db')

ax.legend()


for label in ax.xaxis.get_ticklabels():
    label.set_visible(False)

for label in ax.xaxis.get_ticklabels()[::2]:
    label.set_visible(True)

# %%
fig, ax = plt.subplots()

def addline(mean,stdev,name,color): 
    ax.errorbar(x,mean,yerr=stdev,label=name, fmt='x', 
                capsize=4,
                markersize=8,
                markeredgewidth=0.5,
                capthick=0.5,
                linestyle='solid',linewidth=0.5,color=color)

addline(pho_mean,pho_stdev,"Pholog",'#00a030')
addline(swi_mean,swi_stdev,"SWI",'#ce0000')
addline(gnu_mean,gnu_stdev,"GNU x 100",'#0091db')

ax.legend()


for label in ax.xaxis.get_ticklabels():
    label.set_visible(False)

for label in ax.xaxis.get_ticklabels()[::2]:
    label.set_visible(True)

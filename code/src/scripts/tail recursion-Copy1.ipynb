# %%
import matplotlib.pyplot as plt
import  matplotlib
import statistics

font = {'size'   : 15}

loc = "/home/phoebe/Dropbox/Stuff1819/proooject/diss/graphs"

plt.rc('text', usetex=True)



plt.rc('font', **font)

# %%
tro = [2.85, 2.85, 2.85, 3.01, 2.98, 2.85, 2.86, 2.85, 2.83, 2.83]
trno = [10.77, 10.46, 10.23, 10.20, 10.06, 10.52, 10.15, 9.87, 10.11, 11.27]

# %%
# yes tail recursion 

yes = [(1553525377280322883,148954),
(1553525377344841044,150498),
(1553525377377311894,152005),
(1553525377402507988,153553),
(1553525377423872787,155067),
(1553525377445241743,156621),
(1553525377466556132,158133),
(1553525377490088153,159677),
(1553525377513176530,161189),
(1553525377533482758,162742),
(1553525377553719486,164242),
(1553525377573946455,165794),
(1553525377598769244,167300),
(1553525377620138435,168850),
(1553525377640418865,170386),
(1553525377661654750,171935),
(1553525377683873254,173487),
(1553525377707796865,175009),
(1553525377730625510,176545),
(1553525377752147716,178052),
(1553525377773693246,179600),
(1553525377800224472,181114),
(1553525377823865672,182668),
(1553525377845559871,184180),
(1553525377867158560,185724),
(1553525377890846381,187236),
(1553525377915484666,188789),
(1553525377937860130,190289),
(1553525377959474957,191841),
(1553525377981033187,193347),
(1553525378007083066,194897),
(1553525378029932592,196433),
(1553525378052739941,197977),
(1553525378075517536,199491),
(1553525378101625314,201039),
(1553525378124480358,202546),
(1553525378146809519,204098),
(1553525378168397520,205620),
(1553525378190809860,176622),
(1553525378214263310,178129),
(1553525378234588047,179677),
(1553525378254935845,181191),
(1553525378275244590,182881),
(1553525378299605343,184429),
(1553525378321243039,185943),
(1553525378342668653,187497),
(1553525378364048302,189009),
(1553525378385427312,190553),
(1553525378410331073,192065),
(1553525378431748098,193618),
(1553525378452212340,195118),
(1553525378472444249,196670),
(1553525378495177789,198176),
(1553525378518530915,199726),
(1553525378540497804,201262),
(1553525378562192498,202806),
(1553525378583575160,204320),
(1553525378608407439,205868),
(1553525378629799592,207375),
(1553525378651186425,208927),
(1553525378672755677,210481),
(1553525378696972166,211995),
(1553525378720890197,213549),
(1553525378743699390,215061),
(1553525378766225838,216605),
(1553525378788245865,218117),
(1553525378814078776,219670),
(1553525378836874548,221170),
(1553525378859657599,222722),
(1553525378881574623,224228),
(1553525378907236269,225778),
(1553525378928857841,227314),
(1553525378950465834,228858),
(1553525378972038950,230372),
(1553525378995720422,231920),
(1553525379020138793,233427),
(1553525379042960085,234979),
(1553525379065719290,236501),
(1553525379088585655,238037),
(1553525379114641643,239544),
(1553525379137507139,241092),
(1553525379160344546,242606),
(1553525379183179682,244160),
(1553525379208469741,176540),
(1553525379229953349,178084),
(1553525379251468513,179596),
(1553525379272896227,181149),
(1553525379295884997,182649),
(1553525379319266885,184201),
(1553525379340761716,185707),
(1553525379362228631,187257),
(1553525379383633757,188793),
(1553525379408497487,190337),
(1553525379429962972,191851),
(1553525379451414483,193399),
(1553525379472756301,194906),
(1553525379495480831,196458),
(1553525379518956175,197980),
(1553525379540356114,199516),
(1553525379561797904,201023),
(1553525379583175069,202571),
(1553525379607976779,204085),
(1553525379629444004,205639),
(1553525379654343024,207151),
(1553525379675966328,208695),
(1553525379699296171,210207),
(1553525379722303650,211760),
(1553525379743727298,213260),
(1553525379765174590,214812),
(1553525379786576930,216318),
(1553525379811692529,217868),
(1553525379834481065,219416),
(1553525379857250922,220914),
(1553525379880057053,222467),
(1553525379905353568,223998),
(1553525379927712819,225542),
(1553525379949325048,227049),
(1553525379970926605,228597),
(1553525379992562777,230111),
(1553525380019343036,231665)]

(start,z) = yes[0]
yes_x = [(i - start)/1000000000 for (i,j) in yes]
yes_y = [j for (i,j) in yes]

# %%
no = [(1553393324870227632,150057),
(1553393324894702112,151750),
(1553393324923391573,153668),
(1553393324949605630,155325),
(1553393324974261649,157222),
(1553393324996935160,158915),
(1553393325022725774,160935),
(1553393325046390840,162839),
(1553393325070667270,164532),
(1553393325093625568,166405),
(1553393325117197807,168099),
(1553393325140446055,170119),
(1553393325164050450,172057),
(1553393325188043803,173707),
(1553393325213541598,175609),
(1553393325238119954,177289),
(1553393325262937825,179160),
(1553393325288863694,180853),
(1553393325312588413,182726),
(1553393325338195245,184420),
(1553393325365609476,186317),
(1553393325391314819,187967),
(1553393325416134523,189869),
(1553393325441562286,191549),
(1553393325465340736,193420),
(1553393325490796293,195113),
(1553393325516399033,197022),
(1553393325540634624,198679),
(1553393325566035608,200576),
(1553393325590209810,202226),
(1553393325615398486,204128),
(1553393325640449740,205808),
(1553393325664235651,176435),
(1553393325688189226,178128),
(1553393325710254127,180046),
(1553393325734237288,181703),
(1553393325757333529,183600),
(1553393325781106033,185293),
(1553393325803412257,187313),
(1553393325827701139,189217),
(1553393325851401544,190910),
(1553393325875188060,192783),
(1553393325897323429,194477),
(1553393325921370115,196497),
(1553393325944449909,198401),
(1553393325968242675,200094),
(1553393325991025551,201967),
(1553393326015093464,203661),
(1553393326037707589,205558),
(1553393326061621490,207208),
(1553393326084294820,209110),
(1553393326109239492,210795),
(1553393326134581718,212692),
(1553393326158590635,214342),
(1553393326184003252,216244),
(1553393326209102454,217924),
(1553393326233527041,219795),
(1553393326259028466,221488),
(1553393326283105628,223397),
(1553393326308699941,225054),
(1553393326334303527,226951),
(1553393326358927941,228601),
(1553393326387580206,230503),
(1553393326414170544,232183),
(1553393326438648869,234054),
(1553393326463765538,235747),
(1553393326489022536,237665),
(1553393326513651198,239322),
(1553393326539030361,241219),
(1553393326564292963,242912),
(1553393326588349598,244932),
(1553393326612822839,177490),
(1553393326635737366,179147),
(1553393326660105164,181044),
(1553393326683059027,182738),
(1553393326706726412,184758),
(1553393326730441639,186662),
(1553393326754217629,188355),
(1553393326777547411,190228),
(1553393326800953095,191922),
(1553393326825309333,193979),
(1553393326849351169,195841),
(1553393326873683152,197534),
(1553393326896368580,199443),
(1553393326920418784,201100),
(1553393326943386560,202997),
(1553393326967544080,204647),
(1553393326990494899,206549),
(1553393327014375723,208229),
(1553393327037784870,210100),
(1553393327061535761,211793),
(1553393327085349459,213711),
(1553393327108135911,215368),
(1553393327132371611,217265),
(1553393327156438505,218956),
(1553393327181746714,220874),
(1553393327205690778,222531),
(1553393327230754708,224428),
(1553393327255597712,226121),
(1553393327280303939,228141),
(1553393327305780249,230045),
(1553393327330288413,231738),
(1553393327355731903,233611),
(1553393327381434628,235305),
(1553393327405751141,237325),
(1553393327431468725,239229),
(1553393327457213915,240922),
(1553393327481299134,242795),
(1553393327506951004,244489),
(1553393327532635312,246386),
(1553393327557183583,248036),
(1553393327582788856,249938),
(1553393327607494785,251618),
(1553393327632023219,176018),
(1553393327656470856,177711),
(1553393327679589781,179620),
(1553393327703640839,181277),
(1553393327726286934,183174),
(1553393327750521977,184824),
(1553393327773183178,186726)]

(start,z)=no[0]
no_x = [(i-start)/1000000000 for (i,j) in no]
no_y = [j for (i,j) in no]

# %%
yes2 = [(1553525383686273749,148954),
(1553525383731482704,150498),
(1553525383767137470,152005),
(1553525383789596996,153553),
(1553525383809749949,155067),
(1553525383831144292,156621),
(1553525383854803413,158133),
(1553525383876125696,159677),
(1553525383897452342,161189),
(1553525383920945020,162742),
(1553525383945635745,164242),
(1553525383966989551,165794),
(1553525383988250566,167300),
(1553525384009501000,168850),
(1553525384037862017,170386),
(1553525384060322980,171935),
(1553525384083010640,173487),
(1553525384105675506,175009),
(1553525384131710436,176545),
(1553525384157391414,178052),
(1553525384180178359,179600),
(1553525384202894855,181114),
(1553525384225589048,182668),
(1553525384250996338,184180),
(1553525384273709522,185724),
(1553525384296394628,187236),
(1553525384319061435,188789),
(1553525384349238647,190289),
(1553525384372000154,191841),
(1553525384394697330,193347),
(1553525384417389078,194897),
(1553525384442167543,196433),
(1553525384465652285,197977),
(1553525384488360086,199491),
(1553525384511138329,201039),
(1553525384534338449,202546),
(1553525384559407440,204098),
(1553525384582223781,205620),
(1553525384603868980,176622),
(1553525384625188525,178129),
(1553525384652669937,179677),
(1553525384673346324,181191),
(1553525384693768489,182881),
(1553525384713982108,184429),
(1553525384734766273,185943),
(1553525384762931377,187497),
(1553525384784335159,189009),
(1553525384805669492,190553),
(1553525384826662966,192065),
(1553525384850316582,193618),
(1553525384870566573,195118),
(1553525384890825877,196670),
(1553525384911019048,198176),
(1553525384931215997,199726),
(1553525384953467275,201262),
(1553525384973900891,202806),
(1553525384994111170,204320),
(1553525385017409275,205868),
(1553525385038998037,207375),
(1553525385061298140,208927),
(1553525385082559800,210481),
(1553525385105076996,211995),
(1553525385127850468,213549),
(1553525385153656759,215061),
(1553525385181431770,216605),
(1553525385204250808,218117),
(1553525385227008149,219670),
(1553525385252314976,221170),
(1553525385275735798,222722),
(1553525385297306348,224228),
(1553525385319462613,225778),
(1553525385342753471,227314),
(1553525385366099150,228858),
(1553525385387677019,230372),
(1553525385409254897,231920),
(1553525385430815970,233427),
(1553525385455834602,234979),
(1553525385477388878,236501),
(1553525385498984811,238037),
(1553525385520555127,239544),
(1553525385543798138,241092),
(1553525385567165024,242606),
(1553525385588785536,244160),
(1553525385609397383,176540),
(1553525385629663925,178084),
(1553525385653730042,179596),
(1553525385674270322,181149),
(1553525385694565366,182649),
(1553525385714846871,184201),
(1553525385735099762,185707),
(1553525385758856977,187257),
(1553525385779149435,188793),
(1553525385799455644,190337),
(1553525385819686496,191851),
(1553525385840434188,193399),
(1553525385864426466,194906),
(1553525385885753905,196458),
(1553525385907050667,197980),
(1553525385928333500,199516),
(1553525385951948193,201023),
(1553525385973024278,202571),
(1553525385993302796,204085),
(1553525386013537097,205639),
(1553525386033775002,207151),
(1553525386057479953,208695),
(1553525386077767992,210207),
(1553525386098049787,211760),
(1553525386118285721,213260),
(1553525386138555121,214812),
(1553525386162291645,216318),
(1553525386182932010,217868),
(1553525386204486069,219416),
(1553525386226016018,220914),
(1553525386249652840,222467),
(1553525386272574066,223998),
(1553525386294165309,225542),
(1553525386315764573,227049),
(1553525386337302744,228597),
(1553525386362159412,230111),
(1553525386383764520,231665)]

(start,z) = yes2[0]
yes2_x = [(i - start)/1000000000 for (i,j) in yes2]
yes2_y = [j for (i,j) in yes2]

# %%
yes3 = [(1553525390546559872,148954),
(1553525390605077676,150498),
(1553525390628640720,152005),
(1553525390648988176,153553),
(1553525390669292806,155067),
(1553525390695287179,156621),
(1553525390715559647,158133),
(1553525390735864335,159677),
(1553525390756102950,161189),
(1553525390780763912,162742),
(1553525390802451230,164242),
(1553525390822767535,165794),
(1553525390843096701,167300),
(1553525390863368066,168850),
(1553525390887435941,170386),
(1553525390908775697,171935),
(1553525390930374109,173487),
(1553525390952012411,175009),
(1553525390976223488,176545),
(1553525391001940960,178052),
(1553525391023585129,179600),
(1553525391045232877,181114),
(1553525391066837150,182668),
(1553525391092650273,184180),
(1553525391114389423,185724),
(1553525391137566106,187236),
(1553525391160933768,188789),
(1553525391186647312,190289),
(1553525391209899791,191841),
(1553525391231491562,193347),
(1553525391256229207,194897),
(1553525391279278495,196433),
(1553525391302708671,197977),
(1553525391324289926,199491),
(1553525391345912621,201039),
(1553525391367496167,202546),
(1553525391392335630,204098),
(1553525391414008959,205620),
(1553525391434661950,176622),
(1553525391455441905,178129),
(1553525391476030651,179677),
(1553525391499343087,181191),
(1553525391519668626,182881),
(1553525391539976119,184429),
(1553525391561322550,185943),
(1553525391583036078,187497),
(1553525391606017608,189009),
(1553525391626333755,190553),
(1553525391646618320,192065),
(1553525391669211345,193618),
(1553525391692870021,195118),
(1553525391713254892,196670),
(1553525391733612955,198176),
(1553525391753915759,199726),
(1553525391778245319,201262),
(1553525391801758534,202806),
(1553525391822070319,204320),
(1553525391842376612,205868),
(1553525391862635382,207375),
(1553525391884448675,208927),
(1553525391907602062,210481),
(1553525391929228036,211995),
(1553525391950887850,213549),
(1553525391972486132,215061),
(1553525391997671151,216605),
(1553525392019382574,218117),
(1553525392041202843,219670),
(1553525392062818554,221170),
(1553525392086232159,222722),
(1553525392109382949,224228),
(1553525392133625251,225778),
(1553525392155336146,227314),
(1553525392177006146,228858),
(1553525392201838590,230372),
(1553525392223509691,231920),
(1553525392245144925,233427),
(1553525392266802692,234979),
(1553525392291156436,236501),
(1553525392313305222,238037),
(1553525392334997093,239544),
(1553525392356688189,241092),
(1553525392378873415,242606),
(1553525392403820736,244160),
(1553525392424505610,176540),
(1553525392444880556,178084),
(1553525392465338864,179596),
(1553525392487565391,181149),
(1553525392509458766,182649),
(1553525392529842055,184201),
(1553525392550207135,185707),
(1553525392570590062,187257),
(1553525392595282822,188793),
(1553525392617428268,190337),
(1553525392638944793,191851),
(1553525392660438363,193399),
(1553525392682395544,194906),
(1553525392705414569,196458),
(1553525392725727536,197980),
(1553525392746037379,199516),
(1553525392766363787,201023),
(1553525392788542829,202571),
(1553525392810463282,204085),
(1553525392830804677,205639),
(1553525392851124422,207151),
(1553525392871466415,208695),
(1553525392895182521,210207),
(1553525392915592787,211760),
(1553525392935921836,213260),
(1553525392956230147,214812),
(1553525392976515796,216318),
(1553525393000895863,217868),
(1553525393022559165,219416),
(1553525393044194994,220914),
(1553525393065814894,222467),
(1553525393089159915,223998),
(1553525393112362638,225542),
(1553525393134015075,227049),
(1553525393155717294,228597),
(1553525393177395211,230111),
(1553525393202362616,231665)]
(start,z) = yes3[0]
yes3_x = [(i - start)/1000000000 for (i,j) in yes3]
yes3_y = [j for (i,j) in yes3]

# %%
yes4 = [(1553525398294116901,148954),
(1553525398361820455,150498),
(1553525398396384670,152005),
(1553525398418644789,153553),
(1553525398443015888,155067),
(1553525398463286403,156621),
(1553525398484662022,158133),
(1553525398506785262,159677),
(1553525398529738533,161189),
(1553525398554018429,162742),
(1553525398574809914,164242),
(1553525398595053263,165794),
(1553525398615250925,167300),
(1553525398639216626,168850),
(1553525398659942035,170386),
(1553525398681278776,171935),
(1553525398702839721,173487),
(1553525398724397449,175009),
(1553525398748193428,176545),
(1553525398769729058,178052),
(1553525398791296889,179600),
(1553525398812857945,181114),
(1553525398837521619,182668),
(1553525398860840134,184180),
(1553525398882427430,185724),
(1553525398904015527,187236),
(1553525398925564770,188789),
(1553525398951040897,190289),
(1553525398972634503,191841),
(1553525398994182176,193347),
(1553525399015720239,194897),
(1553525399040960585,196433),
(1553525399063323720,197977),
(1553525399084885877,199491),
(1553525399106464720,201039),
(1553525399128441632,202546),
(1553525399153503568,204098),
(1553525399175200148,205620),
(1553525399195745108,176622),
(1553525399215992084,178129),
(1553525399239589149,179677),
(1553525399260641359,181191),
(1553525399280934866,182881),
(1553525399301212142,184429),
(1553525399321458073,185943),
(1553525399345799711,187497),
(1553525399366109704,189009),
(1553525399386361809,190553),
(1553525399406572316,192065),
(1553525399426831014,193618),
(1553525399451115300,195118),
(1553525399471449430,196670),
(1553525399491699267,198176),
(1553525399513200142,199726),
(1553525399536628844,201262),
(1553525399558681740,202806),
(1553525399578972299,204320),
(1553525399599240335,205868),
(1553525399619464656,207375),
(1553525399647669098,208927),
(1553525399669797832,210481),
(1553525399691697554,211995),
(1553525399713334614,213549),
(1553525399736116574,215061),
(1553525399759724446,216605),
(1553525399781381542,218117),
(1553525399803057183,219670),
(1553525399824632342,221170),
(1553525399849421757,222722),
(1553525399871082009,224228),
(1553525399892698632,225778),
(1553525399914305895,227314),
(1553525399936882723,228858),
(1553525399960740783,230372),
(1553525399982411694,231920),
(1553525400005561785,233427),
(1553525400028595087,234979),
(1553525400053726163,236501),
(1553525400075518571,238037),
(1553525400097105270,239544),
(1553525400118686353,241092),
(1553525400142276112,242606),
(1553525400165417305,244160),
(1553525400186072142,176540),
(1553525400206381128,178084),
(1553525400226658766,179596),
(1553525400248738501,181149),
(1553525400269108938,182649),
(1553525400289457516,184201),
(1553525400309697845,185707),
(1553525400329944016,187257),
(1553525400354680721,188793),
(1553525400374976273,190337),
(1553525400395775635,191851),
(1553525400416080991,193399),
(1553525400436806620,194906),
(1553525400460138766,196458),
(1553525400480362630,197980),
(1553525400500789060,199516),
(1553525400521148943,201023),
(1553525400543218027,202571),
(1553525400565182794,204085),
(1553525400585482906,205639),
(1553525400605753050,207151),
(1553525400625965271,208695),
(1553525400649515247,210207),
(1553525400670172943,211760),
(1553525400690516618,213260),
(1553525400710819217,214812),
(1553525400731050113,216318),
(1553525400755172540,217868),
(1553525400776784778,219416),
(1553525400798358595,220914),
(1553525400819983927,222467),
(1553525400843123636,223998),
(1553525400866491167,225542),
(1553525400888085423,227049),
(1553525400909760812,228597),
(1553525400931313589,230111),
(1553525400956258224,231665),]

(start,z) = yes4[0]
yes4_x = [(i - start)/1000000000 for (i,j) in yes4]
yes4_y = [j for (i,j) in yes4]

# %%
yes5 = [(1553525406737955846,148954),
(1553525406774710672,150498),
(1553525406813148622,152005),
(1553525406839846903,153553),
(1553525406860553041,155067),
(1553525406883660270,156621),
(1553525406907205841,158133),
(1553525406927925044,159677),
(1553525406950733830,161189),
(1553525406971303607,162742),
(1553525406996439439,164242),
(1553525407018831881,165794),
(1553525407039516215,167300),
(1553525407059909982,168850),
(1553525407082393162,170386),
(1553525407107784322,171935),
(1553525407129512501,173487),
(1553525407152844577,175009),
(1553525407175670738,176545),
(1553525407199259788,178052),
(1553525407221832451,179600),
(1553525407244714284,181114),
(1553525407267836381,182668),
(1553525407293493899,184180),
(1553525407319163378,185724),
(1553525407341015992,187236),
(1553525407363193464,188789),
(1553525407387985347,190289),
(1553525407411751607,191841),
(1553525407434188087,193347),
(1553525407457576610,194897),
(1553525407479465409,196433),
(1553525407505158967,197977),
(1553525407527042950,199491),
(1553525407553156409,201039),
(1553525407575122909,202546),
(1553525407601764825,204098),
(1553525407623668217,205620),
(1553525407645859568,176622),
(1553525407666480566,178129),
(1553525407688645918,179677),
(1553525407711639615,181191),
(1553525407732160117,182881),
(1553525407754068020,184429),
(1553525407774584103,185943),
(1553525407799416347,187497),
(1553525407820069696,189009),
(1553525407841399366,190553),
(1553525407861987388,192065),
(1553525407882552599,193618),
(1553525407906859477,195118),
(1553525407927421109,196670),
(1553525407948339563,198176),
(1553525407968789881,199726),
(1553525407992248951,201262),
(1553525408014682205,202806),
(1553525408037169380,204320),
(1553525408058876217,205868),
(1553525408080452949,207375),
(1553525408105603101,208927),
(1553525408128846485,210481),
(1553525408152234315,211995),
(1553525408175563531,213549),
(1553525408202455200,215061),
(1553525408225718613,216605),
(1553525408249096269,218117),
(1553525408272823202,219670),
(1553525408299525863,221170),
(1553525408322936955,222722),
(1553525408346120657,224228),
(1553525408369165550,225778),
(1553525408394014426,227314),
(1553525408418943501,228858),
(1553525408442043516,230372),
(1553525408466077359,231920),
(1553525408491151774,233427),
(1553525408518286048,234979),
(1553525408542990744,236501),
(1553525408567723762,238037),
(1553525408593434023,239544),
(1553525408620757034,241092),
(1553525408645664694,242606),
(1553525408670452882,244160),
(1553525408698593601,176540),
(1553525408722250373,178084),
(1553525408745421365,179596),
(1553525408768119174,181149),
(1553525408791320723,182649),
(1553525408816868888,184201),
(1553525408839342299,185707),
(1553525408862594765,187257),
(1553525408885461583,188793),
(1553525408912204222,190337),
(1553525408935113273,191851),
(1553525408957903559,193399),
(1553525408980701048,194906),
(1553525409006552286,196458),
(1553525409029131625,197980),
(1553525409051543197,199516),
(1553525409073886571,201023),
(1553525409097619078,202571),
(1553525409122725965,204085),
(1553525409145351131,205639),
(1553525409167980846,207151),
(1553525409191992451,208695),
(1553525409218371814,210207),
(1553525409241073006,211760),
(1553525409263637124,213260),
(1553525409286212143,214812),
(1553525409312258034,216318),
(1553525409335186978,217868),
(1553525409359208051,219416),
(1553525409383220654,220914),
(1553525409410443313,222467),
(1553525409434435112,223998),
(1553525409458450136,225542),
(1553525409482514450,227049),
(1553525409509699279,228597),
(1553525409533794269,230111),
(1553525409557905784,231665),]

(start,z) = yes5[0]
yes5_x = [(i - start)/1000000000 for (i,j) in yes5]
yes5_y = [j for (i,j) in yes4]

# %%
results_x = [yes_x,yes2_x,yes3_x,yes4_x,yes5_x]

yes_avg = []
yes_stdev = []
for i in range(len(yes_x)):
    extracted = []
    for j in range(len(results_x)):
        extracted += [results_x[j][i]]
        
#     print(extracted)
    yes_avg += [statistics.mean(extracted)]
    yes_stdev += [statistics.stdev(extracted)]
    
upper = [yes_avg[i] + 1 * yes_stdev[i] for i in range(len(yes_avg))]
lower = [yes_avg[i] - 1 * yes_stdev[i] for i in range(len(yes_avg))]

# print(yes_stdev)

# %%
import numpy

fig, ax = plt.subplots()

plt.fill_betweenx(yes_y,lower,upper,alpha=1,color="#8cdcff",label="$\pm 1 \sigma$ in time")

for j in numpy.arange(0,1.1,0.1):
    ax.plot([yes_avg[i] - j * yes_stdev[i] for i in range(len(yes_avg))],yes_y,color="#8cdcff")
    ax.plot([yes_avg[i] + j * yes_stdev[i] for i in range(len(yes_avg))],yes_y,color="#8cdcff")


ax.plot(yes_avg,yes_y,color='black',linewidth=1)


plt.legend(frameon=False)


# plt.hlines(yes_y,lower,upper)

# plt.fill(yes_avg,lower,"blue",yes_avg,upper,"blue")


# plt.plot(yes_x,yes_y,color='black',linewidth=0.5)
# plt.plot(yes4_x,yes4_y,color='black',linewidth=0.5)


# plt.errorbar(yes_avg,yes_y,xerr=yes_stdev)


plt.xlabel("Time / s")
plt.ylabel("Words of live data in the major heap")
plt.ticklabel_format(style='sci',scilimits=(0,0))


plt.savefig((loc + "/tail_recursion_opt.png"),dpi=800,bbox_inches='tight')

# %%
no_x_raw = [0, 81182783, 167679359, 250698165, 357914179, 444725594, 549612827, 632445749, 733707112, 877225386, 968417042, 1067989957, 1185482051, 1311516050, 1468672982, 1575802606, 1687081887, 1817533631, 1950657195, 2138864251, 2294935219, 2421558767, 2547271553, 2675697914, 2828035158, 2980416552, 3137111512, 3299256984, 3558657205, 3725974063, 3877469417, 4031676357, 4186902779, 4344360739, 4510591204, 4687826675, 4869619775, 5057860454, 5250849919, 5558003040, 5770576450, 5993821032, 6220860361, 6405190785, 6593793755, 6784665669, 6976291062, 7171407845, 7372521667, 7585884042, 7805068265, 8026808075, 8250616976, 8479443054, 8712175237, 8950475336, 9193849861, 9438061882, 9849811400, 10152727416, 10411278909, 10651982029, 10889376145, 11139712987, 11383316121, 11630176895, 11877692796, 12127557884, 12384111861, 12693471870, 12991148951, 13326193006, 13628405172, 13937236300, 14265154269, 14600248323, 14935170083, 15261277942, 15596603195, 15959424253, 16508410101, 16856589739, 17206269440, 17563698015, 17898046394, 18251778807, 18655153466, 18961048866, 19276303746, 19594917295, 19911710643, 20239131038, 20575101261, 20913345954, 21260309073, 21609562765, 21954265659, 22311741985, 22698125236, 23070688086, 23447055735, 23848606846, 24262657193, 24683565403, 25071791111, 25445090151, 25853547667, 26259706792, 26644875358, 27043368769, 27399596113, 27735547095, 28083596964, 28442052105, 28816281870, 29180345128, 29542703188, 29903187030, 30264441961, 30635662778]
no_x = [i/1000000000 for i in no_x_raw]
no_y = [2828392, 5558504, 8316621, 11019867, 13750271, 16453975, 19184100, 21915109, 24673469, 27403153, 30134188, 32837919, 35568928, 38299955, 41029211, 43760217, 46463926, 49194961, 51925970, 54656997, 57385449, 60116455, 62847490, 65578507, 68282228, 71013255, 73744284, 76475290, 79206325, 81933560, 84664587, 87395611, 90126617, 92857652, 95561376, 98292385, 101023412, 103754441, 106485447, 109216482, 111947499, 114678526, 117404305, 120135311, 122866346, 125597363, 128328390, 131004782, 133735809, 136494139, 139225174, 141956191, 144687218, 147418242, 150149248, 152825663, 155556669, 158287704, 161018713, 163749740, 166473197, 169204203, 171935238, 174666247, 177397274, 180128298, 182859304, 185590339, 188321356, 191052383, 193756085, 196487114, 199218120, 201949155, 204680172, 207411199, 210142223, 212873229, 215604264, 218335281, 221011698, 223742707, 226473734, 229204763, 231935769, 234666804, 237387060, 240118087, 242849116, 245580122, 248311157, 251042174, 253773201, 256504225, 259235231, 261966266, 264697283, 267373700, 270104709, 272835736, 275566765, 278325108, 281056125, 283787152, 286518176, 289194566, 291925595, 294656601, 297387636, 300118645, 300160324, 300160481, 300160638, 300160797, 300160954, 300161111, 300161270, 300161427, 300161584, 300161743]

# %%
no_2_raw = [(1553541734980373304,2812365),
(1553541735079827278,5564481),
(1553541735176631492,8284196),
(1553541735272963995,11004535),
(1553541735377194657,13756349),
(1553541735494282576,16476676),
(1553541735596310590,19228234),
(1553541735730748678,21948587),
(1553541735928458824,24636911),
(1553541736032973832,27388186),
(1553541736184066698,30108517),
(1553541736348390358,32860831),
(1553541736487072542,35549157),
(1553541736592276248,38300001),
(1553541736760078199,40988317),
(1553541736998923505,43772638),
(1553541737194384779,46460957),
(1553541737404326725,49213294),
(1553541737547309075,51899401),
(1553541737662019320,54651715),
(1553541737784512326,57404056),
(1553541737939711474,60092372),
(1553541738183491012,62812681),
(1553541738358877961,65565009),
(1553541738558850664,68317336),
(1553541738717078665,71005657),
(1553541738954279475,73754870),
(1553541739116455331,76443188),
(1553541739255355380,79195522),
(1553541739410672808,81947836),
(1553541739559425647,84636154),
(1553541739725110427,87356489),
(1553541739914412799,90108814),
(1553541740095261587,92861142),
(1553541740288087268,95549468),
(1553541740491003314,98301793),
(1553541740819848121,101054121),
(1553541741025390364,103742447),
(1553541741268732449,106490420),
(1553541741454623471,109178743),
(1553541741646336860,111931069),
(1553541741840266238,114683392),
(1553541742038992740,117371715),
(1553541742242262104,120124041),
(1553541742444345611,122812360),
(1553541742667318336,125596696),
(1553541742905619680,128285020),
(1553541743139934514,131037346),
(1553541743392095029,133725665),
(1553541743630732027,136478002),
(1553541743882790671,139230318),
(1553541744139909663,141918625),
(1553541744412081748,144670966),
(1553541744705546429,147423282),
(1553541745025068709,150111589),
(1553541745271014713,152857599),
(1553541745511064308,155545915),
(1553541745757928766,158298229),
(1553541745994040490,161050570),
(1553541746244415583,163738886),
(1553541746486445671,166491200),
(1553541746731347263,169179518),
(1553541746984158615,171931852),
(1553541747244695117,174684166),
(1553541747514700682,177404493),
(1553541747799570025,180092819),
(1553541748091624139,182845144),
(1553541748388230138,185597472),
(1553541748678387322,188285798),
(1553541748955866510,191038123),
(1553541749240368530,193726446),
(1553541749525936838,196478772),
(1553541749819259936,199231097),
(1553541750138047681,201919420),
(1553541750634450016,204671746),
(1553541750940600518,207424069),
(1553541751237297121,210112392),
(1553541751543338895,212864718),
(1553541751943706519,215544100),
(1553541752244548203,218296437),
(1553541752533234159,221048753),
(1553541752824658887,223737060),
(1553541753133611200,226489401),
(1553541753503929528,229177717),
(1553541753823597279,231930031),
(1553541754134158472,234682372),
(1553541754465064852,237370688),
(1553541754786431204,240123002),
(1553541755111091132,242875343),
(1553541755468537927,245563659),
(1553541755795983220,248315973),
(1553541756186796430,251004291),
(1553541756610580344,253788630),
(1553541756942439287,256476951),
(1553541757293548018,259229279),
(1553541757646470931,261917605),
(1553541757992883152,264669930),
(1553541758368916809,267422258),
(1553541758738347609,270110584),
(1553541759104957330,272862909),
(1553541759486962768,275551232),
(1553541759861583063,278303558),
(1553541760233256393,281055883),
(1553541760614549744,283744206),
(1553541760994170508,286496532),
(1553541761383257754,289248855),
(1553541761854889345,291937178),
(1553541762398283819,294689504),
(1553541762812387184,297377823),
(1553541763246426355,300130160),
(1553541763609075716,300161278),
(1553541763969324619,300161432),
(1553541764334661477,300161579),
(1553541764700140188,300161726),
(1553541765063225758,300161878),
(1553541765427847716,300162032),
(1553541765828327834,300162179),
(1553541766209389001,300162331),
(1553541766575525148,300162485),
(1553541766917404138,300162632)]

(start,z) = no_2_raw[0]
no2_x = [(i - start)/1000000000 for (i,j) in no_2_raw]
no2_y = [j for (i,j) in no_2_raw]

# %%
no_3_raw = [
    (1553541894405094894,2812365),
(1553541894491710964,5564481),
(1553541894578068858,8284196),
(1553541894658706524,11004535),
(1553541894755601007,13756349),
(1553541894867457100,16476676),
(1553541894973010426,19228234),
(1553541895080079306,21948587),
(1553541895220478539,24636911),
(1553541895305580200,27388186),
(1553541895402269321,30108517),
(1553541895599334975,32860831),
(1553541895818315882,35549157),
(1553541895921539005,38300001),
(1553541896047082061,40988317),
(1553541896171504430,43772638),
(1553541896334836354,46460957),
(1553541896556754465,49213294),
(1553541896724904754,51899401),
(1553541896869847729,54651715),
(1553541897007035482,57404056),
(1553541897142598678,60092372),
(1553541897318854591,62812681),
(1553541897474532209,65565009),
(1553541897640676845,68317336),
(1553541897819331540,71005657),
(1553541898043443852,73754870),
(1553541898217771670,76443188),
(1553541898393477375,79195522),
(1553541898553200333,81947836),
(1553541898732676365,84636154),
(1553541898919553284,87356489),
(1553541899117010231,90108814),
(1553541899319674796,92861142),
(1553541899515946116,95549468),
(1553541899720536560,98301793),
(1553541900062578101,101054121),
(1553541900270148313,103742447),
(1553541900502903823,106490420),
(1553541900674705550,109178743),
(1553541900851840079,111931069),
(1553541901057867152,114683392),
(1553541901234738923,117371715),
(1553541901417311534,120124041),
(1553541901641706289,122812360),
(1553541901885106271,125596696),
(1553541902138598227,128285020),
(1553541902385043713,131037346),
(1553541902631858745,133725665),
(1553541902907391186,136478002),
(1553541903185524000,139230318),
(1553541903475075278,141918625),
(1553541903785821928,144670966),
(1553541904108136670,147423282),
(1553541904496670380,150111589),
(1553541904779001619,152857599),
(1553541905087657997,155545915),
(1553541905373872152,158298229),
(1553541905670404933,161050570),
(1553541905957221031,163738886),
(1553541906220913718,166491200),
(1553541906500627566,169179518),
(1553541906799346617,171931852),
(1553541907040499180,174684166),
(1553541907306384756,177404493),
(1553541907586061080,180092819),
(1553541907902775289,182845144),
(1553541908231661493,185597472),
(1553541908568030866,188285798),
(1553541908905721506,191038123),
(1553541909217566942,193726446),
(1553541909551107059,196478772),
(1553541909888457084,199231097),
(1553541910277415699,201919420),
(1553541910850158243,204671746),
(1553541911194348944,207424069),
(1553541911523016550,210112392),
(1553541911865033399,212864718),
(1553541912328479955,215544100),
(1553541912665276732,218296437),
(1553541913012393662,221048753),
(1553541913350586634,223737060),
(1553541913707918215,226489401),
(1553541914048316326,229177717),
(1553541914408953371,231930031),
(1553541914785095252,234682372),
(1553541915094831714,237370688),
(1553541915431468847,240123002),
(1553541915743053007,242875343),
(1553541916071800188,245563659),
(1553541916461562026,248315973),
(1553541916977773794,251004291),
(1553541917374237065,253788630),
(1553541917829747146,256476951),
(1553541918266400350,259229279),
(1553541918653326654,261917605),
(1553541919070394750,264669930),
(1553541919496592127,267422258),
(1553541919863314792,270110584),
(1553541920232553123,272862909),
(1553541920640931141,275551232),
(1553541921065888688,278303558),
(1553541921452862275,281055883),
(1553541921829035221,283744206),
(1553541922233146402,286496532),
(1553541922673930782,289248855),
(1553541923132301683,291937178),
(1553541923559443585,294689504),
(1553541923957658309,297377823),
(1553541924378544412,300130160),
(1553541924730676327,300161278),
(1553541925084078123,300161432),
(1553541925433866236,300161579),
(1553541925793520589,300161726),
(1553541926153922175,300161878),
(1553541926510439272,300162032),
(1553541926860272793,300162179),
(1553541927226204896,300162331),
(1553541927593591598,300162485),
(1553541927941173186,300162632)
]

(start,z) = no_3_raw[0]
no3_x = [(i - start)/1000000000 for (i,j) in no_3_raw]
no3_y = [j for (i,j) in no_3_raw]

# %%
no_4_raw = [(1553541997214143794,2812365),
(1553541997301008824,5564481),
(1553541997390661419,8284196),
(1553541997474677295,11004535),
(1553541997573664780,13756349),
(1553541997682902172,16476676),
(1553541997790337561,19228234),
(1553541997887954533,21948587),
(1553541998024663706,24636911),
(1553541998126361048,27388186),
(1553541998227959915,30108517),
(1553541998371981135,32860831),
(1553541998532003743,35549157),
(1553541998640400278,38300001),
(1553541998737935304,40988317),
(1553541998850144426,43772638),
(1553541998975392436,46460957),
(1553541999156294067,49213294),
(1553541999314118442,51899401),
(1553541999426763070,54651715),
(1553541999540162960,57404056),
(1553541999657194083,60092372),
(1553541999800273618,62812681),
(1553541999945513018,65565009),
(1553542000114098570,68317336),
(1553542000269764544,71005657),
(1553542000446873645,73754870),
(1553542000582987745,76443188),
(1553542000733352255,79195522),
(1553542000883529881,81947836),
(1553542001023906779,84636154),
(1553542001180204438,87356489),
(1553542001347638006,90108814),
(1553542001543135025,92861142),
(1553542001726459005,95549468),
(1553542001904829532,98301793),
(1553542002205615789,101054121),
(1553542002392801410,103742447),
(1553542002608026628,106490420),
(1553542002787045412,109178743),
(1553542002954788145,111931069),
(1553542003125338456,114683392),
(1553542003309573963,117371715),
(1553542003484507183,120124041),
(1553542003661152797,122812360),
(1553542003859841397,125596696),
(1553542004077680562,128285020),
(1553542004288632455,131037346),
(1553542004518929513,133725665),
(1553542004742839787,136478002),
(1553542004974919374,139230318),
(1553542005207086508,141918625),
(1553542005431926454,144670966),
(1553542005671094558,147423282),
(1553542005946033680,150111589),
(1553542006160217707,152857599),
(1553542006387942745,155545915),
(1553542006602773607,158298229),
(1553542006831587673,161050570),
(1553542007069223885,163738886),
(1553542007304405669,166491200),
(1553542007538372459,169179518),
(1553542007763136264,171931852),
(1553542008003345953,174684166),
(1553542008234969613,177404493),
(1553542008490009004,180092819),
(1553542008763505561,182845144),
(1553542009022952282,185597472),
(1553542009299174479,188285798),
(1553542009572716290,191038123),
(1553542009846287592,193726446),
(1553542010136267657,196478772),
(1553542010417448354,199231097),
(1553542010741731933,201919420),
(1553542011229336768,204671746),
(1553542011523229649,207424069),
(1553542011808920643,210112392),
(1553542012106661958,212864718),
(1553542012504306300,215544100),
(1553542012790755697,218296437),
(1553542013077350738,221048753),
(1553542013363788797,223737060),
(1553542013674616995,226489401),
(1553542013961966866,229177717),
(1553542014284247105,231930031),
(1553542014578034758,234682372),
(1553542014890470404,237370688),
(1553542015185663828,240123002),
(1553542015497429185,242875343),
(1553542015795734486,245563659),
(1553542016116884466,248315973),
(1553542016445265713,251004291),
(1553542016792039748,253788630),
(1553542017188998227,256476951),
(1553542017568583716,259229279),
(1553542017929989532,261917605),
(1553542018301105841,264669930),
(1553542018690195012,267422258),
(1553542019077398608,270110584),
(1553542019452271413,272862909),
(1553542019842442774,275551232),
(1553542020230724798,278303558),
(1553542020635327069,281055883),
(1553542021032572209,283744206),
(1553542021459144433,286496532),
(1553542021853125402,289248855),
(1553542022268869781,291937178),
(1553542022708730509,294689504),
(1553542023200557666,297377823),
(1553542023630611549,300130160),
(1553542023994955120,300161278),
(1553542024346266089,300161432),
(1553542024708590960,300161579),
(1553542025086422886,300161726),
(1553542025472859824,300161878),
(1553542025855360833,300162032),
(1553542026216609174,300162179),
(1553542026576588460,300162331),
(1553542026942733358,300162485),
(1553542027302063278,300162632)]

(start,z) = no_4_raw[0]
no4_x = [(i - start)/1000000000 for (i,j) in no_4_raw]
no4_y = [j for (i,j) in no_4_raw]

# %%
no_5_raw = [(1553542118282183784,2812365),
(1553542118372319635,5564481),
(1553542118458800926,8284196),
(1553542118539893669,11004535),
(1553542118635520211,13756349),
(1553542118739889258,16476676),
(1553542118831352913,19228234),
(1553542118920895082,21948587),
(1553542119074792209,24636911),
(1553542119167218142,27388186),
(1553542119266455294,30108517),
(1553542119410939543,32860831),
(1553542119559414381,35549157),
(1553542119683970500,38300001),
(1553542119792971527,40988317),
(1553542119911526213,43772638),
(1553542120044724795,46460957),
(1553542120249164135,49213294),
(1553542120401487606,51899401),
(1553542120519997357,54651715),
(1553542120669488985,57404056),
(1553542120824601017,60092372),
(1553542120990794752,62812681),
(1553542121160411958,65565009),
(1553542121331121655,68317336),
(1553542121519321673,71005657),
(1553542121737507622,73754870),
(1553542121890066618,76443188),
(1553542122061314620,79195522),
(1553542122225764121,81947836),
(1553542122383637497,84636154),
(1553542122537318527,87356489),
(1553542122709540506,90108814),
(1553542122893649413,92861142),
(1553542123078308189,95549468),
(1553542123277728211,98301793),
(1553542123587865975,101054121),
(1553542123801335928,103742447),
(1553542124035763504,106490420),
(1553542124226782157,109178743),
(1553542124418870062,111931069),
(1553542124614658849,114683392),
(1553542124813107816,117371715),
(1553542125020766611,120124041),
(1553542125219247157,122812360),
(1553542125454990190,125596696),
(1553542125668961416,128285020),
(1553542125893648883,131037346),
(1553542126131954130,133725665),
(1553542126381149921,136478002),
(1553542126627507922,139230318),
(1553542126872116609,141918625),
(1553542127121180626,144670966),
(1553542127383086873,147423282),
(1553542127702175130,150111589),
(1553542127972869841,152857599),
(1553542128241683265,155545915),
(1553542128488204223,158298229),
(1553542128748998894,161050570),
(1553542129015643340,163738886),
(1553542129241360053,166491200),
(1553542129515756115,169179518),
(1553542129795625483,171931852),
(1553542130066694530,174684166),
(1553542130301289362,177404493),
(1553542130597054067,180092819),
(1553542130882831779,182845144),
(1553542131182654797,185597472),
(1553542131510405536,188285798),
(1553542131831753153,191038123),
(1553542132146400873,193726446),
(1553542132486756445,196478772),
(1553542132829763872,199231097),
(1553542133216552667,201919420),
(1553542133797503788,204671746),
(1553542134121941055,207424069),
(1553542134512384372,210112392),
(1553542134919442527,212864718),
(1553542135410084593,215544100),
(1553542135727827694,218296437),
(1553542136046311574,221048753),
(1553542136371590777,223737060),
(1553542136690551900,226489401),
(1553542136988664420,229177717),
(1553542137298534692,231930031),
(1553542137616268146,234682372),
(1553542137939968652,237370688),
(1553542138271746992,240123002),
(1553542138602984758,242875343),
(1553542138927811641,245563659),
(1553542139269910502,248315973),
(1553542139602603339,251004291),
(1553542139971758119,253788630),
(1553542140437387535,256476951),
(1553542140887782123,259229279),
(1553542141330436169,261917605),
(1553542141779596046,264669930),
(1553542142183712258,267422258),
(1553542142611694546,270110584),
(1553542143005466579,272862909),
(1553542143389794789,275551232),
(1553542143780126877,278303558),
(1553542144232397286,281055883),
(1553542144614389267,283744206),
(1553542145005398393,286496532),
(1553542145421460491,289248855),
(1553542145852017558,291937178),
(1553542146284828583,294689504),
(1553542146759058573,297377823),
(1553542147195635837,300130160),
(1553542147617909264,300161278),
(1553542148029901919,300161432),
(1553542148454282546,300161579),
(1553542148823949986,300161726),
(1553542149184485818,300161878),
(1553542149544107082,300162032),
(1553542149920015385,300162179),
(1553542150330068098,300162331),
(1553542150742537297,300162485),
(1553542151107224704,300162632),
]

(start,z) = no_5_raw[0]
no5_x = [(i - start)/1000000000 for (i,j) in no_5_raw]
no5_y = [j for (i,j) in no_5_raw]

# %%
results_x = [no_x,no2_x,no3_x,no4_x,no5_x]

no_avg = []
no_stdev = []
for i in range(len(no_x)):
    extracted = []
    for j in range(len(results_x)):
        extracted += [results_x[j][i]]
        
#     print(extracted)
    no_avg += [statistics.mean(extracted)]
    no_stdev += [statistics.stdev(extracted)]
    
upper = [no_avg[i] + 1 * no_stdev[i] for i in range(len(no_avg))]
lower = [no_avg[i] - 1 * no_stdev[i] for i in range(len(no_avg))]

# %%
fig,ax = plt.subplots()

# ax.plot(no_x,no_y,color="red",linewidth=0.5)

# ax.plot(no2_x,no2_y,color="green",linewidth=0.5)

# ax.plot(no3_x,no3_y,color="blue",linewidth=0.5)


# ax.plot(no4_x,no4_y,color="yellow",linewidth=0.5)


# ax.plot(no5_x,no5_y,color="black",linewidth=0.5)


plt.fill_betweenx(no_y,lower,upper,alpha=1,color="#8cdcff",label="$\pm 1 \sigma$ in time")

for j in numpy.arange(0,1.1,0.1):
    ax.plot([no_avg[i] - j * no_stdev[i] for i in range(len(no_avg))],no_y,color="#8cdcff")
    ax.plot([no_avg[i] + j * no_stdev[i] for i in range(len(no_avg))],no_y,color="#8cdcff")


ax.plot(no_avg,no_y,color='black',linewidth=1)


plt.legend(frameon=False)



ax.set_xlabel("Time / s")
ax.set_ylabel("Words of live data in the major heap")
# plt.ticklabel_format(style='plain')
# print(act_x)
# print(act_y)


fig.savefig((loc + "/no_tail_recursion.png"),dpi=800,bbox_inches='tight')
